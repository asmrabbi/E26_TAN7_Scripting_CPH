# %% [markdown]
# # L04 Student Exercises — Control Flow Collections Functions
#
# **Course:** AAU E26 — Introduction to Scripting, Data Mining and Machine Learning
# **Lecture:** Lecture 4 — Conditions, loops, lists, functions and debugging
# **Goal:** Practise conditions, loops, lists, functions, and boundary testing.
#
# [Open this notebook in Google Colab](https://colab.research.google.com/github/asmrabbi/E26_TAN7_Scripting_CPH/blob/main/notebooks/exercises/L04_exercises_control_flow_collections_functions.ipynb) · [View the course repository](https://github.com/asmrabbi/E26_TAN7_Scripting_CPH)
#
# Run the cells from top to bottom. Every executable line includes a short comment explaining what it does.

# %% [markdown]
# ## Goal
#
# Practise conditions, loops, lists, functions, and boundary testing.

# %% [markdown]
# ## Setup
#
# Attempt each task before opening the separately released solution notebook.
#
# ### Running this notebook on a local computer
#
# 1. Download or clone the course repository.
# 2. Open a terminal in the repository folder.
# 3. Create and activate a virtual environment.
# 4. Install the shared requirements with `python -m pip install -r requirements.txt`.
# 5. Start Jupyter with `python -m jupyter lab`.
#
# Packages used directly in this notebook: `No third-party package is required for this notebook.`

# %% [markdown]
# ## Steps
#
# 1. Write a function that returns problems for an invalid satisfaction score.
# 2. Test the function with 1.0, 5.0, 0.9, 5.1, and None.
# 3. Loop over a list of records and count how many require review.
# 4. Explain why the two exact boundary values are important tests.

# %%
test_scores = [1.0, 5.0, 0.9, 5.1, None]  # Stores normal, boundary, invalid, and missing test cases.
# TODO: Define validate_score(score) below this comment.
# TODO: Return a list of clear problem messages from the function.
# TODO: Loop through test_scores and print each score with its result.
# TODO: Count how many scores require review.

# %% [markdown]
# ## Checks
#
# 1.0 and 5.0 are valid boundaries; 0.9, 5.1, and None require review, so the expected count is 3.

# %% [markdown]
# ## Next Steps
#
# Change one input, predict the result before running, and explain any difference between the expected and observed output.
