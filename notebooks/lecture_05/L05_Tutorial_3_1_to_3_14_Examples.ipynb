# %% [markdown]
# # Lecture 5 — Tutorials 3.1–3.14 Examples
#
# **Goal.** Run every worked or reference Python example from Tutorials 3.1–3.13 in website order and inspect its verified output.
#
# This notebook matches the numbered Lecture 5 website tutorials. The dataset is synthetic, contains deliberate quality problems and must not be interpreted as evidence about real cities or services.
#
# **Local setup.** Google Colab includes pandas. On a local machine, run `python -m pip install -r requirements.txt` from the repository, or install pandas with `python -m pip install "pandas>=2.0"`.

# %% [markdown]
# ## Setup
#
# Run this cell first. It loads the versioned raw CSV from GitHub and checks the expected 121 × 14 structure. Keep the raw data unchanged during Lecture 5.

# %%
import pandas as pd  # Loads the library feature used by this step.
data_url = "https://raw.githubusercontent.com/asmrabbi/E26_TAN7_Scripting_CPH/main/data/E26_TAN7_service_experience_raw.csv"  # Stores the calculated or supplied value for later use.
df = pd.read_csv(data_url)  # Stores the calculated or supplied value for later use.
print("Dataset shape:", df.shape)  # Displays the result so it can be inspected.
assert df.shape == (121, 14), "The wrong dataset version was loaded."  # Stores the calculated or supplied value for later use.
display(df.head())  # Displays the result so it can be inspected.
# Out:
# Dataset shape: (121, 14)
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
#
# [5 rows x 14 columns]

# %% [markdown]
# # Tutorial 3.1
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.1 reference 1 — Why move beyond individual variables?
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
city = "Copenhagen"  # Stores the calculated or supplied value for later use.
service_type = "Housing"  # Stores the calculated or supplied value for later use.
cases_received = 120  # Stores the calculated or supplied value for later use.
cases_resolved = 112  # Stores the calculated or supplied value for later use.

# %% [markdown]
# # Tutorial 3.2
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.2 reference 1 — Delimiters are not always commas
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# pd.read_csv("file.csv", sep=";")  # Stores the calculated or supplied value for later use.
print("Reference cell: run the website example manually to observe FileNotFoundError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe FileNotFoundError.

# %% [markdown]
# # Tutorial 3.3
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.3 reference 1 — Import pandas
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
import pandas as pd  # Loads the library feature used by this step.

# %% [markdown]
# ## Tutorial 3.3 reference 2 — Line-by-line explanation
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# pd.read_csv(...)  # Runs this part of the documented analysis.
print("Reference cell: run the website example manually to observe ValueError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe ValueError.

# %% [markdown]
# ## Tutorial 3.3 reference 3 — Line-by-line explanation
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# pandas.read_csv(...)  # Runs this part of the documented analysis.
print("Reference cell: run the website example manually to observe NameError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe NameError.

# %% [markdown]
# ## Example 3.3.1 — Confirm pandas is available
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
import pandas as pd  # Loads the library feature used by this step.

print(pd.__version__)  # Displays the result so it can be inspected.
# Out:
# 2.2.3

# %% [markdown]
# ## Tutorial 3.3 reference 5 — What is a DataFrame?
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
import pandas as pd  # Loads the library feature used by this step.

data = {  # Stores the calculated or supplied value for later use.
    "city": ["Copenhagen", "Aalborg"],  # Runs this part of the documented analysis.
    "cases_received": [120, 92]  # Runs this part of the documented analysis.
}  # Keeps this multi-line expression readable.

df_small = pd.DataFrame(data)  # Stores the calculated or supplied value for later use.
df_small  # Runs this part of the documented analysis.
# Out:
#          city  cases_received
# 0  Copenhagen             120
# 1     Aalborg              92

# %% [markdown]
# ## Example 3.3.2 — DataFrame versus Series
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(type(df_small))  # Displays the result so it can be inspected.
print(type(df_small["city"]))  # Displays the result so it can be inspected.
print(type(df_small[["city"]]))  # Displays the result so it can be inspected.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Tutorial 3.3 reference 7 — The main course loading method: raw GitHub URL
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
import pandas as pd  # Loads the library feature used by this step.

url = "https://raw.githubusercontent.com/asmrabbi/E26_TAN7_Scripting_CPH/main/data/E26_TAN7_service_experience_raw.csv"  # Stores the calculated or supplied value for later use.
df = pd.read_csv(url)  # Stores the calculated or supplied value for later use.

df.head()  # Runs this part of the documented analysis.
# Out:
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Example 3.3.3 — Load from a local path
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# df = pd.read_csv("data/E26_TAN7_service_experience_raw.csv")  # Stores the calculated or supplied value for later use.
print("Reference cell: run the website example manually to observe FileNotFoundError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe FileNotFoundError.

# %% [markdown]
# ## Tutorial 3.3 reference 9 — Uploading a CSV in Google Colab
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# df = pd.read_csv("E26_TAN7_service_experience_raw.csv")  # Stores the calculated or supplied value for later use.
print("Reference cell: run the website example manually to observe FileNotFoundError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe FileNotFoundError.

# %% [markdown]
# ## Tutorial 3.3 reference 10 — Upload through Python
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# from google.colab import files  # Loads the library feature used by this step.
#
# uploaded = files.upload()  # Stores the calculated or supplied value for later use.
print("Reference cell: run the website example manually to observe ModuleNotFoundError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe ModuleNotFoundError.

# %% [markdown]
# ## Tutorial 3.3 reference 11 — Upload through Python
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# df = pd.read_csv("E26_TAN7_service_experience_raw.csv")  # Stores the calculated or supplied value for later use.
print("Reference cell: run the website example manually to observe FileNotFoundError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe FileNotFoundError.

# %% [markdown]
# ## Tutorial 3.3 reference 12 — Wrong delimiter
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# df = pd.read_csv("file.csv", sep=";")  # Stores the calculated or supplied value for later use.
print("Reference cell: run the website example manually to observe FileNotFoundError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe FileNotFoundError.

# %% [markdown]
# ## Tutorial 3.3 reference 13 — Encoding error
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# df = pd.read_csv("file.csv", encoding="utf-8")  # Stores the calculated or supplied value for later use.
print("Reference cell: run the website example manually to observe FileNotFoundError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe FileNotFoundError.

# %% [markdown]
# ## Tutorial 3.3 reference 14 — Methods versus attributes
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.head()  # Runs this part of the documented analysis.
# Out:
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Tutorial 3.3 reference 15 — Methods versus attributes
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.shape  # Runs this part of the documented analysis.
# Out:
# (121, 14)

# %% [markdown]
# ## Tutorial 3.3 reference 16 — Broken code
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# import pandas as pd  # Loads the library feature used by this step.
#
# df = pd.read_csv("E26_TAN7_service_experiences_raw.csv")  # Stores the calculated or supplied value for later use.
print("Reference cell: run the website example manually to observe FileNotFoundError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe FileNotFoundError.

# %% [markdown]
# # Tutorial 3.4
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.4 reference 1 — Start from a fresh load
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
import pandas as pd  # Loads the library feature used by this step.

url = "https://raw.githubusercontent.com/asmrabbi/E26_TAN7_Scripting_CPH/main/data/E26_TAN7_service_experience_raw.csv"  # Stores the calculated or supplied value for later use.
df = pd.read_csv(url)  # Stores the calculated or supplied value for later use.

# %% [markdown]
# ## Tutorial 3.4 reference 2 — `head()` — inspect the first rows
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.head()  # Runs this part of the documented analysis.
# Out:
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Tutorial 3.4 reference 3 — `head()` — inspect the first rows
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.head(10)  # Runs this part of the documented analysis.
# Out:
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
# 5  SR2026-0006  ...  Helpful staff explained the housing process, a...
# 6  SR2026-0007  ...  Several users asked for clearer information ab...
# 7  SR2026-0008  ...  The answer was useful, although the waiting ti...
# 8  SR2026-0009  ...  Collection information was easy to understand ...
# 9  SR2026-0010  ...                 Friendly staff and a clear answer.
#
# [10 rows x 14 columns]

# %% [markdown]
# ## Tutorial 3.4 reference 4 — `tail()` — inspect the final rows
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.tail()  # Runs this part of the documented analysis.
# Out:
#        record_id  ...                                           feedback
# 116  SR2026-0117  ...  The digital form worked well, although some in...
# 117  SR2026-0118  ...                                                NaN
# 118  SR2026-0119  ...  Collection information was easy to understand ...
# 119  SR2026-0120  ...  The response was fast and the information was ...
# 120  SR2026-0027  ...  The digital form worked well, although some in...
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Tutorial 3.4 reference 5 — `sample()` — inspect rows from different positions
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.sample(5, random_state=42)  # Stores the calculated or supplied value for later use.
# Out:
#       record_id  ...                                           feedback
# 44  SR2026-0045  ...  The online process was easy to use, although o...
# 47  SR2026-0048  ...  The online information was helpful, but some u...
# 4   SR2026-0005  ...  The response was fast and the information was ...
# 55  SR2026-0056  ...  Helpful staff explained the housing process, a...
# 26  SR2026-0027  ...  The digital form worked well, although some in...
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Tutorial 3.4 reference 6 — `shape` — how many rows and columns?
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.shape  # Runs this part of the documented analysis.
# Out:
# (121, 14)

# %% [markdown]
# ## Tutorial 3.4 reference 7 — `shape` — how many rows and columns?
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
rows, columns = df.shape  # Stores the calculated or supplied value for later use.

print("Rows:", rows)  # Displays the result so it can be inspected.
print("Columns:", columns)  # Displays the result so it can be inspected.
# Out:
# Rows: 121
# Columns: 14

# %% [markdown]
# ## Tutorial 3.4 reference 8 — `len(df)` — another way to count rows
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
len(df)  # Runs this part of the documented analysis.
# Out:
# 121

# %% [markdown]
# ## Tutorial 3.4 reference 9 — `columns` — inspect column names
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.columns  # Runs this part of the documented analysis.
# Out:
# Index(['record_id', 'report_month', 'city', 'service_type', 'cases_received',
#        'cases_resolved', 'resolution_days', 'satisfaction_score',
#        'digital_cases', 'in_person_cases', 'repeat_contacts',
#        'complaints_received', 'staff_hours', 'feedback'],
#       dtype='object')

# %% [markdown]
# ## Tutorial 3.4 reference 10 — `columns` — inspect column names
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(df.columns.tolist())  # Displays the result so it can be inspected.
# Out:
# ['record_id', 'report_month', 'city', 'service_type', 'cases_received', 'cases_resolved', 'resolution_days', 'satisfaction_score', 'digital_cases', 'in_person_cases', 'repeat_contacts', 'complaints_received', 'staff_hours', 'feedback']

# %% [markdown]
# ## Tutorial 3.4 reference 11 — `index` — inspect row labels
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.index  # Runs this part of the documented analysis.
# Out:
# RangeIndex(start=0, stop=121, step=1)

# %% [markdown]
# ## Tutorial 3.4 reference 12 — `dtypes` — how pandas currently represents each column
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.dtypes  # Runs this part of the documented analysis.
# Out:
# record_id               object
# report_month            object
# city                    object
# service_type            object
# cases_received           int64
# cases_resolved           int64
# resolution_days         object
# satisfaction_score     float64
# digital_cases            int64
# in_person_cases          int64
# repeat_contacts          int64
# complaints_received      int64
# staff_hours            float64
# feedback                object
# dtype: object

# %% [markdown]
# ## Tutorial 3.4 reference 13 — `info()` — compact structural inspection
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.info()  # Runs this part of the documented analysis.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   record_id            121 non-null    object
#  1   report_month         121 non-null    object
#  2   city                 121 non-null    object
#  3   service_type         121 non-null    object
#  4   cases_received       121 non-null    int64
#  5   cases_resolved       121 non-null    int64
#  6   resolution_days      121 non-null    object
#  7   satisfaction_score   117 non-null    float64
#  8   digital_cases        121 non-null    int64
#  9   in_person_cases      121 non-null    int64
#  10  repeat_contacts      121 non-null    int64
#  11  complaints_received  121 non-null    int64
#  12  staff_hours          121 non-null    float64
#  13  feedback             118 non-null    object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 13.4+ KB

# %% [markdown]
# ## Tutorial 3.4 reference 14 — A repeatable first-inspection routine
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print("Shape:", df.shape)  # Displays the result so it can be inspected.
print("\nColumns:")  # Displays the result so it can be inspected.
print(df.columns.tolist())  # Displays the result so it can be inspected.

print("\nFirst rows:")  # Displays the result so it can be inspected.
display(df.head())  # Displays the result so it can be inspected.

print("\nData types:")  # Displays the result so it can be inspected.
print(df.dtypes)  # Displays the result so it can be inspected.

print("\nInfo:")  # Displays the result so it can be inspected.
df.info()  # Runs this part of the documented analysis.
# Out:
# Shape: (121, 14)
#
# Columns:
# ['record_id', 'report_month', 'city', 'service_type', 'cases_received', 'cases_resolved', 'resolution_days', 'satisfaction_score', 'digital_cases', 'in_person_cases', 'repeat_contacts', 'complaints_received', 'staff_hours', 'feedback']
#
# First rows:
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
#
# [5 rows x 14 columns]
#
# Data types:
# record_id               object
# report_month            object
# city                    object
# service_type            object
# cases_received           int64
# cases_resolved           int64
# resolution_days         object
# ...

# %% [markdown]
# ## Example 3.4.1 — Interpret shape correctly
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(df.shape)  # Displays the result so it can be inspected.
# Out:
# (121, 14)

# %% [markdown]
# ## Example 3.4.2 — Compare `head()` and `sample()`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print("First five rows")  # Displays the result so it can be inspected.
display(df.head())  # Displays the result so it can be inspected.

print("Random sample")  # Displays the result so it can be inspected.
display(df.sample(5, random_state=42))  # Displays the result so it can be inspected.
# Out:
# First five rows
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
#
# [5 rows x 14 columns]
# Random sample
#       record_id  ...                                           feedback
# 44  SR2026-0045  ...  The online process was easy to use, although o...
# 47  SR2026-0048  ...  The online information was helpful, but some u...
# 4   SR2026-0005  ...  The response was fast and the information was ...
# 55  SR2026-0056  ...  Helpful staff explained the housing process, a...
# 26  SR2026-0027  ...  The digital form worked well, although some in...
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Tutorial 3.4 reference 17 — Broken code
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# print(df.shape())  # Displays the result so it can be inspected.
print("Reference cell: run the website example manually to observe TypeError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe TypeError.

# %% [markdown]
# ## Tutorial 3.4 reference 18 — Repair
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(df.shape)  # Displays the result so it can be inspected.
# Out:
# (121, 14)

# %% [markdown]
# # Tutorial 3.5
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.5 reference 1 — Select one column
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
city = df["city"]  # Stores the calculated or supplied value for later use.
city.head()  # Runs this part of the documented analysis.
# Out:
# 0    Copenhagen
# 1    Copenhagen
# 2    Copenhagen
# 3    Copenhagen
# 4    Copenhagen
# Name: city, dtype: object

# %% [markdown]
# ## Tutorial 3.5 reference 2 — Select one column
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(type(df["city"]))  # Displays the result so it can be inspected.
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Tutorial 3.5 reference 3 — Why the column name uses quotation marks
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["city"]  # Runs this part of the documented analysis.
# Out:
# 0       Copenhagen
# 1       Copenhagen
# 2       Copenhagen
# 3       Copenhagen
# 4       Copenhagen
# 5           Aarhus
# 6      copenhagen
# 7           Aarhus
# 8           Aarhus
# 9           Aarhus
# 10          Odense
# 11          Odense
# 12          Odense
# 13          Odense
# 14          Odense
# 15         Aalborg
# 16         Aalborg
# 17         Aalborg
# 18         Aalborg
# 19         Aalborg
# [Stored output shortened: showing 20 of 121 values. Colab displays the full result.]

# %% [markdown]
# ## Tutorial 3.5 reference 4 — Why the column name uses quotation marks
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# df[city]  # Runs this part of the documented analysis.
print("Reference cell: run the website example manually to observe KeyError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe KeyError.

# %% [markdown]
# ## Example 3.5.1 — Select a numeric column
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
cases = df["cases_received"]  # Stores the calculated or supplied value for later use.
print(cases.head())  # Displays the result so it can be inspected.
# Out:
# 0    130
# 1    124
# 2    105
# 3    104
# 4    166
# Name: cases_received, dtype: int64

# %% [markdown]
# ## Example 3.5.1 — Select a numeric column
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(cases.sum())  # Displays the result so it can be inspected.
# Out:
# 12653

# %% [markdown]
# ## Tutorial 3.5 reference 7 — Select several columns
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
subset = df[["city", "service_type", "cases_received"]]  # Stores the calculated or supplied value for later use.
subset.head()  # Runs this part of the documented analysis.
# Out:
#          city      service_type  cases_received
# 0  Copenhagen           Housing             130
# 1  Copenhagen         Transport             124
# 2  Copenhagen        Employment             105
# 3  Copenhagen             Waste             104
# 4  Copenhagen  Citizen Services             166

# %% [markdown]
# ## Example 3.5.2 — Build a readable preview table
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
columns_to_show = [  # Stores the calculated or supplied value for later use.
    "record_id",  # Runs this part of the documented analysis.
    "city",  # Runs this part of the documented analysis.
    "service_type",  # Runs this part of the documented analysis.
    "cases_received",  # Runs this part of the documented analysis.
    "cases_resolved"  # Runs this part of the documented analysis.
]  # Keeps this multi-line expression readable.

preview = df[columns_to_show]  # Stores the calculated or supplied value for later use.
preview.head()  # Runs this part of the documented analysis.
# Out:
#      record_id        city      service_type  cases_received  cases_resolved
# 0  SR2026-0001  Copenhagen           Housing             130             116
# 1  SR2026-0002  Copenhagen         Transport             124             110
# 2  SR2026-0003  Copenhagen        Employment             105              93
# 3  SR2026-0004  Copenhagen             Waste             104              94
# 4  SR2026-0005  Copenhagen  Citizen Services             166             152

# %% [markdown]
# ## Tutorial 3.5 reference 9 — Selecting by label with `.loc[]`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.loc[0]  # Runs this part of the documented analysis.
# Out:
# record_id                                                    SR2026-0001
# report_month                                                  2026-01-01
# city                                                          Copenhagen
# service_type                                                     Housing
# cases_received                                                       130
# cases_resolved                                                       116
# resolution_days                                                      8.0
# satisfaction_score                                                   3.5
# digital_cases                                                         88
# in_person_cases                                                       42
# repeat_contacts                                                       17
# complaints_received                                                   10
# staff_hours                                                         87.8
# ...

# %% [markdown]
# ## Tutorial 3.5 reference 10 — Selecting by label with `.loc[]`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.loc[0:4, ["city", "service_type", "cases_received"]]  # Runs this part of the documented analysis.
# Out:
#          city      service_type  cases_received
# 0  Copenhagen           Housing             130
# 1  Copenhagen         Transport             124
# 2  Copenhagen        Employment             105
# 3  Copenhagen             Waste             104
# 4  Copenhagen  Citizen Services             166

# %% [markdown]
# ## Tutorial 3.5 reference 11 — Important slicing detail
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.loc[0:4]  # Runs this part of the documented analysis.
# Out:
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Tutorial 3.5 reference 12 — Selecting by position with `.iloc[]`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.iloc[0]  # Runs this part of the documented analysis.
# Out:
# record_id                                                    SR2026-0001
# report_month                                                  2026-01-01
# city                                                          Copenhagen
# service_type                                                     Housing
# cases_received                                                       130
# cases_resolved                                                       116
# resolution_days                                                      8.0
# satisfaction_score                                                   3.5
# digital_cases                                                         88
# in_person_cases                                                       42
# repeat_contacts                                                       17
# complaints_received                                                   10
# staff_hours                                                         87.8
# ...

# %% [markdown]
# ## Tutorial 3.5 reference 13 — Selecting by position with `.iloc[]`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.iloc[0:5]  # Runs this part of the documented analysis.
# Out:
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Tutorial 3.5 reference 14 — Selecting by position with `.iloc[]`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.iloc[0:5, 0:4]  # Runs this part of the documented analysis.
# Out:
#      record_id report_month        city      service_type
# 0  SR2026-0001   2026-01-01  Copenhagen           Housing
# 1  SR2026-0002   2026-01-01  Copenhagen         Transport
# 2  SR2026-0003   2026-01-01  Copenhagen        Employment
# 3  SR2026-0004   2026-01-01  Copenhagen             Waste
# 4  SR2026-0005   2026-01-01  Copenhagen  Citizen Services

# %% [markdown]
# ## Tutorial 3.5 reference 15 — Boolean filtering
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["cases_received"] > 100  # Runs this part of the documented analysis.
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# [Stored output shortened: showing 20 of 121 values. Colab displays the full result.]

# %% [markdown]
# ## Tutorial 3.5 reference 16 — Boolean filtering
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
high_case_rows = df[df["cases_received"] > 100]  # Stores the calculated or supplied value for later use.
high_case_rows  # Runs this part of the documented analysis.
# Out:
#       record_id report_month        city      service_type  cases_received  cases_resolved resolution_days  satisfaction_score  digital_cases  in_person_cases  repeat_contacts  complaints_received  staff_hours                                                                            feedback
# 0   SR2026-0001   2026-01-01  Copenhagen           Housing             130             116             8.0                 3.5             88               42               17                   10         87.8     The guidance was clear, but the supporting-document requirements caused delays.
# 1   SR2026-0002   2026-01-01  Copenhagen         Transport             124             110             5.1                 3.9             92               32               10                    8         54.7                  Several users asked for clearer information about service changes.
# ...

# %% [markdown]
# ## Example 3.5.3 — Filter by category
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
housing = df[df["service_type"] == "Housing"]  # Stores the calculated or supplied value for later use.
housing  # Runs this part of the documented analysis.
# Out:
#       record_id report_month        city service_type  cases_received  cases_resolved resolution_days  satisfaction_score  digital_cases  in_person_cases  repeat_contacts  complaints_received  staff_hours                                                                                     feedback
# 0   SR2026-0001   2026-01-01  Copenhagen      Housing             130             116             8.0                 3.5             88               42               17                   10         87.8              The guidance was clear, but the supporting-document requirements caused delays.
# 5   SR2026-0006   2026-01-01      Aarhus      Housing             111              96             7.5                 3.6             69               42               16                    8         72.0            Helpful staff explained the housing process, although the waiting time felt long.
# ...

# %% [markdown]
# ## Example 3.5.3 — Filter by category
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df[df["service_type"] == "housing"]  # Stores the calculated or supplied value for later use.
# Out:
# Empty DataFrame
# Columns: [record_id, report_month, city, service_type, cases_received, cases_resolved, resolution_days, satisfaction_score, digital_cases, in_person_cases, repeat_contacts, complaints_received, staff_hours, feedback]
# Index: []

# %% [markdown]
# ## Tutorial 3.5 reference 19 — Combine conditions with `&`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
result = df[  # Stores the calculated or supplied value for later use.
    (df["city"] == "Copenhagen") &  # Stores the calculated or supplied value for later use.
    (df["cases_received"] > 100)  # Runs this part of the documented analysis.
]  # Keeps this multi-line expression readable.

result  # Runs this part of the documented analysis.
# Out:
#       record_id report_month        city      service_type  cases_received  cases_resolved resolution_days  satisfaction_score  digital_cases  in_person_cases  repeat_contacts  complaints_received  staff_hours                                                                            feedback
# 0   SR2026-0001   2026-01-01  Copenhagen           Housing             130             116             8.0                 3.5             88               42               17                   10         87.8     The guidance was clear, but the supporting-document requirements caused delays.
# 1   SR2026-0002   2026-01-01  Copenhagen         Transport             124             110             5.1                 3.9             92               32               10                    8         54.7                  Several users asked for clearer information about service changes.
# ...

# %% [markdown]
# ## Tutorial 3.5 reference 20 — Why the parentheses matter
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
(df["city"] == "Copenhagen")  # Stores the calculated or supplied value for later use.
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# [Stored output shortened: showing 20 of 121 values. Colab displays the full result.]

# %% [markdown]
# ## Tutorial 3.5 reference 21 — Why the parentheses matter
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# (df["city"] == "Copenhagen") and (df["cases_received"] > 100)  # Stores the calculated or supplied value for later use.
print("Reference cell: run the website example manually to observe ValueError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe ValueError.

# %% [markdown]
# ## Tutorial 3.5 reference 22 — Combine alternatives with `|`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
result = df[  # Stores the calculated or supplied value for later use.
    (df["service_type"] == "Housing") |  # Stores the calculated or supplied value for later use.
    (df["service_type"] == "Transport")  # Stores the calculated or supplied value for later use.
]  # Keeps this multi-line expression readable.

# %% [markdown]
# ## Tutorial 3.5 reference 23 — Use `.isin()` for several allowed categories
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
result = df[  # Stores the calculated or supplied value for later use.
    df["service_type"].isin(["Housing", "Transport"])  # Runs this part of the documented analysis.
]  # Keeps this multi-line expression readable.

# %% [markdown]
# ## Example 3.5.4 — Filter and then choose columns
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
result = df.loc[  # Stores the calculated or supplied value for later use.
    df["cases_received"] > 100,  # Runs this part of the documented analysis.
    ["record_id", "city", "service_type", "cases_received"]  # Runs this part of the documented analysis.
]  # Keeps this multi-line expression readable.

result  # Runs this part of the documented analysis.
# Out:
#       record_id        city      service_type  cases_received
# 0   SR2026-0001  Copenhagen           Housing             130
# 1   SR2026-0002  Copenhagen         Transport             124
# 2   SR2026-0003  Copenhagen        Employment             105
# 3   SR2026-0004  Copenhagen             Waste             104
# 4   SR2026-0005  Copenhagen  Citizen Services             166
# 5   SR2026-0006      Aarhus           Housing             111
# 9   SR2026-0010      Aarhus  Citizen Services             123
# 10  SR2026-0011      Odense        Transport              107
# 14  SR2026-0015      Odense  Citizen Services             110
# 20  SR2026-0021  Copenhagen           Housing             157
# 21  SR2026-0022  Copenhagen         Transport             126
# 22  SR2026-0023  Copenhagen        Employment             120
# [Stored output shortened: showing 12 of 62 rows. Colab displays the full scrollable result.]

# %% [markdown]
# ## Tutorial 3.5 reference 25 — Filtering is an analytical decision
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
copenhagen = df[df["city"] == "Copenhagen"]  # Stores the calculated or supplied value for later use.

# %% [markdown]
# ## Tutorial 3.5 reference 26 — Broken code 1
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# df["City"]  # Runs this part of the documented analysis.
print("Reference cell: run the website example manually to observe KeyError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe KeyError.

# %% [markdown]
# ## Tutorial 3.5 reference 27 — Repair
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["city"]  # Runs this part of the documented analysis.
# Out:
# 0       Copenhagen
# 1       Copenhagen
# 2       Copenhagen
# 3       Copenhagen
# 4       Copenhagen
# 5           Aarhus
# 6      copenhagen
# 7           Aarhus
# 8           Aarhus
# 9           Aarhus
# 10          Odense
# 11          Odense
# 12          Odense
# 13          Odense
# 14          Odense
# 15         Aalborg
# 16         Aalborg
# 17         Aalborg
# 18         Aalborg
# 19         Aalborg
# [Stored output shortened: showing 20 of 121 values. Colab displays the full result.]

# %% [markdown]
# ## Tutorial 3.5 reference 28 — Broken code 2
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
# df[(df["city"] == "Copenhagen") and (df["cases_received"] > 100)]  # Stores the calculated or supplied value for later use.
print("Reference cell: run the website example manually to observe ValueError.")  # Explains why Run all continues safely.
# Out:
# Reference cell: run the website example manually to observe ValueError.

# %% [markdown]
# ## Tutorial 3.5 reference 29 — Repair
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df[  # Keeps this multi-line expression readable.
    (df["city"] == "Copenhagen") &  # Stores the calculated or supplied value for later use.
    (df["cases_received"] > 100)  # Runs this part of the documented analysis.
]  # Keeps this multi-line expression readable.
# Out:
#       record_id report_month        city      service_type  cases_received  cases_resolved resolution_days  satisfaction_score  digital_cases  in_person_cases  repeat_contacts  complaints_received  staff_hours                                                                            feedback
# 0   SR2026-0001   2026-01-01  Copenhagen           Housing             130             116             8.0                 3.5             88               42               17                   10         87.8     The guidance was clear, but the supporting-document requirements caused delays.
# 1   SR2026-0002   2026-01-01  Copenhagen         Transport             124             110             5.1                 3.9             92               32               10                    8         54.7                  Several users asked for clearer information about service changes.
# ...

# %% [markdown]
# # Tutorial 3.6
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.6 reference 1 — Inspect pandas dtypes
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(df.dtypes)  # Displays the result so it can be inspected.
# Out:
# record_id               object
# report_month            object
# city                    object
# service_type            object
# cases_received           int64
# cases_resolved           int64
# resolution_days         object
# satisfaction_score     float64
# digital_cases            int64
# in_person_cases          int64
# repeat_contacts          int64
# complaints_received      int64
# staff_hours            float64
# feedback                object
# dtype: object

# %% [markdown]
# ## Example 3.6.1 — Build a conceptual type table
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
conceptual_types = {  # Stores the calculated or supplied value for later use.
    "record_id": "identifier",  # Runs this part of the documented analysis.
    "report_month": "date-like",  # Runs this part of the documented analysis.
    "city": "categorical",  # Runs this part of the documented analysis.
    "service_type": "categorical",  # Runs this part of the documented analysis.
    "cases_received": "numeric count",  # Runs this part of the documented analysis.
    "cases_resolved": "numeric count",  # Runs this part of the documented analysis.
    "resolution_days": "numeric measure",  # Runs this part of the documented analysis.
    "satisfaction_score": "numeric rating",  # Runs this part of the documented analysis.
    "digital_cases": "numeric count",  # Runs this part of the documented analysis.
    "in_person_cases": "numeric count",  # Runs this part of the documented analysis.
    "repeat_contacts": "numeric count",  # Runs this part of the documented analysis.
    "complaints_received": "numeric count",  # Runs this part of the documented analysis.
    "staff_hours": "numeric measure",  # Runs this part of the documented analysis.
    "feedback": "free text"  # Runs this part of the documented analysis.
}  # Keeps this multi-line expression readable.

for column, role in conceptual_types.items():  # Starts a loop over the relevant values.
    print(column, "->", role)  # Displays the result so it can be inspected.
# Out:
# record_id -> identifier
# report_month -> date-like
# city -> categorical
# service_type -> categorical
# cases_received -> numeric count
# cases_resolved -> numeric count
# resolution_days -> numeric measure
# satisfaction_score -> numeric rating
# digital_cases -> numeric count
# in_person_cases -> numeric count
# repeat_contacts -> numeric count
# complaints_received -> numeric count
# staff_hours -> numeric measure
# feedback -> free text

# %% [markdown]
# ## Example 3.6.2 — Compare technical and conceptual types
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
for column in df.columns:  # Starts a loop over the relevant values.
    print(column, "| pandas dtype:", df[column].dtype)  # Displays the result so it can be inspected.
# Out:
# record_id | pandas dtype: object
# report_month | pandas dtype: object
# city | pandas dtype: object
# service_type | pandas dtype: object
# cases_received | pandas dtype: int64
# cases_resolved | pandas dtype: int64
# resolution_days | pandas dtype: object
# satisfaction_score | pandas dtype: float64
# digital_cases | pandas dtype: int64
# in_person_cases | pandas dtype: int64
# repeat_contacts | pandas dtype: int64
# complaints_received | pandas dtype: int64
# staff_hours | pandas dtype: float64
# feedback | pandas dtype: object

# %% [markdown]
# # Tutorial 3.7
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.7 reference 1 — `count()` — count non-missing values
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["cases_received"].count()  # Runs this part of the documented analysis.
# Out:
# 121

# %% [markdown]
# ## Tutorial 3.7 reference 2 — `count()` — count non-missing values
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["feedback"].count()  # Runs this part of the documented analysis.
# Out:
# 118

# %% [markdown]
# ## Tutorial 3.7 reference 3 — `count()` versus `len()`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print("Rows:", len(df))  # Displays the result so it can be inspected.
print("Non-missing feedback values:", df["feedback"].count())  # Displays the result so it can be inspected.
# Out:
# Rows: 121
# Non-missing feedback values: 118

# %% [markdown]
# ## Tutorial 3.7 reference 4 — `sum()` — total a numeric column
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
total_cases_received = df["cases_received"].sum()  # Stores the calculated or supplied value for later use.
print(total_cases_received)  # Displays the result so it can be inspected.
# Out:
# 12653

# %% [markdown]
# ## Tutorial 3.7 reference 5 — `mean()` — arithmetic average
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
mean_cases = df["cases_received"].mean()  # Stores the calculated or supplied value for later use.
print(mean_cases)  # Displays the result so it can be inspected.
# Out:
# 104.5702479338843

# %% [markdown]
# ## Tutorial 3.7 reference 6 — `median()` — middle value
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
median_cases = df["cases_received"].median()  # Stores the calculated or supplied value for later use.
print(median_cases)  # Displays the result so it can be inspected.
# Out:
# 102.0

# %% [markdown]
# ## Tutorial 3.7 reference 7 — `min()` and `max()`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print("Minimum:", df["cases_received"].min())  # Displays the result so it can be inspected.
print("Maximum:", df["cases_received"].max())  # Displays the result so it can be inspected.
# Out:
# Minimum: -4
# Maximum: 185

# %% [markdown]
# ## Tutorial 3.7 reference 8 — `std()` — standard deviation
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
std_cases = df["cases_received"].std()  # Stores the calculated or supplied value for later use.
print(round(std_cases, 2))  # Displays the result so it can be inspected.
# Out:
# 27.26

# %% [markdown]
# ## Tutorial 3.7 reference 9 — `describe()` — several summaries together
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["cases_received"].describe()  # Runs this part of the documented analysis.
# Out:
# count    121.000000
# mean     104.570248
# std       27.256750
# min       -4.000000
# 25%       86.000000
# 50%      102.000000
# 75%      122.000000
# max      185.000000
# Name: cases_received, dtype: float64

# %% [markdown]
# ## Tutorial 3.7 reference 10 — `round()` for readable output
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
mean_cases = df["cases_received"].mean()  # Stores the calculated or supplied value for later use.
print("Mean cases:", round(mean_cases, 2))  # Displays the result so it can be inspected.
# Out:
# Mean cases: 104.57

# %% [markdown]
# ## Example 3.7.1 — Received and resolved totals
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
total_received = df["cases_received"].sum()  # Stores the calculated or supplied value for later use.
total_resolved = df["cases_resolved"].sum()  # Stores the calculated or supplied value for later use.

print("Cases received:", total_received)  # Displays the result so it can be inspected.
print("Cases resolved:", total_resolved)  # Displays the result so it can be inspected.
# Out:
# Cases received: 12653
# Cases resolved: 11958

# %% [markdown]
# ## Tutorial 3.7 reference 12 — Find the row associated with an extreme value
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
max_index = df["cases_received"].idxmax()  # Stores the calculated or supplied value for later use.
df.loc[max_index]  # Runs this part of the documented analysis.
# Out:
# record_id                                                    SR2026-0045
# report_month                                                  2026-03-01
# city                                                          Copenhagen
# service_type                                            Citizen Services
# cases_received                                                       185
# cases_resolved                                                       174
# resolution_days                                                      2.6
# satisfaction_score                                                   4.2
# digital_cases                                                        154
# in_person_cases                                                       31
# repeat_contacts                                                       10
# complaints_received                                                    6
# staff_hours                                                         56.2
# ...

# %% [markdown]
# ## Tutorial 3.7 reference 13 — Find the row associated with an extreme value
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
min_index = df["cases_received"].idxmin()  # Stores the calculated or supplied value for later use.
df.loc[min_index]  # Runs this part of the documented analysis.
# Out:
# record_id                                                    SR2026-0054
# report_month                                                  2026-03-01
# city                                                              Odense
# service_type                                                       Waste
# cases_received                                                        -4
# cases_resolved                                                         0
# resolution_days                                                      3.0
# satisfaction_score                                                   4.1
# digital_cases                                                          0
# in_person_cases                                                        0
# repeat_contacts                                                        0
# complaints_received                                                    0
# staff_hours                                                         29.7
# ...

# %% [markdown]
# ## Example 3.7.2 — Inspect the negative minimum
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
min_index = df["cases_received"].idxmin()  # Stores the calculated or supplied value for later use.

print("Minimum row index:", min_index)  # Displays the result so it can be inspected.
display(df.loc[[min_index]])  # Displays the result so it can be inspected.
# Out:
# Minimum row index: 53
#       record_id  ...                                           feedback
# 53  SR2026-0054  ...  Helpful guidance, but some users reported dela...
#
# [1 rows x 14 columns]

# %% [markdown]
# ## Tutorial 3.7 reference 15 — Missing values and numerical calculations
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["satisfaction_score"].mean()  # Runs this part of the documented analysis.
# Out:
# 4.112820512820512

# %% [markdown]
# ## Tutorial 3.7 reference 16 — Missing values and numerical calculations
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print("Rows:", len(df))  # Displays the result so it can be inspected.
print("Available satisfaction scores:", df["satisfaction_score"].count())  # Displays the result so it can be inspected.
# Out:
# Rows: 121
# Available satisfaction scores: 117

# %% [markdown]
# ## Tutorial 3.7 reference 17 — Preliminary satisfaction mean
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
mean_satisfaction = df["satisfaction_score"].mean()  # Stores the calculated or supplied value for later use.
print(round(mean_satisfaction, 2))  # Displays the result so it can be inspected.
# Out:
# 4.11

# %% [markdown]
# # Tutorial 3.8
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.8 reference 1 — Column arithmetic
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
cases_received = 120  # Stores the calculated or supplied value for later use.
cases_resolved = 112  # Stores the calculated or supplied value for later use.
unresolved_cases = cases_received - cases_resolved  # Stores the calculated or supplied value for later use.

# %% [markdown]
# ## Tutorial 3.8 reference 2 — Column arithmetic
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["unresolved_cases"] = (  # Stores the calculated or supplied value for later use.
    df["cases_received"] - df["cases_resolved"]  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

# %% [markdown]
# ## Example 3.8.1 — Inspect the derived column
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["unresolved_cases"] = (  # Stores the calculated or supplied value for later use.
    df["cases_received"] - df["cases_resolved"]  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

display(  # Displays the result so it can be inspected.
    df[[  # Keeps this multi-line expression readable.
        "record_id",  # Runs this part of the documented analysis.
        "cases_received",  # Runs this part of the documented analysis.
        "cases_resolved",  # Runs this part of the documented analysis.
        "unresolved_cases"  # Runs this part of the documented analysis.
    ]].head(8)  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.
# Out:
#      record_id  cases_received  cases_resolved  unresolved_cases
# 0  SR2026-0001             130             116                14
# 1  SR2026-0002             124             110                14
# 2  SR2026-0003             105              93                12
# 3  SR2026-0004             104              94                10
# 4  SR2026-0005             166             152                14
# 5  SR2026-0006             111              96                15
# 6  SR2026-0007              95              88                 7
# 7  SR2026-0008              87              80                 7

# %% [markdown]
# ## Tutorial 3.8 reference 4 — Create a row-level resolution rate
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["resolution_rate"] = (  # Stores the calculated or supplied value for later use.
    df["cases_resolved"] /  # Runs this part of the documented analysis.
    df["cases_received"] * 100  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

# %% [markdown]
# ## Example 3.8.2 — Inspect the rate
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
display(  # Displays the result so it can be inspected.
    df[[  # Keeps this multi-line expression readable.
        "record_id",  # Runs this part of the documented analysis.
        "cases_received",  # Runs this part of the documented analysis.
        "cases_resolved",  # Runs this part of the documented analysis.
        "resolution_rate"  # Runs this part of the documented analysis.
    ]]  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.
# Out:
#       record_id  cases_received  cases_resolved  resolution_rate
# 0   SR2026-0001             130             116        89.230769
# 1   SR2026-0002             124             110        88.709677
# 2   SR2026-0003             105              93        88.571429
# 3   SR2026-0004             104              94        90.384615
# 4   SR2026-0005             166             152        91.566265
# 5   SR2026-0006             111              96        86.486486
# 6   SR2026-0007              95              88        92.631579
# 7   SR2026-0008              87              80        91.954023
# 8   SR2026-0009              97              89        91.752577
# 9   SR2026-0010             123             113        91.869919
# 10  SR2026-0011             107              92        85.981308
# 11  SR2026-0012              80              87       108.750000
# [Stored output shortened: showing 12 of 121 rows. Colab displays the full scrollable result.]

# %% [markdown]
# ## Tutorial 3.8 reference 6 — Method A — calculate each row's percentage, then average the percentages
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
mean_row_rate = df["resolution_rate"].mean()  # Stores the calculated or supplied value for later use.
print(round(mean_row_rate, 2))  # Displays the result so it can be inspected.
# Out:
# 93.66

# %% [markdown]
# ## Tutorial 3.8 reference 7 — Method B — divide total resolved by total received
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
overall_rate = (  # Stores the calculated or supplied value for later use.
    df["cases_resolved"].sum() /  # Runs this part of the documented analysis.
    df["cases_received"].sum() * 100  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

print(round(overall_rate, 2))  # Displays the result so it can be inspected.
# Out:
# 94.51

# %% [markdown]
# ## Tutorial 3.8 reference 8 — Percentage of rows with missing feedback
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["feedback"].isna()  # Runs this part of the documented analysis.
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# [Stored output shortened: showing 20 of 121 values. Colab displays the full result.]

# %% [markdown]
# ## Tutorial 3.8 reference 9 — Percentage of rows with missing feedback
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
missing_feedback = df["feedback"].isna().sum()  # Stores the calculated or supplied value for later use.
total_rows = len(df)  # Stores the calculated or supplied value for later use.

missing_feedback_pct = missing_feedback / total_rows * 100  # Stores the calculated or supplied value for later use.

print("Missing feedback rows:", missing_feedback)  # Displays the result so it can be inspected.
print("Missing feedback percentage:", round(missing_feedback_pct, 2))  # Displays the result so it can be inspected.
# Out:
# Missing feedback rows: 3
# Missing feedback percentage: 2.48

# %% [markdown]
# ## Tutorial 3.8 reference 10 — Percentage of rows belonging to a category
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
housing_rows = (df["service_type"] == "Housing").sum()  # Stores the calculated or supplied value for later use.
housing_pct = housing_rows / len(df) * 100  # Stores the calculated or supplied value for later use.

print("Housing rows:", housing_rows)  # Displays the result so it can be inspected.
print("Housing percentage:", round(housing_pct, 2))  # Displays the result so it can be inspected.
# Out:
# Housing rows: 21
# Housing percentage: 17.36

# %% [markdown]
# ## Example 3.8.3 — Create a clearly named percentage
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["resolved_pct_of_received"] = (  # Stores the calculated or supplied value for later use.
    df["cases_resolved"] /  # Runs this part of the documented analysis.
    df["cases_received"] * 100  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

# %% [markdown]
# # Tutorial 3.9
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.9 reference 1 — Inspect unique values before counting them
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(df["service_type"].unique())  # Displays the result so it can be inspected.
# Out:
# ['Housing' 'Transport' 'Employment' 'Waste' 'Citizen Services'
#  'Transport ' 'Citizen services' 'WASTE' 'Employment Services']

# %% [markdown]
# ## Tutorial 3.9 reference 2 — Inspect unique values before counting them
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(df["city"].unique())  # Displays the result so it can be inspected.
# Out:
# ['Copenhagen' 'Aarhus' ' copenhagen ' 'Odense' 'Aalborg' 'AALBORG'
#  'Odense ' 'aarhus' 'Koebenhavn']

# %% [markdown]
# ## Tutorial 3.9 reference 3 — Count distinct values with `nunique()`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["service_type"].nunique()  # Runs this part of the documented analysis.
# Out:
# 9

# %% [markdown]
# ## Tutorial 3.9 reference 4 — Frequency table with `value_counts()`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["service_type"].value_counts()  # Runs this part of the documented analysis.
# Out:
# service_type
# Transport              24
# Employment             24
# Waste                  24
# Citizen Services       24
# Housing                21
# Transport               1
# Citizen services        1
# WASTE                   1
# Employment Services     1
# Name: count, dtype: int64

# %% [markdown]
# ## Tutorial 3.9 reference 5 — Percentages with `normalize=True`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
service_pct = (  # Stores the calculated or supplied value for later use.
    df["service_type"]  # Runs this part of the documented analysis.
    .value_counts(normalize=True) * 100  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

print(service_pct.round(2))  # Displays the result so it can be inspected.
# Out:
# service_type
# Transport              19.83
# Employment             19.83
# Waste                  19.83
# Citizen Services       19.83
# Housing                17.36
# Transport               0.83
# Citizen services        0.83
# WASTE                   0.83
# Employment Services     0.83
# Name: proportion, dtype: float64

# %% [markdown]
# ## Tutorial 3.9 reference 6 — Include missing values when relevant
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["feedback"].value_counts(dropna=False)  # Stores the calculated or supplied value for later use.
# Out:
# feedback
# Helpful guidance, but some users reported delayed follow-up.                             9
# The issue was resolved quickly after the first contact.                                  7
# The response was fast and the information was useful.                                    7
# The response was quick, but route-change information was difficult to find online.       7
# The guidance was clear, but the supporting-document requirements caused delays.          6
# Friendly staff and a clear answer.                                                       6
# The digital form was convenient and staff explained the process clearly.                 6
# Fast response and useful guidance.                                                       5
# The online application was useful, but several steps were difficult to understand.       5
# Helpful staff explained the housing process, although the waiting time felt long.        5
# ...

# %% [markdown]
# ## Tutorial 3.9 reference 7 — Mode
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["service_type"].mode()  # Runs this part of the documented analysis.
# Out:
# 0    Citizen Services
# 1          Employment
# 2           Transport
# 3               Waste
# Name: service_type, dtype: object

# %% [markdown]
# ## Tutorial 3.9 reference 8 — Introductory `groupby()`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
mean_by_service = (  # Stores the calculated or supplied value for later use.
    df.groupby("service_type")["cases_received"]  # Runs this part of the documented analysis.
      .mean()  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

print(mean_by_service.round(2))  # Displays the result so it can be inspected.
# Out:
# service_type
# Citizen Services       129.92
# Citizen services        99.00
# Employment              88.04
# Employment Services     97.00
# Housing                115.86
# Transport              102.54
# Transport              107.00
# WASTE                   90.00
# Waste                   88.96
# Name: cases_received, dtype: float64

# %% [markdown]
# ## Tutorial 3.9 reference 9 — Group totals
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
total_by_service = (  # Stores the calculated or supplied value for later use.
    df.groupby("service_type")["cases_received"]  # Runs this part of the documented analysis.
      .sum()  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

print(total_by_service)  # Displays the result so it can be inspected.
# Out:
# service_type
# Citizen Services       3118
# Citizen services         99
# Employment             2113
# Employment Services      97
# Housing                2433
# Transport              2461
# Transport               107
# WASTE                    90
# Waste                  2135
# Name: cases_received, dtype: int64

# %% [markdown]
# ## Tutorial 3.9 reference 10 — Several calculations at once with `.agg()`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
summary = (  # Stores the calculated or supplied value for later use.
    df.groupby("service_type")["cases_received"]  # Runs this part of the documented analysis.
      .agg(["count", "sum", "mean", "median", "min", "max"])  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

print(summary.round(2))  # Displays the result so it can be inspected.
# Out:
#                      count   sum    mean  median  min  max
# service_type
# Citizen Services        24  3118  129.92   122.0   94  185
# Citizen services         1    99   99.00    99.0   99   99
# Employment              24  2113   88.04    86.5   62  129
# Employment Services      1    97   97.00    97.0   97   97
# Housing                 21  2433  115.86   113.0   86  157
# Transport               24  2461  102.54    98.5   75  144
# Transport                1   107  107.00   107.0  107  107
# WASTE                    1    90   90.00    90.0   90   90
# Waste                   24  2135   88.96    89.5   -4  138

# %% [markdown]
# ## Tutorial 3.9 reference 11 — Grouping by a dirty category can mislead
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
city_summary = (  # Stores the calculated or supplied value for later use.
    df.groupby("city")["cases_received"]  # Runs this part of the documented analysis.
      .agg(["count", "sum", "mean"])  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

print(city_summary.round(2))  # Displays the result so it can be inspected.
# Out:
#               count   sum    mean
# city
#  copenhagen       1    95   95.00
# AALBORG           1    76   76.00
# Aalborg          28  2386   85.21
# Aarhus           30  3349  111.63
# Copenhagen       29  3807  131.28
# Koebenhavn        1    76   76.00
# Odense           29  2642   91.10
# Odense            1    78   78.00
# aarhus            1   144  144.00

# %% [markdown]
# ## Tutorial 3.9 reference 12 — Cross-tabulation with `pd.crosstab()`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
service_by_city = pd.crosstab(  # Stores the calculated or supplied value for later use.
    df["city"],  # Runs this part of the documented analysis.
    df["service_type"]  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

service_by_city  # Runs this part of the documented analysis.
# Out:
# service_type  Citizen Services  Citizen services  ...  WASTE  Waste
# city                                              ...
#  copenhagen                  0                 0  ...      0      0
# AALBORG                      0                 0  ...      0      0
# Aalborg                      6                 1  ...      0      5
# Aarhus                       6                 0  ...      0      6
# Copenhagen                   6                 0  ...      0      6
# Koebenhavn                   0                 0  ...      0      1
# Odense                       6                 0  ...      1      6
# Odense                       0                 0  ...      0      0
# aarhus                       0                 0  ...      0      0
#
# [9 rows x 9 columns]

# %% [markdown]
# ## Tutorial 3.9 reference 13 — Percentage crosstab — optional extension
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
service_by_city_pct = pd.crosstab(  # Stores the calculated or supplied value for later use.
    df["city"],  # Runs this part of the documented analysis.
    df["service_type"],  # Runs this part of the documented analysis.
    normalize="index"  # Stores the calculated or supplied value for later use.
) * 100  # Runs this part of the documented analysis.

service_by_city_pct.round(1)  # Runs this part of the documented analysis.
# Out:
# service_type  Citizen Services  Citizen services  ...  WASTE  Waste
# city                                              ...
#  copenhagen                0.0               0.0  ...    0.0    0.0
# AALBORG                    0.0               0.0  ...    0.0    0.0
# Aalborg                   21.4               3.6  ...    0.0   17.9
# Aarhus                    20.0               0.0  ...    0.0   20.0
# Copenhagen                20.7               0.0  ...    0.0   20.7
# Koebenhavn                 0.0               0.0  ...    0.0  100.0
# Odense                    20.7               0.0  ...    3.4   20.7
# Odense                     0.0               0.0  ...    0.0    0.0
# aarhus                     0.0               0.0  ...    0.0    0.0
#
# [9 rows x 9 columns]

# %% [markdown]
# ## Example 3.9.1 — Compare satisfaction by service type
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
satisfaction_by_service = (  # Stores the calculated or supplied value for later use.
    df.groupby("service_type")["satisfaction_score"]  # Runs this part of the documented analysis.
      .agg(["count", "mean", "median", "min", "max"])  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

print(satisfaction_by_service.round(2))  # Displays the result so it can be inspected.
# Out:
#                      count  mean  median  min  max
# service_type
# Citizen Services        24  4.47     4.5  4.2  4.9
# Citizen services         1  3.90     3.9  3.9  3.9
# Employment              23  3.84     4.0  0.0  4.4
# Employment Services      1  4.20     4.2  4.2  4.2
# Housing                 20  3.67     3.7  3.5  3.9
# Transport               23  4.14     4.2  3.9  4.4
# Transport                1  3.50     3.5  3.5  3.5
# WASTE                    1  3.80     3.8  3.8  3.8
# Waste                   23  4.42     4.3  4.1  6.2

# %% [markdown]
# # Tutorial 3.10
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.10 reference 1 — Missing values with `isna()`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df.isna()  # Runs this part of the documented analysis.
# Out:
#     record_id  report_month   city  service_type  cases_received  cases_resolved  resolution_days  satisfaction_score  digital_cases  in_person_cases  repeat_contacts  complaints_received  staff_hours  feedback  unresolved_cases  resolution_rate  resolved_pct_of_received
# 0       False         False  False         False           False           False            False               False          False            False            False                False        False     False             False            False                     False
# 1       False         False  False         False           False           False            False               False          False            False            False                False        False     False             False            False                     False
# ...

# %% [markdown]
# ## Tutorial 3.10 reference 2 — Missing values with `isna()`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
missing_by_column = df.isna().sum()  # Stores the calculated or supplied value for later use.
print(missing_by_column)  # Displays the result so it can be inspected.
# Out:
# record_id                   0
# report_month                0
# city                        0
# service_type                0
# cases_received              0
# cases_resolved              0
# resolution_days             0
# satisfaction_score          4
# digital_cases               0
# in_person_cases             0
# repeat_contacts             0
# complaints_received         0
# staff_hours                 0
# feedback                    3
# unresolved_cases            0
# resolution_rate             0
# resolved_pct_of_received    0
# dtype: int64

# %% [markdown]
# ## Tutorial 3.10 reference 3 — Total recognised missing cells
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
total_missing = df.isna().sum().sum()  # Stores the calculated or supplied value for later use.
print(total_missing)  # Displays the result so it can be inspected.
# Out:
# 7

# %% [markdown]
# ## Tutorial 3.10 reference 4 — Missing percentages
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
missing_pct = df.isna().mean() * 100  # Stores the calculated or supplied value for later use.
print(missing_pct.round(2))  # Displays the result so it can be inspected.
# Out:
# record_id                   0.00
# report_month                0.00
# city                        0.00
# service_type                0.00
# cases_received              0.00
# cases_resolved              0.00
# resolution_days             0.00
# satisfaction_score          3.31
# digital_cases               0.00
# in_person_cases             0.00
# repeat_contacts             0.00
# complaints_received         0.00
# staff_hours                 0.00
# feedback                    2.48
# unresolved_cases            0.00
# resolution_rate             0.00
# resolved_pct_of_received    0.00
# dtype: float64

# %% [markdown]
# ## Tutorial 3.10 reference 5 — Missing satisfaction score
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
missing_satisfaction = df[df["satisfaction_score"].isna()]  # Stores the calculated or supplied value for later use.
display(missing_satisfaction)  # Displays the result so it can be inspected.
# Out:
#        record_id report_month  ... resolution_rate resolved_pct_of_received
# 21   SR2026-0022   2026-02-01  ...       93.650794                93.650794
# 48   SR2026-0049   2026-03-01  ...       92.660550                92.660550
# 87   SR2026-0088   2026-05-01  ...       96.969697                96.969697
# 110  SR2026-0111   2026-06-01  ...       94.680851                94.680851
#
# [4 rows x 17 columns]

# %% [markdown]
# ## Tutorial 3.10 reference 6 — Missing feedback
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
missing_feedback = df[df["feedback"].isna()]  # Stores the calculated or supplied value for later use.
display(missing_feedback)  # Displays the result so it can be inspected.
# Out:
#        record_id report_month  ... resolution_rate resolved_pct_of_received
# 17   SR2026-0018   2026-01-01  ...       88.571429                88.571429
# 75   SR2026-0076   2026-04-01  ...       91.666667                91.666667
# 117  SR2026-0118   2026-06-01  ...       98.484848                98.484848
#
# [3 rows x 17 columns]

# %% [markdown]
# ## Tutorial 3.10 reference 7 — Exact duplicate rows
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
duplicate_mask = df.duplicated()  # Stores the calculated or supplied value for later use.
print(duplicate_mask)  # Displays the result so it can be inspected.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 116    False
# 117    False
# 118    False
# 119    False
# 120     True
# Length: 121, dtype: bool

# %% [markdown]
# ## Tutorial 3.10 reference 8 — Exact duplicate rows
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print("Exact duplicate rows:", df.duplicated().sum())  # Displays the result so it can be inspected.
# Out:
# Exact duplicate rows: 1

# %% [markdown]
# ## Tutorial 3.10 reference 9 — Exact duplicate rows
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
display(df[df.duplicated()])  # Displays the result so it can be inspected.
# Out:
#        record_id report_month  ... resolution_rate resolved_pct_of_received
# 120  SR2026-0027   2026-02-01  ...       92.727273                92.727273
#
# [1 rows x 17 columns]

# %% [markdown]
# ## Tutorial 3.10 reference 10 — Why only one duplicate is counted
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
display(df[df.duplicated(keep=False)])  # Displays the result so it can be inspected.
# Out:
#        record_id report_month  ... resolution_rate resolved_pct_of_received
# 26   SR2026-0027   2026-02-01  ...       92.727273                92.727273
# 120  SR2026-0027   2026-02-01  ...       92.727273                92.727273
#
# [2 rows x 17 columns]

# %% [markdown]
# ## Tutorial 3.10 reference 11 — Duplicate identifiers are not the same as duplicate rows
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
id_duplicates = df["record_id"].duplicated(keep=False)  # Stores the calculated or supplied value for later use.

display(  # Displays the result so it can be inspected.
    df.loc[  # Keeps this multi-line expression readable.
        id_duplicates,  # Runs this part of the documented analysis.
        ["record_id", "report_month", "city", "service_type"]  # Runs this part of the documented analysis.
    ]  # Keeps this multi-line expression readable.
)  # Keeps this multi-line expression readable.
# Out:
#        record_id report_month     city      service_type
# 26   SR2026-0027   2026-02-01   Aarhus         Transport
# 78   SR2026-0079   2026-04-01  Aalborg             Waste
# 79   SR2026-0079   2026-04-01  Aalborg  Citizen Services
# 120  SR2026-0027   2026-02-01   Aarhus         Transport

# %% [markdown]
# ## Tutorial 3.10 reference 12 — Category consistency
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(df["city"].value_counts(dropna=False))  # Displays the result so it can be inspected.
# Out:
# city
# Aarhus          30
# Copenhagen      29
# Odense          29
# Aalborg         28
#  copenhagen      1
# AALBORG          1
# Odense           1
# aarhus           1
# Koebenhavn       1
# Name: count, dtype: int64

# %% [markdown]
# ## Tutorial 3.10 reference 13 — Negative case counts
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
negative_received = df[df["cases_received"] < 0]  # Stores the calculated or supplied value for later use.
display(negative_received)  # Displays the result so it can be inspected.
# Out:
#       record_id report_month  ... resolution_rate resolved_pct_of_received
# 53  SR2026-0054   2026-03-01  ...            -0.0                     -0.0
#
# [1 rows x 17 columns]

# %% [markdown]
# ## Tutorial 3.10 reference 14 — Out-of-range satisfaction
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
out_of_range_satisfaction = df[  # Stores the calculated or supplied value for later use.
    (df["satisfaction_score"] < 1) |  # Runs this part of the documented analysis.
    (df["satisfaction_score"] > 5)  # Runs this part of the documented analysis.
]  # Keeps this multi-line expression readable.

display(out_of_range_satisfaction)  # Displays the result so it can be inspected.
# Out:
#       record_id report_month  ... resolution_rate resolved_pct_of_received
# 38  SR2026-0039   2026-02-01  ...       90.277778                90.277778
# 72  SR2026-0073   2026-04-01  ...       96.103896                96.103896
#
# [2 rows x 17 columns]

# %% [markdown]
# ## Tutorial 3.10 reference 15 — Resolved greater than received
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
resolved_gt_received = df[  # Stores the calculated or supplied value for later use.
    df["cases_resolved"] > df["cases_received"]  # Runs this part of the documented analysis.
]  # Keeps this multi-line expression readable.

display(  # Displays the result so it can be inspected.
    resolved_gt_received[[  # Keeps this multi-line expression readable.
        "record_id",  # Runs this part of the documented analysis.
        "cases_received",  # Runs this part of the documented analysis.
        "cases_resolved"  # Runs this part of the documented analysis.
    ]]  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.
# Out:
#       record_id  cases_received  cases_resolved
# 11  SR2026-0012              80              87
# 53  SR2026-0054              -4               0
# 89  SR2026-0090             159             162

# %% [markdown]
# ## Tutorial 3.10 reference 16 — Detect a numeric-looking column containing text
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(df["resolution_days"].unique())  # Displays the result so it can be inspected.
# Out:
# ['8.0' '5.1' '5.5' '4.9' '3.1' '7.5' '2.7' '3.0' '6.8' '4.2' '4.4'
#  'unknown' '3.5' '5.4' '2.8' '7.3' '4.8' '6.1' '3.8' '2.9' '7.2' '3.9'
#  '2.6' '4.6' '2.3' '6.5' '1.8' '5.2' '5.3' '6.9' '2.5' '4.0' '5.7' '1.5'
#  '2.2' '1.4' '24.7' '4.5' '3.4' '1.7' '6.4' '5.6' '1.9' '7.7' '7.0' '3.6'
#  '7.4' '5.0' '2.4' '2.1' '7.9' '4.7' '3.2' '3.7' '5.9']

# %% [markdown]
# ## Tutorial 3.10 reference 17 — Detect a numeric-looking column containing text
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
resolution_numeric_preview = pd.to_numeric(  # Stores the calculated or supplied value for later use.
    df["resolution_days"],  # Runs this part of the documented analysis.
    errors="coerce"  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

# %% [markdown]
# ## Tutorial 3.10 reference 18 — Detect a numeric-looking column containing text
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
conversion_problem = (  # Stores the calculated or supplied value for later use.
    df["resolution_days"].notna() &  # Runs this part of the documented analysis.
    resolution_numeric_preview.isna()  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

display(  # Displays the result so it can be inspected.
    df.loc[  # Keeps this multi-line expression readable.
        conversion_problem,  # Runs this part of the documented analysis.
        ["record_id", "resolution_days"]  # Runs this part of the documented analysis.
    ]  # Keeps this multi-line expression readable.
)  # Keeps this multi-line expression readable.
# Out:
#        record_id resolution_days
# 14   SR2026-0015         unknown
# 66   SR2026-0067         unknown
# 102  SR2026-0103         unknown

# %% [markdown]
# ## Tutorial 3.10 reference 19 — Important
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["resolution_days"]  # Runs this part of the documented analysis.
# Out:
# 0         8.0
# 1         5.1
# 2         5.5
# 3         4.9
# 4         3.1
# 5         7.5
# 6         5.1
# 7         5.5
# 8         2.7
# 9         3.0
# 10        6.8
# 11        4.2
# 12        4.4
# 13        3.0
# 14    unknown
# 15        6.8
# 16        3.5
# 17        5.4
# 18        3.5
# 19        2.8
# [Stored output shortened: showing 20 of 121 values. Colab displays the full result.]

# %% [markdown]
# ## Tutorial 3.10 reference 20 — Detect invalid date-like values without overwriting the raw column
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
report_month_preview = pd.to_datetime(  # Stores the calculated or supplied value for later use.
    df["report_month"],  # Runs this part of the documented analysis.
    errors="coerce"  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

# %% [markdown]
# ## Tutorial 3.10 reference 21 — Detect invalid date-like values without overwriting the raw column
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
invalid_date_mask = report_month_preview.isna()  # Stores the calculated or supplied value for later use.

display(  # Displays the result so it can be inspected.
    df.loc[  # Keeps this multi-line expression readable.
        invalid_date_mask,  # Runs this part of the documented analysis.
        ["record_id", "report_month"]  # Runs this part of the documented analysis.
    ]  # Keeps this multi-line expression readable.
)  # Keeps this multi-line expression readable.
# Out:
#       record_id report_month
# 43  SR2026-0044   2026-13-01

# %% [markdown]
# ## Tutorial 3.10 reference 22 — Build a first data-quality summary
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
quality_summary = {  # Stores the calculated or supplied value for later use.
    "rows": len(df),  # Runs this part of the documented analysis.
    "columns": df.shape[1],  # Runs this part of the documented analysis.
    "missing_cells": int(df.isna().sum().sum()),  # Runs this part of the documented analysis.
    "exact_duplicate_rows": int(df.duplicated().sum()),  # Runs this part of the documented analysis.
    "negative_cases_received": int((df["cases_received"] < 0).sum()),  # Runs this part of the documented analysis.
    "out_of_range_satisfaction": int(  # Keeps this multi-line expression readable.
        ((df["satisfaction_score"] < 1) |  # Runs this part of the documented analysis.
         (df["satisfaction_score"] > 5)).sum()  # Runs this part of the documented analysis.
    )  # Keeps this multi-line expression readable.
}  # Keeps this multi-line expression readable.

for check, value in quality_summary.items():  # Starts a loop over the relevant values.
    print(check, ":", value)  # Displays the result so it can be inspected.
# Out:
# rows : 121
# columns : 17
# missing_cells : 7
# exact_duplicate_rows : 1
# negative_cases_received : 1
# out_of_range_satisfaction : 2

# %% [markdown]
# # Tutorial 3.11
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.11 reference 1 — Start by reading the text
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
display(df[["record_id", "feedback"]].head(10))  # Displays the result so it can be inspected.
# Out:
#      record_id                                           feedback
# 0  SR2026-0001  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  Several users asked for clearer information ab...
# 2  SR2026-0003  Useful advice and a friendly response from staff.
# 3  SR2026-0004  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  The response was fast and the information was ...
# 5  SR2026-0006  Helpful staff explained the housing process, a...
# 6  SR2026-0007  Several users asked for clearer information ab...
# 7  SR2026-0008  The answer was useful, although the waiting ti...
# 8  SR2026-0009  Collection information was easy to understand ...
# 9  SR2026-0010                 Friendly staff and a clear answer.

# %% [markdown]
# ## Tutorial 3.11 reference 2 — Start by reading the text
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
feedback_non_missing = df["feedback"].dropna()  # Stores the calculated or supplied value for later use.

display(  # Displays the result so it can be inspected.
    feedback_non_missing.sample(  # Keeps this multi-line expression readable.
        min(8, len(feedback_non_missing)),  # Runs this part of the documented analysis.
        random_state=42  # Stores the calculated or supplied value for later use.
    )  # Keeps this multi-line expression readable.
)  # Keeps this multi-line expression readable.
# Out:
# 57     The answer was useful, although the waiting ti...
# 91                    Fast response and useful guidance.
# 4      The response was fast and the information was ...
# 46     The response was quick, but route-change infor...
# 27     The guidance was clear but the process require...
# 119    The response was fast and the information was ...
# 70     The answer solved the problem, but repeated co...
# 10     The online application was useful, but several...
# Name: feedback, dtype: object

# %% [markdown]
# ## Tutorial 3.11 reference 3 — Count available text responses
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print("Rows:", len(df))  # Displays the result so it can be inspected.
print("Non-missing feedback:", df["feedback"].count())  # Displays the result so it can be inspected.
# Out:
# Rows: 121
# Non-missing feedback: 118

# %% [markdown]
# ## Tutorial 3.11 reference 4 — Character length
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
feedback_length = df["feedback"].str.len()  # Stores the calculated or supplied value for later use.
print(feedback_length)  # Displays the result so it can be inspected.
# Out:
# 0      79.0
# 1      66.0
# 2      49.0
# 3      60.0
# 4      53.0
#        ...
# 116    72.0
# 117     NaN
# 118    73.0
# 119    53.0
# 120    72.0
# Name: feedback, Length: 121, dtype: float64

# %% [markdown]
# ## Tutorial 3.11 reference 5 — Character length
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(round(feedback_length.mean(), 2))  # Displays the result so it can be inspected.
# Out:
# 63.78

# %% [markdown]
# ## Tutorial 3.11 reference 6 — Approximate word count with pandas string methods
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
word_count = df["feedback"].str.split().str.len()  # Stores the calculated or supplied value for later use.
print(word_count)  # Displays the result so it can be inspected.
# Out:
# 0      10.0
# 1       9.0
# 2       8.0
# 3       8.0
# 4       9.0
#        ...
# 116    10.0
# 117     NaN
# 118    11.0
# 119     9.0
# 120    10.0
# Name: feedback, Length: 121, dtype: float64

# %% [markdown]
# ## Tutorial 3.11 reference 7 — Search for a literal word with `.str.contains()`
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
helpful_mask = df["feedback"].str.contains(  # Stores the calculated or supplied value for later use.
    "helpful",  # Runs this part of the documented analysis.
    case=False,  # Stores the calculated or supplied value for later use.
    na=False  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

# %% [markdown]
# ## Tutorial 3.11 reference 8 — Explain each argument
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(helpful_mask.sum())  # Displays the result so it can be inspected.
# Out:
# 36

# %% [markdown]
# ## Tutorial 3.11 reference 9 — Explain each argument
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
display(  # Displays the result so it can be inspected.
    df.loc[  # Keeps this multi-line expression readable.
        helpful_mask,  # Runs this part of the documented analysis.
        ["record_id", "service_type", "satisfaction_score", "feedback"]  # Runs this part of the documented analysis.
    ]  # Keeps this multi-line expression readable.
)  # Keeps this multi-line expression readable.
# Out:
#       record_id      service_type  satisfaction_score                                                                               feedback
# 3   SR2026-0004             Waste                 4.2                           Helpful guidance, but some users reported delayed follow-up.
# 5   SR2026-0006           Housing                 3.6      Helpful staff explained the housing process, although the waiting time felt long.
# 13  SR2026-0014             Waste                 4.5                           Helpful guidance, but some users reported delayed follow-up.
# 20  SR2026-0021           Housing                 3.6      Helpful staff explained the housing process, although the waiting time felt long.
# 21  SR2026-0022         Transport                 NaN                    Clear information and a helpful answer about the transport service.
# ...

# %% [markdown]
# ## Tutorial 3.11 reference 10 — Search for alternatives with a simple pattern
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
wait_mask = df["feedback"].str.contains(  # Stores the calculated or supplied value for later use.
    "wait|long",  # Runs this part of the documented analysis.
    case=False,  # Stores the calculated or supplied value for later use.
    na=False,  # Stores the calculated or supplied value for later use.
    regex=True  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

# %% [markdown]
# ## Tutorial 3.11 reference 11 — Search for alternatives with a simple pattern
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(wait_mask.sum())  # Displays the result so it can be inspected.
# Out:
# 11

# %% [markdown]
# ## Tutorial 3.11 reference 12 — Search for alternatives with a simple pattern
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
display(  # Displays the result so it can be inspected.
    df.loc[  # Keeps this multi-line expression readable.
        wait_mask,  # Runs this part of the documented analysis.
        ["record_id", "feedback", "satisfaction_score"]  # Runs this part of the documented analysis.
    ]  # Keeps this multi-line expression readable.
)  # Keeps this multi-line expression readable.
# Out:
#        record_id  ... satisfaction_score
# 5    SR2026-0006  ...                3.6
# 7    SR2026-0008  ...                3.9
# 20   SR2026-0021  ...                3.6
# 22   SR2026-0023  ...                3.9
# 25   SR2026-0026  ...                3.6
# 30   SR2026-0031  ...                3.6
# 37   SR2026-0038  ...                4.0
# 55   SR2026-0056  ...                3.7
# 57   SR2026-0058  ...                4.0
# 72   SR2026-0073  ...                0.0
# 110  SR2026-0111  ...                NaN
#
# [11 rows x 3 columns]

# %% [markdown]
# ## Tutorial 3.11 reference 13 — Search for clarity-related wording
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
clear_mask = df["feedback"].str.contains(  # Stores the calculated or supplied value for later use.
    "clear",  # Runs this part of the documented analysis.
    case=False,  # Stores the calculated or supplied value for later use.
    na=False  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

print(clear_mask.sum())  # Displays the result so it can be inspected.
# Out:
# 40

# %% [markdown]
# ## Tutorial 3.11 reference 14 — Search for speed-related wording
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
speed_mask = df["feedback"].str.contains(  # Stores the calculated or supplied value for later use.
    "quick|fast",  # Runs this part of the documented analysis.
    case=False,  # Stores the calculated or supplied value for later use.
    na=False,  # Stores the calculated or supplied value for later use.
    regex=True  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

print(speed_mask.sum())  # Displays the result so it can be inspected.
# Out:
# 32

# %% [markdown]
# ## Tutorial 3.11 reference 15 — Literal versus regex search
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["feedback"].str.contains(  # Keeps this multi-line expression readable.
    "some literal text",  # Runs this part of the documented analysis.
    case=False,  # Stores the calculated or supplied value for later use.
    na=False,  # Stores the calculated or supplied value for later use.
    regex=False  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# [Stored output shortened: showing 20 of 121 values. Colab displays the full result.]

# %% [markdown]
# ## Tutorial 3.11 reference 16 — Compare text presence with a numeric variable
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
display(  # Displays the result so it can be inspected.
    df.loc[  # Keeps this multi-line expression readable.
        wait_mask,  # Runs this part of the documented analysis.
        ["feedback", "satisfaction_score"]  # Runs this part of the documented analysis.
    ]  # Keeps this multi-line expression readable.
)  # Keeps this multi-line expression readable.
# Out:
#                                               feedback  satisfaction_score
# 5    Helpful staff explained the housing process, a...                 3.6
# 7    The answer was useful, although the waiting ti...                 3.9
# 20   Helpful staff explained the housing process, a...                 3.6
# 22   The answer was useful, although the waiting ti...                 3.9
# 25   Helpful staff explained the housing process, a...                 3.6
# 30   The wait was not long, and the final response ...                 3.6
# 37   The answer was useful, although the waiting ti...                 4.0
# 55   Helpful staff explained the housing process, a...                 3.7
# 57   The answer was useful, although the waiting ti...                 4.0
# 72   The answer was useful, although the waiting ti...                 0.0
# 110  Helpful staff explained the housing process, a...                 NaN

# %% [markdown]
# ## Example 3.11.1 — Text length by service type
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["feedback_word_count_preview"] = (  # Stores the calculated or supplied value for later use.
    df["feedback"].str.split().str.len()  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

# %% [markdown]
# ## Example 3.11.1 — Text length by service type
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(  # Displays the result so it can be inspected.
    df.groupby("service_type")["feedback_word_count_preview"]  # Runs this part of the documented analysis.
      .mean()  # Runs this part of the documented analysis.
      .round(2)  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.
# Out:
# service_type
# Citizen Services        8.67
# Citizen services        9.00
# Employment              9.82
# Employment Services    10.00
# Housing                11.10
# Transport               9.38
# Transport              12.00
# WASTE                  14.00
# Waste                   8.71
# Name: feedback_word_count_preview, dtype: float64

# %% [markdown]
# ## Example 3.11.2 — Identify potentially difficult experiences
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
difficulty_mask = df["feedback"].str.contains(  # Stores the calculated or supplied value for later use.
    "difficult|confusing",  # Runs this part of the documented analysis.
    case=False,  # Stores the calculated or supplied value for later use.
    na=False,  # Stores the calculated or supplied value for later use.
    regex=True  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

print("Matches:", difficulty_mask.sum())  # Displays the result so it can be inspected.

display(  # Displays the result so it can be inspected.
    df.loc[  # Keeps this multi-line expression readable.
        difficulty_mask,  # Runs this part of the documented analysis.
        ["record_id", "service_type", "feedback", "satisfaction_score"]  # Runs this part of the documented analysis.
    ]  # Keeps this multi-line expression readable.
)  # Keeps this multi-line expression readable.
# Out:
# Matches: 19
#       record_id      service_type                                                                            feedback  satisfaction_score
# 10  SR2026-0011        Transport   The online application was useful, but several steps were difficult to understand.                 3.5
# 11  SR2026-0012         Transport  The response was quick, but route-change information was difficult to find online.                 4.3
# 16  SR2026-0017         Transport            The digital form worked well, although some instructions were confusing.                 4.1
# 23  SR2026-0024             Waste                             Some users found the collection instructions confusing.                 4.1
# 26  SR2026-0027         Transport            The digital form worked well, although some instructions were confusing.                 4.2
# 40  SR2026-0041           Housing  The online application was useful, but several steps were difficult to understand.                 3.7
# ...

# %% [markdown]
# # Tutorial 3.12
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# ## Tutorial 3.12 reference 1 — From an idea to an operational rule
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["mentions_wait"] = df["feedback"].str.contains(  # Stores the calculated or supplied value for later use.
    "wait|long",  # Runs this part of the documented analysis.
    case=False,  # Stores the calculated or supplied value for later use.
    na=False,  # Stores the calculated or supplied value for later use.
    regex=True  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

# %% [markdown]
# ## Tutorial 3.12 reference 2 — Count the indicator
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(df["mentions_wait"].value_counts())  # Displays the result so it can be inspected.
# Out:
# mentions_wait
# False    110
# True      11
# Name: count, dtype: int64

# %% [markdown]
# ## Tutorial 3.12 reference 3 — Count the indicator
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
print(df["mentions_wait"].sum())  # Displays the result so it can be inspected.
# Out:
# 11

# %% [markdown]
# ## Tutorial 3.12 reference 4 — Create several transparent indicators
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["mentions_helpful"] = df["feedback"].str.contains(  # Stores the calculated or supplied value for later use.
    "helpful",  # Runs this part of the documented analysis.
    case=False,  # Stores the calculated or supplied value for later use.
    na=False  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

df["mentions_clarity"] = df["feedback"].str.contains(  # Stores the calculated or supplied value for later use.
    "clear",  # Runs this part of the documented analysis.
    case=False,  # Stores the calculated or supplied value for later use.
    na=False  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

df["mentions_difficulty"] = df["feedback"].str.contains(  # Stores the calculated or supplied value for later use.
    "difficult|confusing",  # Runs this part of the documented analysis.
    case=False,  # Stores the calculated or supplied value for later use.
    na=False,  # Stores the calculated or supplied value for later use.
    regex=True  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

# %% [markdown]
# ## Tutorial 3.12 reference 5 — Inspect the rule against the original text
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
display(  # Displays the result so it can be inspected.
    df[[  # Keeps this multi-line expression readable.
        "feedback",  # Runs this part of the documented analysis.
        "mentions_wait",  # Runs this part of the documented analysis.
        "mentions_helpful",  # Runs this part of the documented analysis.
        "mentions_clarity",  # Runs this part of the documented analysis.
        "mentions_difficulty"  # Runs this part of the documented analysis.
    ]]  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.
# Out:
#                                                                               feedback  mentions_wait  mentions_helpful  mentions_clarity  mentions_difficulty
# 0      The guidance was clear, but the supporting-document requirements caused delays.          False             False              True                False
# 1                   Several users asked for clearer information about service changes.          False             False              True                False
# 2                                    Useful advice and a friendly response from staff.          False             False             False                False
# 3                         Helpful guidance, but some users reported delayed follow-up.          False              True             False                False
# 4                                The response was fast and the information was useful.          False             False             False                False
# ...

# %% [markdown]
# ## Example 3.12.1 — Satisfaction by waiting mention
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
wait_satisfaction = (  # Stores the calculated or supplied value for later use.
    df.groupby("mentions_wait")["satisfaction_score"]  # Runs this part of the documented analysis.
      .agg(["count", "mean", "median", "min", "max"])  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

print(wait_satisfaction.round(2))  # Displays the result so it can be inspected.
# Out:
#                count  mean  median  min  max
# mentions_wait
# False            107  4.18    4.20  3.5  6.2
# True              10  3.39    3.65  0.0  4.0

# %% [markdown]
# ## Tutorial 3.12 reference 7 — Compare indicator counts across service types
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
wait_by_service = (  # Stores the calculated or supplied value for later use.
    df.groupby("service_type")["mentions_wait"]  # Runs this part of the documented analysis.
      .sum()  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.

print(wait_by_service)  # Displays the result so it can be inspected.
# Out:
# service_type
# Citizen Services       0
# Citizen services       0
# Employment             5
# Employment Services    0
# Housing                6
# Transport              0
# Transport              0
# WASTE                  0
# Waste                  0
# Name: mentions_wait, dtype: int64

# %% [markdown]
# ## Tutorial 3.12 reference 8 — Cross-tabulate a code and category
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
pd.crosstab(  # Keeps this multi-line expression readable.
    df["service_type"],  # Runs this part of the documented analysis.
    df["mentions_wait"]  # Runs this part of the documented analysis.
)  # Keeps this multi-line expression readable.
# Out:
# mentions_wait        False  True
# service_type
# Citizen Services        24      0
# Citizen services         1      0
# Employment              19      5
# Employment Services      1      0
# Housing                 15      6
# Transport               24      0
# Transport                1      0
# WASTE                    1      0
# Waste                   24      0

# %% [markdown]
# ## Example 3.12.2 — A transparent code is better than a vague label
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["negative"] = ...  # Stores the calculated or supplied value for later use.

# %% [markdown]
# ## Example 3.12.2 — A transparent code is better than a vague label
#
# Run this cell after the setup cell. If it is an intentional debugging example, Run all converts it into a safe reference message so later examples still run.

# %%
df["mentions_wait_or_long"] = df["feedback"].str.contains(  # Stores the calculated or supplied value for later use.
    "wait|long",  # Runs this part of the documented analysis.
    case=False,  # Stores the calculated or supplied value for later use.
    na=False,  # Stores the calculated or supplied value for later use.
    regex=True  # Stores the calculated or supplied value for later use.
)  # Keeps this multi-line expression readable.

# %% [markdown]
# # Tutorial 3.13
#
# The following cells retain the website order. Read the heading and explanation on the website before running or modifying a reference cell.

# %% [markdown]
# # Checks and next steps
#
# This notebook contains **161 website Python blocks** from Tutorials 3.1–3.13, plus the shared setup cell. Compare results with the website checkpoints, change one value at a time, and use the Exercises notebook before opening its solution section. Tutorial 3.14 is kept in the separate Applied Activities notebook.
