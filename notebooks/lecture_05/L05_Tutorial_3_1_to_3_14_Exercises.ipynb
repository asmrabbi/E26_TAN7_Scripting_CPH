# %% [markdown]
# # Lecture 5 — Tutorials 3.1–3.13 Exercises
#
# **Goal.** Attempt all 33 numbered website exercises before opening the clearly separated solution section.
#
# This notebook matches the numbered Lecture 5 website tutorials. The dataset is synthetic, contains deliberate quality problems and must not be interpreted as evidence about real cities or services.
#
# **Local setup.** Google Colab includes pandas. On a local machine, run `python -m pip install -r requirements.txt` from the repository, or install pandas with `python -m pip install "pandas>=2.0"`.

# %% [markdown]
# ## Setup
#
# Run this cell first. It loads the versioned raw CSV from GitHub and checks the expected 121 × 14 structure. Keep the raw data unchanged during Lecture 5.

# %%
import pandas as pd  # Loads the library feature used by this step.
data_url = "https://raw.githubusercontent.com/asmrabbi/E26_TAN7_Scripting_CPH/main/data/E26_TAN7_service_experience_raw.csv"  # Stores the calculated or supplied value for later use.
df = pd.read_csv(data_url)  # Stores the calculated or supplied value for later use.
print("Dataset shape:", df.shape)  # Displays the result so it can be inspected.
assert df.shape == (121, 14), "The wrong dataset version was loaded."  # Stores the calculated or supplied value for later use.
display(df.head())  # Displays the result so it can be inspected.
# Out:
# Dataset shape: (121, 14)
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
#
# [5 rows x 14 columns]

# %% [markdown]
# # Student exercises
#
# Work in website order. Write explanations in Markdown cells and code in the starter cells. Do not scroll to the solution divider until you have made an attempt.

# %% [markdown]
# ## Exercise 3.1.1 — Describe a dataset before coding
#
# A fictional dataset contains these columns:
#
# ```text
# organisation_id, year, sector, employees, energy_use_kwh, sustainability_comment
# ```
#
# Answer without writing Python:
#
# 1. What might one row represent?
# 2. Which columns look numeric?
# 3. Which column looks like an identifier?
# 4. Which column contains free text?
# 5. What information would you need before interpreting `energy_use_kwh`?
# 6. Why would the number of rows not necessarily equal the number of organisations?

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.2.1 — Find the structural problem
#
# Consider:
#
# ```csv
# id;city;score
# 1;Copenhagen;4.2
# 2;Aalborg;3.9
# ```
#
# A student runs:
#
# ```python
# df = pd.read_csv("scores.csv")
# ```
#
# and gets one column instead of three.
#
# 1. What is the likely problem?
# 2. What argument should the student investigate?
# 3. Why should they inspect the file before changing the code?

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.2.2 — Missing does not mean zero
#
# Explain why these two values should not automatically be treated as equivalent:
#
# ```text
# cases_received = 0
# cases_received = blank
# ```

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.3.1 — Load and verify
#
# 1. Import pandas as `pd`.
# 2. Load the course CSV from the raw GitHub URL.
# 3. Display the first five rows.
# 4. Store the DataFrame in a variable called `df`.
# 5. Use `type(df)` and explain the result.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.3.2 — Explain the file/DataFrame distinction
#
# A student says:
#
# > “I changed a value in `df`, so I have permanently changed the original CSV on GitHub.”
#
# Explain why this is normally false.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.4.1 — Produce an inspection note
#
# Using the course DataFrame, write code that reports:
#
# 1. number of rows;
# 2. number of columns;
# 3. all column names;
# 4. first three rows;
# 5. last three rows;
# 6. technical dtypes;
# 7. `df.info()`.
#
# Then write three sentences describing what you learned **without making claims about real service performance**.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.4.2 — Why inspect beyond the first five rows?
#
# Explain two reasons why `df.head()` alone is not enough for data-quality assessment.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.5.1 — Column selection
#
# Write code to display only:
#
# - `record_id`;
# - `service_type`;
# - `satisfaction_score`;
# - `feedback`.
#
# Then explain whether the result is a Series or DataFrame.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.5.2 — Filter a numeric condition
#
# Find rows where `cases_received` is at least 100.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.5.3 — Combine a category and numeric condition
#
# Find Transport records with more than 90 cases received. Display only:
#
# - `record_id`;
# - `city`;
# - `cases_received`.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.6.1 — Classify the course variables
#
# Create a table with these columns:
#
# ```text
# variable | conceptual_type | expected_values_or_unit | possible_quality_question
# ```
#
# Complete it for all fourteen variables.
#
# Do not copy `df.dtypes` as the conceptual type.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.6.2 — Explain why this statement is wrong
#
# > “`record_id` is an integer, so calculating its average is useful.”

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.7.1 — Produce a numeric summary
#
# For `cases_resolved`, calculate:
#
# 1. count;
# 2. sum;
# 3. mean;
# 4. median;
# 5. minimum;
# 6. maximum;
# 7. standard deviation;
# 8. `describe()`.
#
# Then write two observations and one quality question.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.7.2 — Mean or median?
#
# Calculate the mean and median of `cases_received`. Explain:
#
# 1. why they differ;
# 2. why the negative raw value matters;
# 3. why neither statistic alone tells you whether the dataset is reliable.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.7.3 — Count the denominator explicitly
#
# Calculate the mean satisfaction score and also print how many non-missing satisfaction scores contributed to the calculation.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.8.1 — Derive a difference
#
# Create:
#
# ```text
# case_gap = cases_received - cases_resolved
# ```
#
# Then:
#
# 1. show the five smallest values;
# 2. identify any negative results;
# 3. explain why a negative result requires investigation.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.8.2 — Explain two rate formulas
#
# Write code for:
#
# 1. the mean of row-level resolution percentages;
# 2. total resolved divided by total received.
#
# Then explain in ordinary language why they differ.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.8.3 — Calculate a missing percentage
#
# Calculate the percentage of missing values in `satisfaction_score` using:
#
# ```text
# missing count / total rows × 100
# ```
#
# Expected raw-data result:
#
# ```text
# 3.31
# ```

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.9.1 — Frequencies and percentages
#
# For `service_type`:
#
# 1. print unique values;
# 2. count unique values;
# 3. create a frequency table;
# 4. create a percentage table;
# 5. identify the most frequent stored category.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.9.2 — Grouped summary
#
# Calculate `count`, `mean`, `median`, `min` and `max` of `cases_received` for each `service_type`.
#
# Then answer:
#
# 1. Which group contains the suspicious negative minimum?
# 2. Why might that affect the mean?
# 3. Why should the output still be labelled preliminary?

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.9.3 — Discover category fragmentation
#
# Group `cases_received` by raw `city` and inspect the output.
#
# Write a short note explaining why the current city groups should probably be reviewed before final analysis.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.9.4 — Create a crosstab
#
# Create a cross-tabulation of `city` by `service_type`.
#
# Then explain:
#
# - what one cell counts;
# - why the raw city inconsistencies matter;
# - what a row-normalised percentage would mean.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.10.1 — Build a quality audit
#
# Write code that reports:
#
# 1. missing values by column;
# 2. missing percentages;
# 3. exact duplicate count;
# 4. all rows involved in exact duplication;
# 5. repeated `record_id` values;
# 6. unique raw city labels;
# 7. negative `cases_received` rows;
# 8. out-of-range satisfaction rows;
# 9. rows where resolved exceeds received;
# 10. non-numeric `resolution_days` values;
# 11. invalid `report_month` values.
#
# For each detected issue, write **one sentence describing the issue without fixing it**.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.10.2 — Classify the quality issue
#
# For each item below, classify it mainly as completeness, uniqueness, validity, consistency, plausibility or logical consistency. More than one answer may sometimes be defensible.
#
# 1. `feedback` is blank.
# 2. `record_id SR2026-0027` is repeated in identical rows, while `SR2026-0079` is reused for two different rows.
# 3. `city = " copenhagen "` appears beside `city = "Copenhagen"`.
# 4. `satisfaction_score = 0.0` or `6.2` when the documented scale is 1–5.
# 5. `cases_resolved = 90` and `cases_received = 85` under an assumption that resolved cases must be a subset of received cases.
# 6. `report_month = 2026-13-01`.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.11.1 — Explore text before coding themes
#
# 1. Display all non-missing feedback comments.
# 2. Read them manually.
# 3. Write down at least three recurring ideas you notice.
# 4. For each idea, identify possible words that could help retrieve relevant comments.
# 5. Explain at least one way that your keyword rule could miss relevant wording.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.11.2 — Search and validate a keyword rule
#
# Create a case-insensitive search for comments containing either `quick` or `fast`.
#
# Then:
#
# 1. count matches;
# 2. display the matching full comments;
# 3. read each match;
# 4. decide whether each one genuinely concerns speed;
# 5. identify one possible synonym your search rule would miss.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.11.3 — Compare quantitative and qualitative evidence
#
# Inspect the comments that match `wait|long` together with `satisfaction_score`.
#
# Write:
#
# - one observation directly supported by the rows;
# - one cautious interpretation;
# - one claim that would be too strong.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.12.1 — Design a coding rule
#
# Choose one idea from the feedback, for example:
#
# - clarity;
# - usefulness/helpfulness;
# - speed;
# - difficulty.
#
# Then:
#
# 1. define the idea in one sentence;
# 2. choose one or more search terms;
# 3. create a Boolean indicator;
# 4. count `True` values;
# 5. display all matching comments;
# 6. manually inspect at least three non-matching comments;
# 7. identify one possible false positive and one possible false negative;
# 8. revise the rule if justified;
# 9. document the final rule.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.12.2 — Compare code and score
#
# Using your Boolean indicator:
#
# ```python
# df.groupby("your_indicator")["satisfaction_score"].agg(
#     ["count", "mean", "median"]
# )
# ```
#
# Write:
#
# - one direct observation;
# - one cautious interpretation;
# - one causal claim that the result does **not** justify.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.12.3 — Multiple codes per comment
#
# Create at least two indicators and find comments where both are `True`.
#
# Example structure:
#
# ```python
# both = df[
#     df["mentions_helpful"] &
#     df["mentions_wait"]
# ]
#
# display(both[["feedback"]])
# ```
#
# Explain why allowing several codes can be more faithful to mixed comments than assigning only one category.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.13.1 — Create a data dictionary
#
# Create a Markdown table for all fourteen variables with:
#
# ```text
# variable
# meaning
# conceptual type
# unit/scale
# expected values
# known/raw concern
# ```

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.13.2 — Rewrite an overclaim
#
# Rewrite this statement so it becomes defensible:
#
# > “Transport has the highest cases, so public transport is the biggest problem in Danish cities.”

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# ## Exercise 3.13.3 — Separate three levels of statement
#
# For one calculation from Tutorial 3.9, write:
#
# 1. one direct observation;
# 2. one cautious interpretation;
# 3. one claim that the dataset cannot support.

# %%
pass  # Runs this part of the documented analysis.

# %% [markdown]
# # STOP — Solutions begin below
#
# The remaining sections are for checking work after an independent attempt. Each coding answer is fully commented and has been executed against the supplied raw CSV.

# %% [markdown]
# ## Solution 3.1.1 — Describe a dataset before coding
#
# One row could represent one measured organisation in one reporting period, but the unit must be confirmed from documentation. `employees` and `energy_use_kwh` look numeric, `organisation_id` is an identifier, and `comment` is free text. Interpreting energy use requires the period, coverage, unit definition, collection method and treatment of missing values. Several rows may belong to the same organisation, so rows are not automatically organisations.

# %% [markdown]
# ## Solution 3.2.1 — Find the structural problem
#
# The file appears semicolon-delimited, while `read_csv()` assumes commas by default. Inspect the raw text and source documentation, then test `sep=";"`; do not change the delimiter blindly because a one-column result can also indicate malformed quoting or the wrong file.

# %% [markdown]
# ## Solution 3.2.2 — Missing does not mean zero
#
# Zero is an observed numeric value. A blank field means no recognised value was stored and may mean missing, not measured or not applicable. Replacing every blank with zero would invent a measurement and can distort totals, averages and quality assessments.

# %% [markdown]
# ## Solution 3.3.1 — Load and verify
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
import pandas as pd  # Loads the library feature used by this step.
url = "https://raw.githubusercontent.com/asmrabbi/E26_TAN7_Scripting_CPH/main/data/E26_TAN7_service_experience_raw.csv"  # Stores the calculated or supplied value for later use.
df = pd.read_csv(url)  # Stores the calculated or supplied value for later use.
display(df.head())  # Displays the result so it can be inspected.
print(type(df))  # Displays the result so it can be inspected.
# Out:
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
#
# [5 rows x 14 columns]
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Solution 3.3.2 — Explain the file/DataFrame distinction
#
# `df` is an in-memory object created from the downloaded file. Changing the object does not rewrite the remote GitHub resource. A permanent change requires an explicit save operation and, for GitHub, permission plus a commit or upload.

# %% [markdown]
# ## Solution 3.4.1 — Produce an inspection note
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
rows, columns = df.shape  # Stores the calculated or supplied value for later use.
print("Rows:", rows)  # Displays the result so it can be inspected.
print("Columns:", columns)  # Displays the result so it can be inspected.
print("Column names:", df.columns.tolist())  # Displays the result so it can be inspected.
display(df.head(3))  # Displays the result so it can be inspected.
display(df.tail(3))  # Displays the result so it can be inspected.
print(df.dtypes)  # Displays the result so it can be inspected.
df.info()  # Runs this part of the documented analysis.
# Out:
# Rows: 121
# Columns: 14
# Column names: ['record_id', 'report_month', 'city', 'service_type', 'cases_received', 'cases_resolved', 'resolution_days', 'satisfaction_score', 'digital_cases', 'in_person_cases', 'repeat_contacts', 'complaints_received', 'staff_hours', 'feedback']
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
#
# [3 rows x 14 columns]
#        record_id  ...                                           feedback
# 118  SR2026-0119  ...  Collection information was easy to understand ...
# 119  SR2026-0120  ...  The response was fast and the information was ...
# 120  SR2026-0027  ...  The digital form worked well, although some in...
#
# [3 rows x 14 columns]
# record_id               object
# report_month            object
# city                    object
# service_type            object
# cases_received           int64
# cases_resolved           int64
# resolution_days         object
# satisfaction_score     float64
# digital_cases            int64
# in_person_cases          int64
# repeat_contacts          int64
# complaints_received      int64
# staff_hours            float64
# feedback                object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   record_id            121 non-null    object
#  1   report_month         121 non-null    object
#  2   city                 121 non-null    object
#  3   service_type         121 non-null    object
#  4   cases_received       121 non-null    int64
#  5   cases_resolved       121 non-null    int64
#  6   resolution_days      121 non-null    object
#  7   satisfaction_score   117 non-null    float64
#  8   digital_cases        121 non-null    int64
#  9   in_person_cases      121 non-null    int64
#  10  repeat_contacts      121 non-null    int64
#  11  complaints_received  121 non-null    int64
#  12  staff_hours          121 non-null    float64
#  13  feedback             118 non-null    object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 13.4+ KB

# %% [markdown]
# ## Solution 3.4.2 — Why inspect beyond the first five rows?
#
# The first five rows may not contain rare errors or later category variants, and files are often ordered by time or source. Inspect the tail, reproducible samples, structure, missing counts, dtypes, ranges and targeted quality conditions as well.

# %% [markdown]
# ## Solution 3.5.1 — Column selection
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
selected = df[["record_id", "service_type", "satisfaction_score", "feedback"]]  # Stores the calculated or supplied value for later use.
display(selected.head())  # Displays the result so it can be inspected.
print(type(selected))  # Displays the result so it can be inspected.
# Out:
#      record_id  ...                                           feedback
# 0  SR2026-0001  ...  The guidance was clear, but the supporting-doc...
# 1  SR2026-0002  ...  Several users asked for clearer information ab...
# 2  SR2026-0003  ...  Useful advice and a friendly response from staff.
# 3  SR2026-0004  ...  Helpful guidance, but some users reported dela...
# 4  SR2026-0005  ...  The response was fast and the information was ...
#
# [5 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Solution 3.5.2 — Filter a numeric condition
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
at_least_100 = df[df["cases_received"] >= 100]  # Stores the calculated or supplied value for later use.
display(at_least_100)  # Displays the result so it can be inspected.
print("Matching rows:", len(at_least_100))  # Displays the result so it can be inspected.
# Out:
#       record_id report_month        city      service_type  cases_received  cases_resolved resolution_days  satisfaction_score  digital_cases  in_person_cases  repeat_contacts  complaints_received  staff_hours                                                                            feedback
# 0   SR2026-0001   2026-01-01  Copenhagen           Housing             130             116             8.0                 3.5             88               42               17                   10         87.8     The guidance was clear, but the supporting-document requirements caused delays.
# 1   SR2026-0002   2026-01-01  Copenhagen         Transport             124             110             5.1                 3.9             92               32               10                    8         54.7                  Several users asked for clearer information about service changes.
# 2   SR2026-0003   2026-01-01  Copenhagen        Employment             105              93             5.5                 3.9             73               32               14                    5         58.2                                   Useful advice and a friendly response from staff.
# 3   SR2026-0004   2026-01-01  Copenhagen             Waste             104              94             4.9                 4.2             80               24                6                    4         34.3                        Helpful guidance, but some users reported delayed follow-up.
# 4   SR2026-0005   2026-01-01  Copenhagen  Citizen Services             166             152             3.1                 4.3            137               29                9                    6         48.9                               The response was fast and the information was useful.
# 5   SR2026-0006   2026-01-01      Aarhus           Housing             111              96             7.5                 3.6             69               42               16                    8         72.0   Helpful staff explained the housing process, although the waiting time felt long.
# 9   SR2026-0010   2026-01-01      Aarhus  Citizen Services             123             113             3.0                 4.4             92               31               10                    2         37.5                                                  Friendly staff and a clear answer.
# 10  SR2026-0011   2026-01-01      Odense        Transport              107              92             6.8                 3.5             61               46               14                    7         71.7  The online application was useful, but several steps were difficult to understand.
# 14  SR2026-0015   2026-01-01      Odense  Citizen Services             110             100         unknown                 4.2             79               31                6                    4         31.3                               The response was fast and the information was useful.
# 19  SR2026-0020   2026-01-01     Aalborg  Citizen Services             100              93             2.8                 4.3             59               41                7                    3         30.4            The digital form was convenient and staff explained the process clearly.
# 20  SR2026-0021   2026-02-01  Copenhagen           Housing             157             143             7.3                 3.6            111               46               21                   13        101.3   Helpful staff explained the housing process, although the waiting time felt long.
# 21  SR2026-0022   2026-02-01  Copenhagen         Transport             126             118             4.8                 NaN             94               32                8                    7         54.7                 Clear information and a helpful answer about the transport service.
# [Stored output shortened: showing 12 of 65 rows. Colab displays the full scrollable result.]
# Matching rows: 65

# %% [markdown]
# ## Solution 3.5.3 — Combine a category and numeric condition
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
transport_over_90 = df[(df["service_type"] == "Transport") & (df["cases_received"] > 90)]  # Stores the calculated or supplied value for later use.
display(transport_over_90[["record_id", "city", "cases_received"]])  # Displays the result so it can be inspected.
# Out:
#        record_id          city  cases_received
# 1    SR2026-0002    Copenhagen             124
# 6    SR2026-0007   copenhagen               95
# 21   SR2026-0022    Copenhagen             126
# 26   SR2026-0027        Aarhus             110
# 41   SR2026-0042    Copenhagen             132
# 46   SR2026-0047        Aarhus             119
# 51   SR2026-0052        Odense              93
# 61   SR2026-0062    Copenhagen             129
# 66   SR2026-0067        Aarhus             102
# 81   SR2026-0082        aarhus             144
# 86   SR2026-0087        Aarhus             122
# 91   SR2026-0092        Odense              92
# 101  SR2026-0102    Copenhagen             123
# 106  SR2026-0107        Aarhus             102
# 120  SR2026-0027        Aarhus             110

# %% [markdown]
# ## Solution 3.6.1 — Classify the course variables
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
roles = {"record_id": "identifier", "report_month": "date-like", "city": "categorical", "service_type": "categorical", "cases_received": "numeric count", "cases_resolved": "numeric count", "resolution_days": "numeric-intended measure", "satisfaction_score": "numeric rating", "digital_cases": "numeric count", "in_person_cases": "numeric count", "repeat_contacts": "numeric count", "complaints_received": "numeric count", "staff_hours": "numeric measure", "feedback": "free text"}  # Stores the calculated or supplied value for later use.
role_table = pd.DataFrame({"variable": list(roles), "conceptual_type": list(roles.values())})  # Stores the calculated or supplied value for later use.
role_table["pandas_dtype"] = role_table["variable"].map(df.dtypes.astype(str))  # Stores the calculated or supplied value for later use.
display(role_table)  # Displays the result so it can be inspected.
# Out:
#                variable           conceptual_type pandas_dtype
# 0             record_id                identifier       object
# 1          report_month                 date-like       object
# 2                  city               categorical       object
# 3          service_type               categorical       object
# 4        cases_received             numeric count        int64
# 5        cases_resolved             numeric count        int64
# 6       resolution_days  numeric-intended measure       object
# 7    satisfaction_score            numeric rating      float64
# 8         digital_cases             numeric count        int64
# 9       in_person_cases             numeric count        int64
# 10      repeat_contacts             numeric count        int64
# 11  complaints_received             numeric count        int64
# 12          staff_hours           numeric measure      float64
# 13             feedback                 free text       object

# %% [markdown]
# ## Solution 3.6.2 — Explain why this statement is wrong
#
# Technical storage does not determine analytical meaning. `record_id` labels records; an arithmetic average of identifiers has no substantive interpretation even if pandas stores the labels in a numeric dtype.

# %% [markdown]
# ## Solution 3.7.1 — Produce a numeric summary
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
resolved = df["cases_resolved"]  # Stores the calculated or supplied value for later use.
print("Count:", resolved.count())  # Displays the result so it can be inspected.
print("Sum:", resolved.sum())  # Displays the result so it can be inspected.
print("Mean:", resolved.mean())  # Displays the result so it can be inspected.
print("Median:", resolved.median())  # Displays the result so it can be inspected.
print("Minimum:", resolved.min())  # Displays the result so it can be inspected.
print("Maximum:", resolved.max())  # Displays the result so it can be inspected.
print("Standard deviation:", resolved.std())  # Displays the result so it can be inspected.
print(resolved.describe())  # Displays the result so it can be inspected.
# Out:
# Count: 121
# Sum: 11958
# Mean: 98.82644628099173
# Median: 95.0
# Minimum: 0
# Maximum: 176
# Standard deviation: 26.195953149914338
# count    121.000000
# mean      98.826446
# std       26.195953
# min        0.000000
# 25%       82.000000
# 50%       95.000000
# 75%      113.000000
# max      176.000000
# Name: cases_resolved, dtype: float64

# %% [markdown]
# ## Solution 3.7.2 — Mean or median?
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
mean_received = df["cases_received"].mean()  # Stores the calculated or supplied value for later use.
median_received = df["cases_received"].median()  # Stores the calculated or supplied value for later use.
print("Mean:", round(mean_received, 2))  # Displays the result so it can be inspected.
print("Median:", median_received)  # Displays the result so it can be inspected.
display(df[df["cases_received"] < 0])  # Displays the result so it can be inspected.
# Out:
# Mean: 104.57
# Median: 102.0
#       record_id  ...                                           feedback
# 53  SR2026-0054  ...  Helpful guidance, but some users reported dela...
#
# [1 rows x 14 columns]

# %% [markdown]
# ## Solution 3.7.3 — Count the denominator explicitly
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
mean_score = df["satisfaction_score"].mean()  # Stores the calculated or supplied value for later use.
valid_scores = df["satisfaction_score"].count()  # Stores the calculated or supplied value for later use.
print("Mean satisfaction:", round(mean_score, 2))  # Displays the result so it can be inspected.
print("Scores included:", valid_scores)  # Displays the result so it can be inspected.
# Out:
# Mean satisfaction: 4.11
# Scores included: 117

# %% [markdown]
# ## Solution 3.8.1 — Derive a difference
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
df["unresolved_cases"] = df["cases_received"] - df["cases_resolved"]  # Stores the calculated or supplied value for later use.
print(df["unresolved_cases"].nsmallest(5))  # Displays the result so it can be inspected.
display(df[df["unresolved_cases"] < 0][["record_id", "cases_received", "cases_resolved", "unresolved_cases"]])  # Displays the result so it can be inspected.
# Out:
# 11   -7
# 53   -4
# 89   -3
# 79    1
# 91    1
# Name: unresolved_cases, dtype: int64
#       record_id  cases_received  cases_resolved  unresolved_cases
# 11  SR2026-0012              80              87                -7
# 53  SR2026-0054              -4               0                -4
# 89  SR2026-0090             159             162                -3

# %% [markdown]
# ## Solution 3.8.2 — Explain two rate formulas
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
row_rates = df["cases_resolved"] / df["cases_received"] * 100  # Stores the calculated or supplied value for later use.
mean_row_rate = row_rates.mean()  # Stores the calculated or supplied value for later use.
overall_rate = df["cases_resolved"].sum() / df["cases_received"].sum() * 100  # Stores the calculated or supplied value for later use.
print("Mean row rate:", round(mean_row_rate, 2))  # Displays the result so it can be inspected.
print("Aggregate rate:", round(overall_rate, 2))  # Displays the result so it can be inspected.
# Out:
# Mean row rate: 93.66
# Aggregate rate: 94.51

# %% [markdown]
# ## Solution 3.8.3 — Calculate a missing percentage
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
missing_count = df["satisfaction_score"].isna().sum()  # Stores the calculated or supplied value for later use.
missing_percentage = missing_count / len(df) * 100  # Stores the calculated or supplied value for later use.
print("Missing satisfaction values:", missing_count)  # Displays the result so it can be inspected.
print("Missing percentage:", round(missing_percentage, 2))  # Displays the result so it can be inspected.
# Out:
# Missing satisfaction values: 4
# Missing percentage: 3.31

# %% [markdown]
# ## Solution 3.9.1 — Frequencies and percentages
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
print(df["service_type"].unique())  # Displays the result so it can be inspected.
print("Distinct raw labels:", df["service_type"].nunique())  # Displays the result so it can be inspected.
print(df["service_type"].value_counts())  # Displays the result so it can be inspected.
print(df["service_type"].value_counts(normalize=True).mul(100).round(2))  # Displays the result so it can be inspected.
print("Modes:", df["service_type"].mode().tolist())  # Displays the result so it can be inspected.
# Out:
# ['Housing' 'Transport' 'Employment' 'Waste' 'Citizen Services'
#  'Transport ' 'Citizen services' 'WASTE' 'Employment Services']
# Distinct raw labels: 9
# service_type
# Transport              24
# Employment             24
# Waste                  24
# Citizen Services       24
# Housing                21
# Transport               1
# Citizen services        1
# WASTE                   1
# Employment Services     1
# Name: count, dtype: int64
# service_type
# Transport              19.83
# Employment             19.83
# Waste                  19.83
# Citizen Services       19.83
# Housing                17.36
# Transport               0.83
# Citizen services        0.83
# WASTE                   0.83
# Employment Services     0.83
# Name: proportion, dtype: float64
# Modes: ['Citizen Services', 'Employment', 'Transport', 'Waste']

# %% [markdown]
# ## Solution 3.9.2 — Grouped summary
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
service_summary = df.groupby("service_type")["cases_received"].agg(["count", "mean", "median", "min", "max"])  # Stores the calculated or supplied value for later use.
display(service_summary.round(2))  # Displays the result so it can be inspected.
# Out:
#                      count    mean  median  min  max
# service_type
# Citizen Services        24  129.92   122.0   94  185
# Citizen services         1   99.00    99.0   99   99
# Employment              24   88.04    86.5   62  129
# Employment Services      1   97.00    97.0   97   97
# Housing                 21  115.86   113.0   86  157
# Transport               24  102.54    98.5   75  144
# Transport                1  107.00   107.0  107  107
# WASTE                    1   90.00    90.0   90   90
# Waste                   24   88.96    89.5   -4  138

# %% [markdown]
# ## Solution 3.9.3 — Discover category fragmentation
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
city_summary = df.groupby("city")["cases_received"].agg(["count", "sum", "mean"])  # Stores the calculated or supplied value for later use.
display(city_summary.round(2))  # Displays the result so it can be inspected.
print("Raw city labels:", df["city"].unique().tolist())  # Displays the result so it can be inspected.
# Out:
#               count   sum    mean
# city
#  copenhagen       1    95   95.00
# AALBORG           1    76   76.00
# Aalborg          28  2386   85.21
# Aarhus           30  3349  111.63
# Copenhagen       29  3807  131.28
# Koebenhavn        1    76   76.00
# Odense           29  2642   91.10
# Odense            1    78   78.00
# aarhus            1   144  144.00
# Raw city labels: ['Copenhagen', 'Aarhus', ' copenhagen ', 'Odense', 'Aalborg', 'AALBORG', 'Odense ', 'aarhus', 'Koebenhavn']

# %% [markdown]
# ## Solution 3.9.4 — Create a crosstab
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
city_service = pd.crosstab(df["city"], df["service_type"])  # Stores the calculated or supplied value for later use.
display(city_service)  # Displays the result so it can be inspected.
row_percent = pd.crosstab(df["city"], df["service_type"], normalize="index").mul(100)  # Stores the calculated or supplied value for later use.
display(row_percent.round(2))  # Displays the result so it can be inspected.
# Out:
# service_type  Citizen Services  Citizen services  ...  WASTE  Waste
# city                                              ...
#  copenhagen                  0                 0  ...      0      0
# AALBORG                      0                 0  ...      0      0
# Aalborg                      6                 1  ...      0      5
# Aarhus                       6                 0  ...      0      6
# Copenhagen                   6                 0  ...      0      6
# Koebenhavn                   0                 0  ...      0      1
# Odense                       6                 0  ...      1      6
# Odense                       0                 0  ...      0      0
# aarhus                       0                 0  ...      0      0
#
# [9 rows x 9 columns]
# service_type  Citizen Services  Citizen services  ...  WASTE   Waste
# city                                              ...
#  copenhagen               0.00              0.00  ...   0.00    0.00
# AALBORG                   0.00              0.00  ...   0.00    0.00
# Aalborg                  21.43              3.57  ...   0.00   17.86
# Aarhus                   20.00              0.00  ...   0.00   20.00
# Copenhagen               20.69              0.00  ...   0.00   20.69
# Koebenhavn                0.00              0.00  ...   0.00  100.00
# Odense                   20.69              0.00  ...   3.45   20.69
# Odense                    0.00              0.00  ...   0.00    0.00
# aarhus                    0.00              0.00  ...   0.00    0.00
#
# [9 rows x 9 columns]

# %% [markdown]
# ## Solution 3.10.1 — Build a quality audit
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
print("Missing counts")  # Displays the result so it can be inspected.
print(df.isna().sum())  # Displays the result so it can be inspected.
print("Missing percentages")  # Displays the result so it can be inspected.
print(df.isna().mean().mul(100).round(2))  # Displays the result so it can be inspected.
print("Exact duplicates:", df.duplicated().sum())  # Displays the result so it can be inspected.
display(df[df.duplicated(keep=False)])  # Displays the result so it can be inspected.
display(df[df["record_id"].duplicated(keep=False)])  # Displays the result so it can be inspected.
print("Raw cities:", df["city"].unique().tolist())  # Displays the result so it can be inspected.
display(df[df["cases_received"] < 0])  # Displays the result so it can be inspected.
sat_problem = (df["satisfaction_score"] < 1) | (df["satisfaction_score"] > 5)  # Stores the calculated or supplied value for later use.
display(df[sat_problem])  # Displays the result so it can be inspected.
display(df[df["cases_resolved"] > df["cases_received"]])  # Displays the result so it can be inspected.
resolution_preview = pd.to_numeric(df["resolution_days"], errors="coerce")  # Stores the calculated or supplied value for later use.
display(df.loc[df["resolution_days"].notna() & resolution_preview.isna(), ["record_id", "resolution_days"]])  # Displays the result so it can be inspected.
month_preview = pd.to_datetime(df["report_month"], errors="coerce")  # Stores the calculated or supplied value for later use.
display(df.loc[month_preview.isna(), ["record_id", "report_month"]])  # Displays the result so it can be inspected.
# Out:
# Missing counts
# record_id              0
# report_month           0
# city                   0
# service_type           0
# cases_received         0
# cases_resolved         0
# resolution_days        0
# satisfaction_score     4
# digital_cases          0
# in_person_cases        0
# repeat_contacts        0
# complaints_received    0
# staff_hours            0
# feedback               3
# unresolved_cases       0
# dtype: int64
# Missing percentages
# record_id              0.00
# report_month           0.00
# city                   0.00
# service_type           0.00
# cases_received         0.00
# cases_resolved         0.00
# resolution_days        0.00
# satisfaction_score     3.31
# digital_cases          0.00
# in_person_cases        0.00
# repeat_contacts        0.00
# complaints_received    0.00
# staff_hours            0.00
# feedback               2.48
# unresolved_cases       0.00
# dtype: float64
# Exact duplicates: 1
#        record_id  ... unresolved_cases
# 26   SR2026-0027  ...                8
# 120  SR2026-0027  ...                8
#
# [2 rows x 15 columns]
#        record_id  ... unresolved_cases
# 26   SR2026-0027  ...                8
# 78   SR2026-0079  ...                4
# 79   SR2026-0079  ...                1
# 120  SR2026-0027  ...                8
#
# [4 rows x 15 columns]
# Raw cities: ['Copenhagen', 'Aarhus', ' copenhagen ', 'Odense', 'Aalborg', 'AALBORG', 'Odense ', 'aarhus', 'Koebenhavn']
#       record_id  ... unresolved_cases
# 53  SR2026-0054  ...               -4
#
# [1 rows x 15 columns]
#       record_id  ... unresolved_cases
# 38  SR2026-0039  ...                7
# 72  SR2026-0073  ...                3
#
# [2 rows x 15 columns]
#       record_id  ... unresolved_cases
# 11  SR2026-0012  ...               -7
# 53  SR2026-0054  ...               -4
# 89  SR2026-0090  ...               -3
#
# [3 rows x 15 columns]
#        record_id resolution_days
# 14   SR2026-0015         unknown
# 66   SR2026-0067         unknown
# 102  SR2026-0103         unknown
#       record_id report_month
# 43  SR2026-0044   2026-13-01

# %% [markdown]
# ## Solution 3.10.2 — Classify the quality issue
#
# 1 completeness; 2 uniqueness; 3 consistency; 4 validity; 5 validity; 6 logical consistency. Plausibility can overlap with several items, but the documented rule should be named.

# %% [markdown]
# ## Solution 3.11.1 — Explore text before coding themes
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
feedback = df["feedback"].dropna()  # Stores the calculated or supplied value for later use.
print(feedback.to_string(index=False))  # Displays the result so it can be inspected.
print("Available comments:", feedback.count())  # Displays the result so it can be inspected.
# Out:
# The guidance was clear, but the supporting-docu...
# Several users asked for clearer information abo...
#  Useful advice and a friendly response from staff.
# Helpful guidance, but some users reported delay...
# The response was fast and the information was u...
# Helpful staff explained the housing process, al...
# Several users asked for clearer information abo...
# The answer was useful, although the waiting tim...
# Collection information was easy to understand a...
#                 Friendly staff and a clear answer.
# The online application was useful, but several ...
# The response was quick, but route-change inform...
#  Useful advice and a friendly response from staff.
# Helpful guidance, but some users reported delay...
# The response was fast and the information was u...
# The guidance was clear, but the supporting-docu...
# The digital form worked well, although some ins...
# The issue was resolved quickly after the first ...
# The digital form was convenient and staff expla...
# Helpful staff explained the housing process, al...
# Clear information and a helpful answer about th...
# The answer was useful, although the waiting tim...
# Some users found the collection instructions co...
# Quick and helpful service with clear instructions.
# Helpful staff explained the housing process, al...
# The digital form worked well, although some ins...
# The guidance was clear but the process required...
# Collection information was easy to understand a...
# The digital form was convenient and staff expla...
# The wait was not long, and the final response w...
#                 Fast response and useful guidance.
# The online information was helpful, but some us...
# Helpful guidance, but some users reported delay...
# The digital form was convenient and staff expla...
# Staff were friendly and the final answer was he...
#                 Fast response and useful guidance.
# The answer was useful, although the waiting tim...
# The issue was resolved quickly after the first ...
# The digital form was convenient and staff expla...
# The online application was useful, but several ...
# Several users asked for clearer information abo...
# Staff were helpful, though appointment availabi...
# Helpful guidance, but some users reported delay...
# The online process was easy to use, although on...
# The answer solved the problem, but repeated con...
# The response was quick, but route-change inform...
# The online information was helpful, but some us...
# The issue was resolved quickly after the first ...
# The response was fast and the information was u...
# Staff were friendly and the final answer was he...
# Clear information and a helpful answer about th...
# The online information was helpful, but some us...
# Helpful guidance, but some users reported delay...
# The digital form was convenient and staff expla...
# Helpful staff explained the housing process, al...
# The response was quick, but route-change inform...
# The answer was useful, although the waiting tim...
# The issue was resolved quickly after the first ...
# The response was fast and the information was u...
# The guidance was clear, but the supporting-docu...
# The response was quick, but route-change inform...
# Staff were helpful, though appointment availabi...
# The issue was resolved quickly after the first ...
# The response was fast and the information was u...
# The guidance was clear, but the supporting-docu...
# The response was quick, but route-change inform...
# Staff were helpful, though appointment availabi...
# Helpful guidance, but some users reported delay...
# Quick and helpful service with clear instructions.
# The answer solved the problem, but repeated con...
# The response was quick, but route-change inform...
# The answer was useful, although the waiting tim...
# Helpful guidance, but some users reported delay...
#                 Friendly staff and a clear answer.
# The response was quick, but route-change inform...
# The guidance was clear but the process required...
# Some users found the collection instructions co...
#                 Friendly staff and a clear answer.
# The online application was useful, but several ...
#                 Fast response and useful guidance.
#  Useful advice and a friendly response from staff.
# Helpful guidance, but some users reported delay...
# The process took forever, although the staff me...
# The online application was useful, but several ...
# Clear information and a helpful answer about th...
# Staff were helpful, though appointment availabi...
# Helpful guidance, but some users reported delay...
# The response was fast and the information was u...
# The online application was useful, but several ...
#                 Fast response and useful guidance.
# The guidance was clear but the process required...
# The online information was clear and easy to find.
#                 Friendly staff and a clear answer.
# The guidance was clear, but the supporting-docu...
# Clear information and a helpful answer about th...
#  Useful advice and a friendly response from staff.
# The online information was clear and easy to find.
# Quick and helpful service with clear instructions.
# The guidance was clear, but the supporting-docu...
# Several users asked for clearer information abo...
# The online information was helpful, but some us...
# The issue was resolved quickly after the first ...
# The digital form was convenient and staff expla...
# Staff were friendly and the final answer was he...
#                 Fast response and useful guidance.
#  Useful advice and a friendly response from staff.
# The issue was resolved quickly after the first ...
#                 Friendly staff and a clear answer.
# Helpful staff explained the housing process, al...
# Clear information and a helpful answer about th...
# The guidance was clear but the process required...
# The online information was clear and easy to find.
#                 Friendly staff and a clear answer.
# Staff were friendly and the final answer was he...
# The digital form worked well, although some ins...
# Collection information was easy to understand a...
# The response was fast and the information was u...
# The digital form worked well, although some ins...
# Available comments: 118

# %% [markdown]
# ## Solution 3.11.2 — Search and validate a keyword rule
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
speed_mask = df["feedback"].str.contains("quick|fast", case=False, na=False, regex=True)  # Stores the calculated or supplied value for later use.
print("Speed-rule matches:", int(speed_mask.sum()))  # Displays the result so it can be inspected.
print(df.loc[speed_mask, "feedback"].to_string(index=False))  # Displays the result so it can be inspected.
# Out:
# Speed-rule matches: 32
# The response was fast and the information was u...
# Collection information was easy to understand a...
# The response was quick, but route-change inform...
# The response was fast and the information was u...
# The issue was resolved quickly after the first ...
# Quick and helpful service with clear instructions.
# Collection information was easy to understand a...
#                 Fast response and useful guidance.
#                 Fast response and useful guidance.
# The issue was resolved quickly after the first ...
# The response was quick, but route-change inform...
# The issue was resolved quickly after the first ...
# The response was fast and the information was u...
# The response was quick, but route-change inform...
# The issue was resolved quickly after the first ...
# The response was fast and the information was u...
# The response was quick, but route-change inform...
# The issue was resolved quickly after the first ...
# The response was fast and the information was u...
# The response was quick, but route-change inform...
# Quick and helpful service with clear instructions.
# The response was quick, but route-change inform...
# The response was quick, but route-change inform...
#                 Fast response and useful guidance.
# The response was fast and the information was u...
#                 Fast response and useful guidance.
# Quick and helpful service with clear instructions.
# The issue was resolved quickly after the first ...
#                 Fast response and useful guidance.
# The issue was resolved quickly after the first ...
# Collection information was easy to understand a...
# The response was fast and the information was u...

# %% [markdown]
# ## Solution 3.11.3 — Compare quantitative and qualitative evidence
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
wait_mask = df["feedback"].str.contains("wait|long", case=False, na=False, regex=True)  # Stores the calculated or supplied value for later use.
wait_rows = df.loc[wait_mask, ["record_id", "service_type", "satisfaction_score", "feedback"]]  # Stores the calculated or supplied value for later use.
display(wait_rows)  # Displays the result so it can be inspected.
print("Matched comments:", len(wait_rows))  # Displays the result so it can be inspected.
print("Matched comments with scores:", wait_rows["satisfaction_score"].notna().sum())  # Displays the result so it can be inspected.
# Out:
#        record_id  ...                                           feedback
# 5    SR2026-0006  ...  Helpful staff explained the housing process, a...
# 7    SR2026-0008  ...  The answer was useful, although the waiting ti...
# 20   SR2026-0021  ...  Helpful staff explained the housing process, a...
# 22   SR2026-0023  ...  The answer was useful, although the waiting ti...
# 25   SR2026-0026  ...  Helpful staff explained the housing process, a...
# 30   SR2026-0031  ...  The wait was not long, and the final response ...
# 37   SR2026-0038  ...  The answer was useful, although the waiting ti...
# 55   SR2026-0056  ...  Helpful staff explained the housing process, a...
# 57   SR2026-0058  ...  The answer was useful, although the waiting ti...
# 72   SR2026-0073  ...  The answer was useful, although the waiting ti...
# 110  SR2026-0111  ...  Helpful staff explained the housing process, a...
#
# [11 rows x 4 columns]
# Matched comments: 11
# Matched comments with scores: 10

# %% [markdown]
# ## Solution 3.12.1 — Design a coding rule
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
df["mentions_clarity"] = df["feedback"].str.contains("clear", case=False, na=False)  # Stores the calculated or supplied value for later use.
print("Clarity matches:", int(df["mentions_clarity"].sum()))  # Displays the result so it can be inspected.
print(df.loc[df["mentions_clarity"], "feedback"].to_string(index=False))  # Displays the result so it can be inspected.
print("Three non-matches for manual review")  # Displays the result so it can be inspected.
print(df.loc[~df["mentions_clarity"] & df["feedback"].notna(), "feedback"].head(3).to_string(index=False))  # Displays the result so it can be inspected.
# Out:
# Clarity matches: 40
# The guidance was clear, but the supporting-docu...
# Several users asked for clearer information abo...
# Several users asked for clearer information abo...
#                 Friendly staff and a clear answer.
# The guidance was clear, but the supporting-docu...
# The digital form was convenient and staff expla...
# Clear information and a helpful answer about th...
# Quick and helpful service with clear instructions.
# The guidance was clear but the process required...
# The digital form was convenient and staff expla...
# The wait was not long, and the final response w...
# The digital form was convenient and staff expla...
# The digital form was convenient and staff expla...
# Several users asked for clearer information abo...
# The answer solved the problem, but repeated con...
# Clear information and a helpful answer about th...
# The digital form was convenient and staff expla...
# The guidance was clear, but the supporting-docu...
# The guidance was clear, but the supporting-docu...
# Quick and helpful service with clear instructions.
# The answer solved the problem, but repeated con...
#                 Friendly staff and a clear answer.
# The guidance was clear but the process required...
#                 Friendly staff and a clear answer.
# Clear information and a helpful answer about th...
# The guidance was clear but the process required...
# The online information was clear and easy to find.
#                 Friendly staff and a clear answer.
# The guidance was clear, but the supporting-docu...
# Clear information and a helpful answer about th...
# The online information was clear and easy to find.
# Quick and helpful service with clear instructions.
# The guidance was clear, but the supporting-docu...
# Several users asked for clearer information abo...
# The digital form was convenient and staff expla...
#                 Friendly staff and a clear answer.
# Clear information and a helpful answer about th...
# The guidance was clear but the process required...
# The online information was clear and easy to find.
#                 Friendly staff and a clear answer.
# Three non-matches for manual review
#  Useful advice and a friendly response from staff.
# Helpful guidance, but some users reported delay...
# The response was fast and the information was u...

# %% [markdown]
# ## Solution 3.12.2 — Compare code and score
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
comparison = df.groupby("mentions_clarity")["satisfaction_score"].agg(["count", "mean", "median"])  # Stores the calculated or supplied value for later use.
display(comparison.round(2))  # Displays the result so it can be inspected.
# Out:
#                   count  mean  median
# mentions_clarity
# False                78  4.08     4.1
# True                 39  4.17     4.2

# %% [markdown]
# ## Solution 3.12.3 — Multiple codes per comment
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
df["mentions_speed"] = df["feedback"].str.contains("quick|fast", case=False, na=False, regex=True)  # Stores the calculated or supplied value for later use.
df["mentions_helpful"] = df["feedback"].str.contains("helpful", case=False, na=False)  # Stores the calculated or supplied value for later use.
both_mask = df["mentions_speed"] & df["mentions_helpful"]  # Stores the calculated or supplied value for later use.
display(df.loc[both_mask, ["record_id", "feedback"]])  # Displays the result so it can be inspected.
print("Comments with both codes:", int(both_mask.sum()))  # Displays the result so it can be inspected.
# Out:
#       record_id                                           feedback
# 24  SR2026-0025  Quick and helpful service with clear instructi...
# 69  SR2026-0070  Quick and helpful service with clear instructi...
# 99  SR2026-0100  Quick and helpful service with clear instructi...
# Comments with both codes: 3

# %% [markdown]
# ## Solution 3.13.1 — Create a data dictionary
#
# The code below gives one reproducible solution. Describe the result in relation to the unit of observation, the denominator and any visible raw-data limitation.

# %%
dictionary_rows = [{"variable": column, "pandas_dtype": str(df[column].dtype), "meaning_or_rule": "Complete from the published Lecture 5 data dictionary"} for column in df.columns]  # Stores the calculated or supplied value for later use.
data_dictionary = pd.DataFrame(dictionary_rows)  # Stores the calculated or supplied value for later use.
display(data_dictionary)  # Displays the result so it can be inspected.
# Out:
#                variable pandas_dtype                                        meaning_or_rule
# 0             record_id       object  Complete from the published Lecture 5 data dictionary
# 1          report_month       object  Complete from the published Lecture 5 data dictionary
# 2                  city       object  Complete from the published Lecture 5 data dictionary
# 3          service_type       object  Complete from the published Lecture 5 data dictionary
# 4        cases_received        int64  Complete from the published Lecture 5 data dictionary
# 5        cases_resolved        int64  Complete from the published Lecture 5 data dictionary
# 6       resolution_days       object  Complete from the published Lecture 5 data dictionary
# 7    satisfaction_score      float64  Complete from the published Lecture 5 data dictionary
# 8         digital_cases        int64  Complete from the published Lecture 5 data dictionary
# 9       in_person_cases        int64  Complete from the published Lecture 5 data dictionary
# 10      repeat_contacts        int64  Complete from the published Lecture 5 data dictionary
# 11  complaints_received        int64  Complete from the published Lecture 5 data dictionary
# [Stored output shortened: showing 12 of 18 rows. Colab displays the full scrollable result.]

# %% [markdown]
# ## Solution 3.13.2 — Rewrite an overclaim
#
# In the raw synthetic teaching table, the exact `Transport` label has 2,461 received cases across 24 rows. This does not establish that public transport is Denmark's biggest problem because the data are synthetic, the unit is a service-category-city-month record, categories are inconsistent and the file is not representative of residents or cities.

# %% [markdown]
# ## Solution 3.13.3 — Separate three levels of statement
#
# Observation: four exact service labels each occur in 24 of 121 raw rows. Cautious interpretation: the raw table is nearly balanced across several intended service categories, though inconsistent variants split some groups. Unsupported claim: real residents use those services equally often.

# %% [markdown]
# # Checks and next steps
#
# All 33 website exercises are present in the student section and in the same solution order. Revisit any answer you could run but could not explain. Then complete Tutorial 3.14 in the separate Applied Activities notebook.
