# %% [markdown]
# # Lecture 10 — Student Mini-Project Template
#
# **Course:** AAU E26 — Introduction to Scripting, Data Mining and Machine Learning
# **Lecture:** Lecture 10
# **Goal:** Create a transparent, reproducible mini-project suitable for discussion and examination preparation.
#
# [Open this notebook in Google Colab](https://colab.research.google.com/github/asmrabbi/E26_TAN7_Scripting_CPH/blob/main/notebooks/projects/L10_student_mini_project_template.ipynb) · [View the course repository](https://github.com/asmrabbi/E26_TAN7_Scripting_CPH)
#
# Run the cells from top to bottom. Every executable line includes a short comment explaining what it does.

# %% [markdown]
# ## Goal
#
# Plan and document a small end-to-end project that connects a question, data quality, code, a result, and critical reflection.

# %% [markdown]
# ## Setup
#
# Make a personal copy in Colab. Replace the bracketed prompts, keep the raw data unchanged, and make every new code line explain itself with a comment.

# %% [markdown]
# ## Steps
#
# ### 1. Question and intended use
#
# - **Question:** [write one answerable question]
# - **Intended audience:** [who needs the result?]
# - **Unit of analysis:** [what does one row represent?]
# - **Decision or discussion supported:** [what will the result inform?]

# %% [markdown]
# ### 2. Source and limitations
#
# - **Data source and link:** [add source]
# - **Collection context:** [what is known?]
# - **Important missing context:** [what is unknown?]
# - **Sensitive or personal data:** [state whether present and how it is protected]

# %%
# TODO: Import only the libraries required for your project.
# TODO: Store the source path or URL in a clearly named variable.
# TODO: Load the data without changing the original source.
# TODO: Display only a bounded preview.

# %% [markdown]
# ### 3. Inspection and quality assessment
#
# Record completeness, validity, consistency, uniqueness, plausibility, and any uncertainty about what counts as an error.

# %%
# TODO: Inspect shape, columns, types, missingness, and duplicates.
# TODO: Test rules that are supported by the source or project definition.
# TODO: Print a focused table of records requiring review.

# %% [markdown]
# ### 4. Transparent preparation
#
# Keep a transformation log containing the field, original issue, action, reason, and possible effect.

# %%
transformation_log = []  # Creates an ordered record of every justified change.
# TODO: Make a working copy of the raw data.
# TODO: Apply one justified transformation at a time.
# TODO: Append a plain-language log entry after each transformation.
# TODO: Compare row counts and missingness before and after.

# %% [markdown]
# ### 5. Analysis or model
#
# Choose the simplest method that can address the question. State denominators, assumptions, and evaluation data.

# %%
# TODO: Calculate a bounded table, chart, or model result.
# TODO: Add labels, units, and evaluation information.
# TODO: Include one reasonableness check.

# %% [markdown]
# ### 6. Interpretation
#
# - **Strongest defensible conclusion:** [write one]
# - **Two unsupported conclusions:** [write two]
# - **Main uncertainty:** [write one]
# - **Next evidence needed:** [write one]

# %% [markdown]
# ### 7. Debugging and revision record
#
# Describe one meaningful error or weak choice, how you diagnosed it, what you changed, and how you checked the repair.

# %% [markdown]
# ## Checks
#
# A classmate should be able to rerun the notebook from top to bottom, trace every source and transformation, understand each output, and distinguish observation from interpretation.

# %% [markdown]
# ## Next Steps
#
# Prepare a five-minute explanation using the same order: question, data, code/process, result, limitation, and one debugging or revision decision.
