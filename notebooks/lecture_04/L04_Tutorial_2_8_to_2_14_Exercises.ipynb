# %% [markdown]
# # Lecture 4 Focused Exercises — Instructions
#
# **Tutorials:** 2.8–2.14
# [Open this notebook in Colab](https://colab.research.google.com/github/asmrabbi/E26_TAN7_Scripting_CPH/blob/main/notebooks/lecture_04/L04_Tutorial_2_8_to_2_14_Exercises.ipynb) · [Open fully commented solutions](https://colab.research.google.com/github/asmrabbi/E26_TAN7_Scripting_CPH/blob/main/notebooks/lecture_04/L04_Tutorial_2_8_to_2_14_Solutions.ipynb) · [GitHub folder](https://github.com/asmrabbi/E26_TAN7_Scripting_CPH/tree/main/notebooks/lecture_04)

# %% [markdown]
# ## Goal
#
# Translate each situation into ordered Python steps and test your own implementation before consulting the answer.

# %% [markdown]
# ## Setup
#
# Python 3 is sufficient; no third-party library or dataset is required. Save a Colab copy before editing, or open this file locally in Jupyter or PyCharm.

# %% [markdown]
# ## Steps
#
# Read the full situation, identify inputs and rules, follow the code plan, run normal and boundary tests, and record one limitation that Python cannot settle.

# %% [markdown]
# ### Exercise 2.8.1 — Classify consultation engagement
#
# Classify engagement as Very high from 300, High from 200, Medium from 100 and Low otherwise. Test the values 99, 100, 199, 200, 299 and 300.
#
# **Code plan**
#
# 1. Store the boundary tests.
# 2. Write a classification function.
# 3. Loop through the tests.
# 4. Display every input and result.

# %%
# Exercise 2.8.1 — Classify consultation engagement starter
# Write the solution in this cell after completing the code plan.
# Step 1: Store the boundary tests.
# Step 2: Write a classification function.
# Step 3: Loop through the tests.
# Step 4: Display every input and result.

# %% [markdown]
# ### Exercise 2.9.1 — Combine transparent review rules
#
# A record needs review when its source is unverified or when consent is missing. A verified source with consent should pass the initial rule even when its topic is ordinary.
#
# **Code plan**
#
# 1. Store several record dictionaries.
# 2. Write the combined rule.
# 3. Return a decision and reason.
# 4. Test all meaningful combinations.

# %%
# Exercise 2.9.1 — Combine transparent review rules starter
# Write the solution in this cell after completing the code plan.
# Step 1: Store several record dictionaries.
# Step 2: Write the combined rule.
# Step 3: Return a decision and reason.
# Step 4: Test all meaningful combinations.

# %% [markdown]
# ### Exercise 2.10.1 — Validate numerical-looking input
#
# Process the simulated inputs 25, text, -1 and 101 as percentages. Conversion errors and out-of-range values must have different messages.
#
# **Code plan**
#
# 1. Loop through the raw text values.
# 2. Catch ValueError narrowly.
# 3. Validate the zero-to-one-hundred range.
# 4. Display each decision.

# %%
# Exercise 2.10.1 — Validate numerical-looking input starter
# Write the solution in this cell after completing the code plan.
# Step 1: Loop through the raw text values.
# Step 2: Catch ValueError narrowly.
# Step 3: Validate the zero-to-one-hundred range.
# Step 4: Display each decision.

# %% [markdown]
# ### Exercise 2.11.1 — Count categories in structured records
#
# Count the categories in a list of observation dictionaries and identify unique campuses. Preserve the original records.
#
# **Code plan**
#
# 1. Store a list of dictionaries.
# 2. Prepare a counter dictionary and campus set.
# 3. Loop through the records.
# 4. Display the counts and unique campuses.

# %%
# Exercise 2.11.1 — Count categories in structured records starter
# Write the solution in this cell after completing the code plan.
# Step 1: Store a list of dictionaries.
# Step 2: Prepare a counter dictionary and campus set.
# Step 3: Loop through the records.
# Step 4: Display the counts and unique campuses.

# %% [markdown]
# ### Exercise 2.12.1 — Repeat until a valid menu choice
#
# Use simulated inputs to model a prompt that repeats until the user chooses A, B or C. The loop must stop visibly and remain bounded in the notebook.
#
# **Code plan**
#
# 1. Store simulated responses.
# 2. Track the current position.
# 3. Use while with an explicit bound.
# 4. Stop when a valid choice appears.

# %%
# Exercise 2.12.1 — Repeat until a valid menu choice starter
# Write the solution in this cell after completing the code plan.
# Step 1: Store simulated responses.
# Step 2: Track the current position.
# Step 3: Use while with an explicit bound.
# Step 4: Stop when a valid choice appears.

# %% [markdown]
# ### Exercise 2.13.1 — Reuse a validation function
#
# Write a function that returns a completion percentage or None when the total is invalid. Apply it to several records and keep printing outside the function.
#
# **Code plan**
#
# 1. Define the function with two parameters.
# 2. Validate the whole and part.
# 3. Return a reusable value.
# 4. Loop through tests and display results.

# %%
# Exercise 2.13.1 — Reuse a validation function starter
# Write the solution in this cell after completing the code plan.
# Step 1: Define the function with two parameters.
# Step 2: Validate the whole and part.
# Step 3: Return a reusable value.
# Step 4: Loop through tests and display results.

# %% [markdown]
# ### Exercise 2.14.1 — Import, calculate and debug
#
# Use the standard statistics module to calculate a mean. Then handle an empty sequence with a clear message and explain why no package installation is required.
#
# **Code plan**
#
# 1. Import statistics.
# 2. Write a guarded mean function.
# 3. Test ordinary and empty lists.
# 4. Display the results.

# %%
# Exercise 2.14.1 — Import, calculate and debug starter
# Write the solution in this cell after completing the code plan.
# Step 1: Import statistics.
# Step 2: Write a guarded mean function.
# Step 3: Test ordinary and empty lists.
# Step 4: Display the results.

# %% [markdown]
# ## Checks
#
# - Every task has a numbered code plan.
# - Your code uses meaningful names and explicit tests.
# - Invalid or ambiguous information is preserved for review.
# - You attempted the work before opening the answer.

# %% [markdown]
# ## Next Steps
#
# Open the solution notebook, compare one decision at a time and revise your own notebook rather than replacing it blindly.
