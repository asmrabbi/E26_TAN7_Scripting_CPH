# %% [markdown]
# # Lecture 7 — Exercises and Guided Practice
#
# This notebook contains the **exercise items only**. Each exercise keeps the exact identifier used on the tutorial website. Examples and exercises share one numbering stream, so the exercise numbers will not necessarily be consecutive inside this file. That is intentional: the missing identifiers belong to worked examples in the Examples notebook.
#
# **Do not renumber these items locally.**

# %% [markdown]
# # Tutorial 3.30 — From cleaned data to analytical questions

# %% [markdown]
# ## Exercise 3.30.7 — Try it yourself
#
# **Website locator:** Exercise 3.30.7

# %% [markdown]
# Turn each broad question into a more data-compatible question.
#
# 1. Why is Copenhagen better than Aarhus?
# 2. Why do people hate digital services?
# 3. Which service is most efficient?
#
# <details>
# <summary>Possible answers</summary>
#
# 1. “How do selected service indicators such as average resolution time, satisfaction score and complaint rate differ between Copenhagen and Aarhus?”
# 2. “How do satisfaction scores and feedback terms differ between records with more digital cases and records with more in-person cases?”
# 3. “How do selected indicators of case resolution, staff time and repeat contacts differ across service types?”
#
# Each revised question still requires careful interpretation. For example, “efficiency” is a broad concept and cannot be reduced automatically to one metric.
#
# </details>
#
# > **Critical reflection**
# >
# > A dataset does not simply contain a reality waiting to be discovered. It contains selected variables created through particular organisational definitions, recording practices and technical systems.
#
# [VISUAL / SCREENSHOT]
# Create a horizontal chain: **Question → Variables → Calculation → Visualisation → Claim → Limitation**. Use one concrete worked example underneath.
#
# ---

# %% [markdown]
# ## Exercise 3.30.8 — Extended practice task 1
#
# **Website locator:** Exercise 3.30.8

# %% [markdown]
# Write three questions that the dataset can answer descriptively and three questions it cannot answer on its own.

# %% [markdown]
# ## Exercise 3.30.9 — Extended practice task 2
#
# **Website locator:** Exercise 3.30.9

# %% [markdown]
# Identify the unit of observation and explain how it constrains the wording of a question.

# %% [markdown]
# ## Exercise 3.30.10 — Extended practice task 3
#
# **Website locator:** Exercise 3.30.10

# %% [markdown]
# Choose one quality flag that matters for a planned analysis and state how you will handle it.

# %% [markdown]
# ## Exercise 3.30.11 — Extended practice task 4
#
# **Website locator:** Exercise 3.30.11

# %% [markdown]
# Translate a broad concept such as 'good service' into two modest, observable indicators available in the dataset.

# %% [markdown]
# ## Exercise 3.30.12 — Extended practice task 5
#
# **Website locator:** Exercise 3.30.12

# %% [markdown]
# Rewrite one causal question as a descriptive or associational question that matches the available evidence.

# %% [markdown]
# ## Exercise 3.30.13 — Explain it without code
#
# **Website locator:** Exercise 3.30.13

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.30.14 — Small transfer task
#
# **Website locator:** Exercise 3.30.14

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.31 — Exploration vs question-driven analysis

# %% [markdown]
# ## Exercise 3.31.1 — Try it yourself
#
# **Website locator:** Exercise 3.31.1

# %% [markdown]
# Create an analysis plan for:
#
# > “Do complaint rates differ across cities?”
#
# <details>
# <summary>Suggested answer</summary>
#
# ```text
# Question:
# Do complaint rates differ across cities?
#
# Relevant columns:
# city, complaints_received, cases_received
#
# Calculation:
# Create complaint_rate = complaints_received / cases_received × 100, then calculate a suitable city-level summary.
#
# Visualisation:
# Bar chart of complaint rate by city, with the calculation clearly documented.
#
# Evidence:
# Differences in observed complaint rates.
#
# Does not prove:
# That city characteristics caused the differences, or that all complaint processes are measured identically across cities.
# ```
#
# </details>
#
# ---

# %% [markdown]
# ## Exercise 3.31.2 — Extended practice task 1
#
# **Website locator:** Exercise 3.31.2

# %% [markdown]
# Write one open exploratory question about the service data.

# %% [markdown]
# ## Exercise 3.31.3 — Extended practice task 2
#
# **Website locator:** Exercise 3.31.3

# %% [markdown]
# Write one directional expectation that could be checked descriptively without claiming causation.

# %% [markdown]
# ## Exercise 3.31.4 — Extended practice task 3
#
# **Website locator:** Exercise 3.31.4

# %% [markdown]
# Create a five-column analysis plan: question, variables, subset, calculation, limitation.

# %% [markdown]
# ## Exercise 3.31.5 — Extended practice task 4
#
# **Website locator:** Exercise 3.31.5

# %% [markdown]
# After running one exploratory summary, record one new question that emerged and label it explicitly as post-hoc.

# %% [markdown]
# ## Exercise 3.31.6 — Extended practice task 5
#
# **Website locator:** Exercise 3.31.6

# %% [markdown]
# Explain why an exploratory pattern should not automatically be reported as a confirmed hypothesis.

# %% [markdown]
# ## Exercise 3.31.7 — Explain it without code
#
# **Website locator:** Exercise 3.31.7

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.31.8 — Small transfer task
#
# **Website locator:** Exercise 3.31.8

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.32 — Descriptive statistics

# %% [markdown]
# ## Exercise 3.32.10 — Try it yourself
#
# **Website locator:** Exercise 3.32.10

# %% [markdown]
# For `resolution_days`, print:
#
# - count;
# - mean;
# - median;
# - minimum;
# - maximum;
# - standard deviation.
#
# <details>
# <summary>Solution</summary>
#
# ```python

# %% [markdown]
# ## Exercise 3.32.11 — Extended practice task 1
#
# **Website locator:** Exercise 3.32.11

# %% [markdown]
# Calculate mean and median `resolution_days` and compare them.

# %% [markdown]
# ## Exercise 3.32.12 — Extended practice task 2
#
# **Website locator:** Exercise 3.32.12

# %% [markdown]
# Count valid satisfaction observations before calculating an average.

# %% [markdown]
# ## Exercise 3.32.13 — Extended practice task 3
#
# **Website locator:** Exercise 3.32.13

# %% [markdown]
# Inspect the minimum and maximum values for each numeric indicator and connect them to Lecture 6 quality flags.

# %% [markdown]
# ## Exercise 3.32.14 — Extended practice task 4
#
# **Website locator:** Exercise 3.32.14

# %% [markdown]
# Calculate standard deviation for one variable and explain in ordinary language what larger versus smaller spread means.

# %% [markdown]
# ## Exercise 3.32.15 — Extended practice task 5
#
# **Website locator:** Exercise 3.32.15

# %% [markdown]
# Write a three-sentence result that reports a summary, the valid N and one limitation.

# %% [markdown]
# ## Exercise 3.32.16 — Explain it without code
#
# **Website locator:** Exercise 3.32.16

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.32.17 — Small transfer task
#
# **Website locator:** Exercise 3.32.17

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.33 — Frequencies, proportions and category summaries

# %% [markdown]
# ## Exercise 3.33.8 — Try it yourself
#
# **Website locator:** Exercise 3.33.8

# %% [markdown]
# Create `repeat_contact_rate_pct` using:
#
# ```text
# repeat_contacts / cases_received × 100
# ```
#
# only where `cases_received > 0`.
#
# <details>
# <summary>Solution</summary>
#
# ```python

# %% [markdown]
# ## Exercise 3.33.9 — Extended practice task 1
#
# **Website locator:** Exercise 3.33.9

# %% [markdown]
# Calculate service-type frequencies as counts and percentages.

# %% [markdown]
# ## Exercise 3.33.10 — Extended practice task 2
#
# **Website locator:** Exercise 3.33.10

# %% [markdown]
# Compare city frequencies and decide whether the dataset design creates equal numbers of service-month observations.

# %% [markdown]
# ## Exercise 3.33.11 — Extended practice task 3
#
# **Website locator:** Exercise 3.33.11

# %% [markdown]
# Calculate complaint rate per 100 received cases and explain the denominator.

# %% [markdown]
# ## Exercise 3.33.12 — Extended practice task 4
#
# **Website locator:** Exercise 3.33.12

# %% [markdown]
# Create a second plausible rate with a different denominator and explain how its meaning changes.

# %% [markdown]
# ## Exercise 3.33.13 — Extended practice task 5
#
# **Website locator:** Exercise 3.33.13

# %% [markdown]
# Write a short warning about comparing raw complaint counts across differently sized services.

# %% [markdown]
# ## Exercise 3.33.14 — Explain it without code
#
# **Website locator:** Exercise 3.33.14

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.33.15 — Small transfer task
#
# **Website locator:** Exercise 3.33.15

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.34 — Grouping and aggregation with `groupby()`

# %% [markdown]
# ## Exercise 3.34.6 — Try it yourself
#
# **Website locator:** Exercise 3.34.6

# %% [markdown]
# Create a city-level table with:
#
# - total cases received;
# - total complaints;
# - mean resolution days;
# - number of records.
#
# <details>
# <summary>Solution</summary>
#
# ```python

# %% [markdown]
# ## Exercise 3.34.7 — Extended practice task 1
#
# **Website locator:** Exercise 3.34.7

# %% [markdown]
# Calculate mean satisfaction by `service_type`.

# %% [markdown]
# ## Exercise 3.34.8 — Extended practice task 2
#
# **Website locator:** Exercise 3.34.8

# %% [markdown]
# Calculate median resolution days by `city`.

# %% [markdown]
# ## Exercise 3.34.9 — Extended practice task 3
#
# **Website locator:** Exercise 3.34.9

# %% [markdown]
# Use `.agg()` to report count, mean and median together.

# %% [markdown]
# ## Exercise 3.34.10 — Extended practice task 4
#
# **Website locator:** Exercise 3.34.10

# %% [markdown]
# Group by both city and service type, then use `reset_index()` to make the result easy to read.

# %% [markdown]
# ## Exercise 3.34.11 — Extended practice task 5
#
# **Website locator:** Exercise 3.34.11

# %% [markdown]
# Choose one group difference and list three alternative explanations that the grouped table alone cannot distinguish.

# %% [markdown]
# ## Exercise 3.34.12 — Explain it without code
#
# **Website locator:** Exercise 3.34.12

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.34.13 — Small transfer task
#
# **Website locator:** Exercise 3.34.13

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.35 — Comparing groups carefully

# %% [markdown]
# ## Exercise 3.35.5 — Try it yourself
#
# **Website locator:** Exercise 3.35.5

# %% [markdown]
# Compare `total_cases`, `total_complaints` and aggregate `complaint_rate_pct` by city.
#
# <details>
# <summary>Solution</summary>
#
# ```python

# %% [markdown]
# ## Exercise 3.35.6 — Extended practice task 1
#
# **Website locator:** Exercise 3.35.6

# %% [markdown]
# Compute an unweighted mean of row-level resolution rates by service type.

# %% [markdown]
# ## Exercise 3.35.7 — Extended practice task 2
#
# **Website locator:** Exercise 3.35.7

# %% [markdown]
# Compute an aggregate resolution rate from summed resolved and received cases.

# %% [markdown]
# ## Exercise 3.35.8 — Extended practice task 3
#
# **Website locator:** Exercise 3.35.8

# %% [markdown]
# Compare the two results and explain why they differ.

# %% [markdown]
# ## Exercise 3.35.9 — Extended practice task 4
#
# **Website locator:** Exercise 3.35.9

# %% [markdown]
# Create a comparison table with at least three indicators instead of one ranking score.

# %% [markdown]
# ## Exercise 3.35.10 — Extended practice task 5
#
# **Website locator:** Exercise 3.35.10

# %% [markdown]
# Write a caption that describes the comparison without declaring a 'best' service.

# %% [markdown]
# ## Exercise 3.35.11 — Explain it without code
#
# **Website locator:** Exercise 3.35.11

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.35.12 — Small transfer task
#
# **Website locator:** Exercise 3.35.12

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.36 — Filtering for targeted questions

# %% [markdown]
# ## Exercise 3.36.11 — Try it yourself
#
# **Website locator:** Exercise 3.36.11

# %% [markdown]
# Create a subset containing:
#
# - Aalborg records;
# - satisfaction between 1 and 5;
# - resolution days above 10.
#
# <details>
# <summary>Solution</summary>
#
# ```python

# %% [markdown]
# ## Exercise 3.36.12 — Extended practice task 1
#
# **Website locator:** Exercise 3.36.12

# %% [markdown]
# Filter the dataset to one city and inspect the resulting row count.

# %% [markdown]
# ## Exercise 3.36.13 — Extended practice task 2
#
# **Website locator:** Exercise 3.36.13

# %% [markdown]
# Create an AND filter for one city and one service type.

# %% [markdown]
# ## Exercise 3.36.14 — Extended practice task 3
#
# **Website locator:** Exercise 3.36.14

# %% [markdown]
# Create an OR filter for two service types.

# %% [markdown]
# ## Exercise 3.36.15 — Extended practice task 4
#
# **Website locator:** Exercise 3.36.15

# %% [markdown]
# Filter to high complaint-rate records and inspect the original raw indicators behind the rate.

# %% [markdown]
# ## Exercise 3.36.16 — Extended practice task 5
#
# **Website locator:** Exercise 3.36.16

# %% [markdown]
# Create a measure-specific valid subset using a quality flag and report how many rows were excluded.

# %% [markdown]
# ## Exercise 3.36.17 — Explain it without code
#
# **Website locator:** Exercise 3.36.17

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.36.18 — Small transfer task
#
# **Website locator:** Exercise 3.36.18

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.37 — Exploring change over time

# %% [markdown]
# ## Exercise 3.37.9 — Try it yourself
#
# **Website locator:** Exercise 3.37.9

# %% [markdown]
# Create a monthly table with:
#
# - total cases;
# - total resolved cases;
# - aggregate resolution rate.
#
# <details>
# <summary>Solution</summary>
#
# ```python

# %% [markdown]
# ## Exercise 3.37.10 — Extended practice task 1
#
# **Website locator:** Exercise 3.37.10

# %% [markdown]
# Confirm that `report_month` is parsed as datetime and sort the dataset chronologically.

# %% [markdown]
# ## Exercise 3.37.11 — Extended practice task 2
#
# **Website locator:** Exercise 3.37.11

# %% [markdown]
# Calculate monthly total `cases_received`.

# %% [markdown]
# ## Exercise 3.37.12 — Extended practice task 3
#
# **Website locator:** Exercise 3.37.12

# %% [markdown]
# Calculate monthly complaint rate from summed counts.

# %% [markdown]
# ## Exercise 3.37.13 — Extended practice task 4
#
# **Website locator:** Exercise 3.37.13

# %% [markdown]
# Create a monthly-by-service summary and identify one visible fluctuation.

# %% [markdown]
# ## Exercise 3.37.14 — Extended practice task 5
#
# **Website locator:** Exercise 3.37.14

# %% [markdown]
# Write two versions of a result sentence: one overconfident and one appropriately bounded to the observed six-month period.

# %% [markdown]
# ## Exercise 3.37.15 — Explain it without code
#
# **Website locator:** Exercise 3.37.15

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.37.16 — Small transfer task
#
# **Website locator:** Exercise 3.37.16

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.38 — Word frequencies with NLTK

# %% [markdown]
# ## Exercise 3.38.12 — Try it yourself
#
# **Website locator:** Exercise 3.38.12

# %% [markdown]
# Find the 15 most common cleaned feedback words and convert them to a DataFrame.
#
# <details>
# <summary>Solution</summary>
#
# ```python

# %% [markdown]
# ## Exercise 3.38.13 — Extended practice task 1
#
# **Website locator:** Exercise 3.38.13

# %% [markdown]
# Build a `FreqDist` from prepared feedback tokens and show the 15 most common words.

# %% [markdown]
# ## Exercise 3.38.14 — Extended practice task 2
#
# **Website locator:** Exercise 3.38.14

# %% [markdown]
# Calculate the total number of tokens and number of unique tokens.

# %% [markdown]
# ## Exercise 3.38.15 — Extended practice task 3
#
# **Website locator:** Exercise 3.38.15

# %% [markdown]
# Convert the top frequencies to a DataFrame suitable for plotting.

# %% [markdown]
# ## Exercise 3.38.16 — Extended practice task 4
#
# **Website locator:** Exercise 3.38.16

# %% [markdown]
# Choose one frequent word and retrieve the original feedback rows containing it.

# %% [markdown]
# ## Exercise 3.38.17 — Extended practice task 5
#
# **Website locator:** Exercise 3.38.17

# %% [markdown]
# Write a short interpretation that distinguishes word frequency from user sentiment.

# %% [markdown]
# ## Exercise 3.38.18 — Explain it without code
#
# **Website locator:** Exercise 3.38.18

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.38.19 — Small transfer task
#
# **Website locator:** Exercise 3.38.19

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.39 — Optional bigrams and short phrases

# %% [markdown]
# ## Exercise 3.39.6 — Try it yourself
#
# **Website locator:** Exercise 3.39.6

# %% [markdown]
# Generate the 10 most common bigrams from the feedback, ensuring that pairs do not cross row boundaries.
#
# <details>
# <summary>Solution</summary>
#
# ```python

# %% [markdown]
# ## Exercise 3.39.7 — Extended practice task 1
#
# **Website locator:** Exercise 3.39.7

# %% [markdown]
# Create bigrams for one feedback sentence and print them.

# %% [markdown]
# ## Exercise 3.39.8 — Extended practice task 2
#
# **Website locator:** Exercise 3.39.8

# %% [markdown]
# Create bigrams separately within every feedback row.

# %% [markdown]
# ## Exercise 3.39.9 — Extended practice task 3
#
# **Website locator:** Exercise 3.39.9

# %% [markdown]
# Count the most common bigrams and convert them to readable strings.

# %% [markdown]
# ## Exercise 3.39.10 — Extended practice task 4
#
# **Website locator:** Exercise 3.39.10

# %% [markdown]
# Deliberately flatten tokens before making bigrams and identify at least one cross-record artefact.

# %% [markdown]
# ## Exercise 3.39.11 — Extended practice task 5
#
# **Website locator:** Exercise 3.39.11

# %% [markdown]
# Explain one advantage and one limitation of bigrams compared with single-word frequencies.

# %% [markdown]
# ## Exercise 3.39.12 — Explain it without code
#
# **Website locator:** Exercise 3.39.12

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.39.13 — Small transfer task
#
# **Website locator:** Exercise 3.39.13

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.40 — Comparing language across groups

# %% [markdown]
# ## Exercise 3.40.9 — Try it yourself
#
# **Website locator:** Exercise 3.40.9

# %% [markdown]
# Compare `helpful` and `confusing` across any two service types. Report both raw counts and frequency per 1,000 tokens.
#
# <details>
# <summary>Solution pattern</summary>
#
# ```python

# %% [markdown]
# ## Exercise 3.40.10 — Extended practice task 1
#
# **Website locator:** Exercise 3.40.10

# %% [markdown]
# Create two service-specific subsets and count total tokens in each.

# %% [markdown]
# ## Exercise 3.40.11 — Extended practice task 2
#
# **Website locator:** Exercise 3.40.11

# %% [markdown]
# Compare raw frequency of one selected word.

# %% [markdown]
# ## Exercise 3.40.12 — Extended practice task 3
#
# **Website locator:** Exercise 3.40.12

# %% [markdown]
# Convert both frequencies to occurrences per 1,000 tokens.

# %% [markdown]
# ## Exercise 3.40.13 — Extended practice task 4
#
# **Website locator:** Exercise 3.40.13

# %% [markdown]
# Retrieve sample comments from both groups containing that word.

# %% [markdown]
# ## Exercise 3.40.14 — Extended practice task 5
#
# **Website locator:** Exercise 3.40.14

# %% [markdown]
# Write a cautious comparative statement that does not label a group as more positive or negative without a validated sentiment method.

# %% [markdown]
# ## Exercise 3.40.15 — Explain it without code
#
# **Website locator:** Exercise 3.40.15

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.40.16 — Small transfer task
#
# **Website locator:** Exercise 3.40.16

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.41 — Choosing a suitable visualisation

# %% [markdown]
# ## Exercise 3.41.1 — Try it yourself
#
# **Website locator:** Exercise 3.41.1

# %% [markdown]
# Choose a chart type for each question:
#
# 1. How did total case volume change over six months?
# 2. Which service types have the highest complaint rate?
# 3. Is longer resolution time associated with lower satisfaction?
# 4. Which 15 processed feedback words occur most often?
#
# <details>
# <summary>Suggested answers</summary>
#
# 1. Line chart.
# 2. Bar chart.
# 3. Scatter plot.
# 4. Horizontal bar chart.
#
# </details>
#
# [VISUAL / SCREENSHOT]
# Create a “choose your chart” decision graphic with four paths: categories → bar; time → line; two numeric variables → scatter; word frequencies → horizontal bar.
#
# ---

# %% [markdown]
# ## Exercise 3.41.2 — Extended practice task 1
#
# **Website locator:** Exercise 3.41.2

# %% [markdown]
# Match five analytical questions to bar, line or scatter charts and justify each choice.

# %% [markdown]
# ## Exercise 3.41.3 — Extended practice task 2
#
# **Website locator:** Exercise 3.41.3

# %% [markdown]
# Sketch the axes for a bar chart of mean satisfaction by service type before coding it.

# %% [markdown]
# ## Exercise 3.41.4 — Extended practice task 3
#
# **Website locator:** Exercise 3.41.4

# %% [markdown]
# Create one intentionally misleading chart by truncating an axis, then repair it and explain the difference.

# %% [markdown]
# ## Exercise 3.41.5 — Extended practice task 4
#
# **Website locator:** Exercise 3.41.5

# %% [markdown]
# Rewrite a vague chart title so it states the measure, grouping and time scope.

# %% [markdown]
# ## Exercise 3.41.6 — Extended practice task 5
#
# **Website locator:** Exercise 3.41.6

# %% [markdown]
# Identify one case where a table would communicate the result more clearly than a chart.

# %% [markdown]
# ## Exercise 3.41.7 — Explain it without code
#
# **Website locator:** Exercise 3.41.7

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.41.8 — Small transfer task
#
# **Website locator:** Exercise 3.41.8

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.42 — Bar and line charts

# %% [markdown]
# ## Exercise 3.42.15 — Try it yourself
#
# **Website locator:** Exercise 3.42.15

# %% [markdown]
# Make a horizontal bar chart of aggregate complaint rate by city.
#
# <details>
# <summary>Solution</summary>
#
# ```python

# %% [markdown]
# ## Exercise 3.42.16 — Extended practice task 1
#
# **Website locator:** Exercise 3.42.16

# %% [markdown]
# Create a bar chart of mean satisfaction by service type and inspect the summary table first.

# %% [markdown]
# ## Exercise 3.42.17 — Extended practice task 2
#
# **Website locator:** Exercise 3.42.17

# %% [markdown]
# Create a horizontal bar chart of the 10 most frequent prepared feedback words.

# %% [markdown]
# ## Exercise 3.42.18 — Extended practice task 3
#
# **Website locator:** Exercise 3.42.18

# %% [markdown]
# Create a line chart of monthly complaint rate using aggregated numerators and denominators.

# %% [markdown]
# ## Exercise 3.42.19 — Extended practice task 4
#
# **Website locator:** Exercise 3.42.19

# %% [markdown]
# Modify one chart title and axis label so the units are explicit.

# %% [markdown]
# ## Exercise 3.42.20 — Extended practice task 5
#
# **Website locator:** Exercise 3.42.20

# %% [markdown]
# Create a deliberately overcrowded multi-line chart, then reduce or reorganise it to improve readability.

# %% [markdown]
# ## Exercise 3.42.21 — Explain it without code
#
# **Website locator:** Exercise 3.42.21

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.42.22 — Small transfer task
#
# **Website locator:** Exercise 3.42.22

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.43 — Scatter plots, relationships and causal caution

# %% [markdown]
# ## Exercise 3.43.6 — Try it yourself
#
# **Website locator:** Exercise 3.43.6

# %% [markdown]
# Create a scatter plot of `staff_hours` against `cases_received` for valid positive values. Then write two sentences:
#
# 1. what the plot appears to show;
# 2. what it does not prove.
#
# <details>
# <summary>Solution pattern</summary>
#
# ```python

# %% [markdown]
# ## Exercise 3.43.7 — Extended practice task 1
#
# **Website locator:** Exercise 3.43.7

# %% [markdown]
# Create a scatter plot of `resolution_days` and `satisfaction_score` using measure-valid rows.

# %% [markdown]
# ## Exercise 3.43.8 — Extended practice task 2
#
# **Website locator:** Exercise 3.43.8

# %% [markdown]
# Calculate Pearson correlation as an optional descriptive measure.

# %% [markdown]
# ## Exercise 3.43.9 — Extended practice task 3
#
# **Website locator:** Exercise 3.43.9

# %% [markdown]
# Identify the most extreme resolution-time point and inspect its full record.

# %% [markdown]
# ## Exercise 3.43.10 — Extended practice task 4
#
# **Website locator:** Exercise 3.43.10

# %% [markdown]
# Recalculate the correlation with and without that point only as a sensitivity exercise, not as a reason to delete it.

# %% [markdown]
# ## Exercise 3.43.11 — Extended practice task 5
#
# **Website locator:** Exercise 3.43.11

# %% [markdown]
# Write one association statement and one causal statement; explain why only the first is supported by this dataset.

# %% [markdown]
# ## Exercise 3.43.12 — Explain it without code
#
# **Website locator:** Exercise 3.43.12

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.43.13 — Small transfer task
#
# **Website locator:** Exercise 3.43.13

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# # Tutorial 3.44 — Integrated analysis: analyse, visualise, interpret and report

# %% [markdown]
# ## Exercise 3.44.1 — Extended practice task 1
#
# **Website locator:** Exercise 3.44.1

# %% [markdown]
# Formulate one bounded analytical question and one simple expectation.

# %% [markdown]
# ## Exercise 3.44.2 — Extended practice task 2
#
# **Website locator:** Exercise 3.44.2

# %% [markdown]
# Produce a transparent service or city summary containing counts and at least two indicators.

# %% [markdown]
# ## Exercise 3.44.3 — Extended practice task 3
#
# **Website locator:** Exercise 3.44.3

# %% [markdown]
# Create one structured-data visualisation and one text-oriented visualisation.

# %% [markdown]
# ## Exercise 3.44.4 — Extended practice task 4
#
# **Website locator:** Exercise 3.44.4

# %% [markdown]
# Return to original feedback comments to contextualise at least one text-frequency pattern.

# %% [markdown]
# ## Exercise 3.44.5 — Extended practice task 5
#
# **Website locator:** Exercise 3.44.5

# %% [markdown]
# Write a 500–800 word mini-report with methods, results, limitations and a clear distinction between observation and explanation.

# %% [markdown]
# ## Exercise 3.44.6 — Explain it without code
#
# **Website locator:** Exercise 3.44.6

# %% [markdown]
# After completing the tasks, write a short explanation of the tutorial for a classmate who has never programmed. Your explanation should name the **data question**, the **Python operation**, the **output**, and at least one **limitation or assumption**.

# %% [markdown]
# ## Exercise 3.44.7 — Small transfer task
#
# **Website locator:** Exercise 3.44.7

# %% [markdown]
# Change the example so that it works with a different column, category or analytical question from the same course dataset. Do not copy the code blindly: write one sentence before the code stating what you expect to happen, and one sentence afterwards stating whether the result matched the expectation.
#
# <details>
# <summary>Self-check before moving on</summary>
#
# You are ready to continue when you can:
#
# - explain the main operation in ordinary language;
# - identify which input columns or text are being used;
# - run the relevant notebook cell from a fresh runtime;
# - interpret the main output;
# - change one parameter or variable deliberately;
# - recognise at least one likely error or misleading interpretation;
# - explain why the operation is appropriate for this particular task.
#
# </details>
#
# ---

# %% [markdown]
# ## Exercise 3.44.8 — Define the analytical question
#
# **Website locator:** Exercise 3.44.8

# %% [markdown]
# Write:
#
# - one main descriptive question;
# - one smaller exploratory question;
# - one simple expectation;
# - the unit of observation;
# - the variables needed;
# - the quality flags relevant to those variables.
#
# Examples of appropriately bounded questions include:
#
# - How do observed satisfaction and resolution-time summaries differ across service types in the six-month dataset?
# - How does the aggregate complaint rate change across the observed reporting months?
# - Which prepared feedback words are most frequent, and in which original comments do they occur?
#
# Avoid causal questions such as “Does digital service cause higher satisfaction?” because this dataset was not designed for causal identification.

# %% [markdown]
# ## Exercise 3.44.9 — Build a transparent analysis table
#
# **Website locator:** Exercise 3.44.9

# %% [markdown]
# Create a grouped summary containing:
#
# - valid record count;
# - total cases received;
# - total complaints;
# - aggregate complaint rate;
# - valid satisfaction count;
# - mean satisfaction;
# - median satisfaction;
# - mean or median resolution days.
#
# Display the table before creating a chart.

# %% [markdown]
# ## Exercise 3.44.10 — Compare at least two grouping choices
#
# **Website locator:** Exercise 3.44.10

# %% [markdown]
# Produce:
#
# 1. one service-type summary;
# 2. one city summary or city × service summary.
#
# For one percentage/rate, compare an unweighted row average with an aggregate ratio and explain why they are not necessarily identical.

# %% [markdown]
# ## Exercise 3.44.11 — Create one temporal analysis
#
# **Website locator:** Exercise 3.44.11

# %% [markdown]
# Aggregate data by reporting month and create one time-oriented indicator, for example:
#
# - total cases received;
# - aggregate complaint rate;
# - mean resolution days among valid records.
#
# Plot the result as a line chart and describe the observed six-month pattern without using long-term trend language.

# %% [markdown]
# ## Exercise 3.44.12 — Create one structured-data visualisation
#
# **Website locator:** Exercise 3.44.12

# %% [markdown]
# Create a bar chart or another justified chart from a summary table. The chart must include:
#
# - an informative title;
# - clear axis labels;
# - readable category labels;
# - a scale that does not exaggerate small differences;
# - a caption/paragraph explaining what one bar or point represents.

# %% [markdown]
# ## Exercise 3.44.13 — Add introductory text analysis
#
# **Website locator:** Exercise 3.44.13

# %% [markdown]
# Using the prepared feedback:
#
# 1. recreate tokens if needed;
# 2. calculate the most frequent words;
# 3. optionally calculate bigrams;
# 4. choose one or two interesting tokens/phrases;
# 5. return to the original feedback rows containing them;
# 6. explain why frequency is not the same as sentiment or importance.
#
# If comparing language across groups, use a token denominator rather than raw counts alone.

# %% [markdown]
# ## Exercise 3.44.14 — Add one relationship plot
#
# **Website locator:** Exercise 3.44.14

# %% [markdown]
# Create a scatter plot for two numeric variables that make conceptual sense, for example `resolution_days` and `satisfaction_score`.
#
# Optionally calculate a Pearson correlation. If you do:
#
# - report the valid N;
# - inspect extreme points;
# - describe it as an association;
# - do not say that one variable causes the other.

# %% [markdown]
# ## Exercise 3.44.15 — Write the report
#
# **Website locator:** Exercise 3.44.15

# %% [markdown]
# A compact report should contain:
#
# ### Question and scope
# What are you asking, over which months and unit of observation?
#
# ### Data preparation
# Which Lecture 6 cleaned dataset is used and which quality flags matter?
#
# ### Methods
# Which summary, rate, grouping, text count and visualisation did you use?
#
# ### Findings
# What patterns are visible?
#
# ### Interpretation
# What is a reasonable interpretation of those patterns?
#
# ### Limitations
# What does the dataset not establish? What may be affected by missingness, aggregation or measurement choices?
#
# ### Next step
# What additional evidence would you want before making a stronger organisational or societal claim?

# %% [markdown]
# ---
#
# # Cumulative self-test — Lecture 7
#
# The Python Foundations tutorials finish with a cumulative self-test rather than treating each tutorial as an isolated topic. Lecture 7 follows the same formation. This self-test deliberately mixes ideas from several tutorials because real data work rarely announces which single command you need.
#
# **How to use it**
#
# 1. Attempt the questions without copying code from the tutorial.
# 2. For code-reading questions, predict the result before running anything.
# 3. For judgement questions, explain *why* you would make a decision, not only what command you would use.
# 4. Mark any question you cannot explain in ordinary language and return to the matching tutorial.
# 5. Only after attempting the full set, open the answer section in the Lecture 7 Exercises notebook.
#
# **Self-test and answer key:** [Open in Google Colab](https://colab.research.google.com/github/asmrabbi/E26_TAN7_Scripting_CPH/blob/main/notebooks/lecture_07/L07_Tutorial_3_30_to_3_44_Exercises.ipynb) · [View on GitHub](https://github.com/asmrabbi/E26_TAN7_Scripting_CPH/blob/main/notebooks/lecture_07/L07_Tutorial_3_30_to_3_44_Exercises.ipynb)
#
# The website should show the questions below. The detailed suggested answers belong in the Exercises notebook so students can attempt the test before seeing them.
#
# <!-- SELFTEST_START -->
#
# ## A. Questions, scope and units of analysis
#
# 1. Why should an analytical question be written before choosing a chart?
#
# 2. What is the unit of observation in the recurring Lecture 7 dataset?
#
# 3. Explain the difference between exploratory analysis and question-driven analysis.
#
# 4. Why should unresolved Lecture 6 quality flags be inspected before computing a summary?
#
# 5. Why can the dataset describe patterns in service records but not automatically measure broad concepts such as institutional trust?
#
# ## B. Descriptive statistics, frequencies and denominators
#
# 6. When would the median be more informative than the mean?
#
# 7. Why should you report the number of valid observations alongside an average satisfaction score?
#
# 8. What is the difference between a count and a proportion?
#
# 9. Why must a rate always have a clearly stated denominator?
#
# 10. If City A has 20 complaints and City B has 15, why can you not immediately conclude that City A performs worse?
#
# ## C. Grouping, aggregation and comparison
#
# 11. What does `groupby()` conceptually do before an aggregation is calculated?
#
# 12. Why can an unweighted mean of service-month satisfaction differ from a case-weighted mean?
#
# 13. Give an example of a grouping choice that could hide variation.
#
# 14. Why should you inspect the grouped table before plotting it?
#
# 15. What is the risk of comparing groups with very different numbers of observations without reporting those counts?
#
# ## D. Filtering and temporal analysis
#
# 16. What is Boolean filtering used for in pandas?
#
# 17. Why should a filter be visible in the same worked example as the calculation it supports?
#
# 18. What extra caution is needed when interpreting six months of service data as a time trend?
#
# 19. Why should dates be stored as actual datetime values for temporal grouping?
#
# 20. A line chart rises sharply in one month. Name two things you should inspect before explaining the increase.
#
# ## E. Introductory text analysis
#
# 21. What does a word-frequency table show?
#
# 22. Why should frequent words be traced back to original feedback comments?
#
# 23. What is a bigram?
#
# 24. Why is comparing raw word counts between cities potentially misleading?
#
# 25. Why is the prepared text column not a replacement for qualitative reading?
#
# ## F. Visualisation choices
#
# 26. When is a bar chart generally suitable in this lecture?
#
# 27. When is a line chart generally suitable?
#
# 28. Why is a scatter plot useful for resolution days and satisfaction score?
#
# 29. Why should axes and titles be labelled with the actual measure being shown?
#
# 30. Why should you avoid deleting an unusual point merely because it makes a chart look untidy?
#
# ## G. Association, correlation and interpretation
#
# 31. What does a negative correlation between resolution days and satisfaction score mean descriptively?
#
# 32. Why does correlation not establish causation?
#
# 33. A chart shows Copenhagen with a higher mean satisfaction than Aalborg. Write one safe descriptive sentence.
#
# 34. What is the difference between an observation and an explanation?
#
# 35. Why is `What does this output not establish?` a required interpretation prompt in this course?
#
# ## H. Integrated Lecture 5–7 reasoning
#
# 36. You want to compare complaint rates across cities. Describe the minimum analysis pipeline from cleaned data to interpretation.
#
# 37. You find that one service type has many more feedback comments than the others. How should that affect a cross-service word-frequency comparison?
#
# 38. Why can two reasonable analysts produce different but defensible summaries from the same cleaned dataset?
#
# 39. What should a short reproducible analysis report contain in this course?
#
# 40. Describe the complete learning arc from Lecture 5 through Lecture 7.
#
# <!-- SELFTEST_END -->
#
#
# ---

# %% [markdown]
# ---
#
# # Cumulative self-test answer key
#
# Attempt the complete self-test before reading the answer key below.

# %% [markdown]
# Attempt the complete self-test before reading this section. These are suggested answers, not wording that must be memorised. For judgement questions, another answer can be reasonable if it is transparent, technically sound and justified by the data context.
#
# ## A. Questions, scope and units of analysis
#
# **1. Suggested answer**
# The question determines which variables, rows, grouping and denominator are relevant. Choosing a chart first can encourage pattern hunting without a clear analytical purpose.
#
# **2. Suggested answer**
# One row represents one service category in one city during one reporting month. Therefore row-level means are means across service-city-month records unless explicitly weighted otherwise.
#
# **3. Suggested answer**
# Exploratory analysis searches for patterns and irregularities without a single fixed expectation. Question-driven analysis starts from a bounded question or expectation and selects calculations specifically to address it.
#
# **4. Suggested answer**
# Different measures may require different valid subsets. A row flagged for an invalid satisfaction score might still be usable for case counts, so the analysis should define inclusion rules rather than ignoring flags.
#
# **5. Suggested answer**
# The available variables are operational indicators with limited meanings. Broad theoretical concepts require additional evidence and justification; a satisfaction score or comment frequency is not equivalent to trust.
#
# ## B. Descriptive statistics, frequencies and denominators
#
# **6. Suggested answer**
# When a numeric distribution is skewed or contains extreme values, the median is less affected by those extremes and can better describe a typical central position.
#
# **7. Suggested answer**
# The mean can be misleading if many scores are missing or invalid. Reporting `n` shows how much data contributed to the statistic.
#
# **8. Suggested answer**
# A count reports how many observations meet a condition. A proportion divides that count by a relevant total, allowing comparisons when groups have different sizes.
#
# **9. Suggested answer**
# The denominator defines what the rate is relative to. Without it, readers cannot interpret or compare the value correctly.
#
# **10. Suggested answer**
# The cities may have different case volumes, service mixes or reporting practices. Complaint rates relative to cases and contextual differences should be considered before interpretation.
#
# ## C. Grouping, aggregation and comparison
#
# **11. Suggested answer**
# It partitions rows into groups defined by one or more keys, such as city or service type. An aggregation such as mean or sum is then calculated within each group.
#
# **12. Suggested answer**
# The unweighted mean gives every row equal influence, while a weighted mean gives records with more cases greater influence. They answer different questions.
#
# **13. Suggested answer**
# A city-level average can hide differences among service types or months. Similarly, a service-level average can hide geographic variation.
#
# **14. Suggested answer**
# The table exposes the actual aggregated values, missing groups and denominators. It makes the chart auditable and helps detect aggregation errors before visual interpretation.
#
# **15. Suggested answer**
# A small group may produce an unstable or unrepresentative average. Counts help readers judge how much evidence lies behind each summary.
#
# ## D. Filtering and temporal analysis
#
# **16. Suggested answer**
# It creates a subset containing rows that meet explicit conditions, such as valid satisfaction scores or a selected city and service. The filter should be documented because it defines the analysis sample.
#
# **17. Suggested answer**
# Students and readers can see exactly which records were included. Hidden earlier filtering makes the output difficult to reproduce and interpret.
#
# **18. Suggested answer**
# Six observations per series provide only a short descriptive window. Apparent increases or decreases may be temporary and should not be described as a stable long-term trend.
#
# **19. Suggested answer**
# Datetime values support reliable sorting, extraction of month/year components and time-based grouping. Text dates can sort incorrectly and make invalid values harder to detect.
#
# **20. Suggested answer**
# Inspect the underlying aggregated values and source rows, including case volume and quality flags. Also consider whether the composition of services or missing records changed in that month.
#
# ## E. Introductory text analysis
#
# **21. Suggested answer**
# It counts how often prepared tokens occur in the analysed text corpus. It describes lexical frequency, not importance, sentiment or causal explanation.
#
# **22. Suggested answer**
# The same word can appear in different contexts, including negation or quotation. Returning to original text prevents counts from being interpreted without context.
#
# **23. Suggested answer**
# A bigram is a pair of adjacent tokens. It can provide a little more context than single-word frequencies by showing recurring two-word combinations.
#
# **24. Suggested answer**
# Cities may contribute different amounts of feedback text. A denominator such as total tokens or comments is needed for more meaningful comparison.
#
# **25. Suggested answer**
# Text preparation deliberately removes or transforms information. Frequency analysis can guide attention, but interpretation still requires reading source comments and considering context.
#
# ## F. Visualisation choices
#
# **26. Suggested answer**
# For comparing a numeric summary across discrete categories, such as mean valid satisfaction by service type or complaint rate by city.
#
# **27. Suggested answer**
# For showing an ordered measure across time when the temporal sequence is meaningful, such as monthly case volume.
#
# **28. Suggested answer**
# It displays pairs of numeric observations so the analyst can inspect whether higher or lower values tend to occur together, while also seeing spread and outliers.
#
# **29. Suggested answer**
# Clear labels communicate the unit and aggregation, reducing the risk that readers misinterpret a rate as a count or a mean as an individual value.
#
# **30. Suggested answer**
# The point may be a genuine extreme observation. It should be investigated and, if excluded for a justified reason, the exclusion should be documented.
#
# ## G. Association, correlation and interpretation
#
# **31. Suggested answer**
# In the analysed records, higher resolution times tend to occur with lower satisfaction scores on average. The statistic describes association, not a causal mechanism.
#
# **32. Suggested answer**
# Other variables, selection effects, measurement choices and reverse relationships may produce the association. Correlation alone does not isolate the effect of one variable on another.
#
# **33. Suggested answer**
# For the valid service-city-month records included in this analysis, Copenhagen has a higher mean satisfaction score than Aalborg. The sentence should not claim why the difference exists.
#
# **34. Suggested answer**
# An observation states what the calculated data or chart displays. An explanation proposes reasons for the pattern and therefore requires additional evidence or theory.
#
# **35. Suggested answer**
# It forces the analyst to state boundaries of evidence, preventing descriptive summaries from being expanded into unsupported causal or general claims.
#
# ## H. Integrated Lecture 5–7 reasoning
#
# **36. Suggested answer**
# Inspect relevant quality flags, define valid rows, aggregate complaints and cases by city, calculate complaints/cases with a stated denominator, inspect the summary table, visualise if useful, then describe the pattern and limitations.
#
# **37. Suggested answer**
# Raw counts will favour the service with more text. Use comparable denominators or within-service frequencies and report the amount of text contributing to each comparison.
#
# **38. Suggested answer**
# They may ask different questions, use different justified groupings, denominators, weighting schemes or valid subsets. Transparency allows readers to understand those choices rather than assuming one summary is uniquely correct.
#
# **39. Suggested answer**
# A bounded question, data source/unit, inclusion or quality decisions, code or reproducible steps, inspectable summary tables, appropriate visualisation/text evidence, interpretation, and limitations.
#
# **40. Suggested answer**
# Lecture 5 opens and inspects structured data and provenance; Lecture 6 audits, cleans, flags and prepares structured/text data while documenting decisions; Lecture 7 asks bounded questions, summarises, groups, visualises and interprets the cleaned data while distinguishing evidence from explanation.
