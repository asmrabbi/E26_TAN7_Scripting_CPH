# %% [markdown]
# # Lecture 3 — Tutorial Examples for Python Foundations I
#
# **Website pages:** Tutorials 2.1–2.7
# [Open in Google Colab](https://colab.research.google.com/github/asmrabbi/E26_TAN7_Scripting_CPH/blob/main/notebooks/lecture_03/L03_Tutorial_2_1_to_2_7_Examples.ipynb) · [Course repository](https://github.com/asmrabbi/E26_TAN7_Scripting_CPH)
#
# This notebook contains every Python example shown in the website tutorial, in the same order as the seven website pages. The identifier before each example tells you exactly where it belongs.

# %% [markdown]
# ## Goal
#
# Run, explain and modify every website example without searching across several files.

# %% [markdown]
# ## Setup
#
# No third-party library, dataset, virtual environment or `requirements.txt` file is needed for Lecture 3. The examples use standard Python 3 and can be run in Google Colab, Jupyter Notebook, JupyterLab or PyCharm.
#
# In Colab, choose **Runtime → Run all**. On a local computer, open this notebook in Jupyter or PyCharm and run the cells from top to bottom.

# %% [markdown]
# ## File map
#
# | Website page | Examples in this notebook | Topic |
# |---|---|---|
# | 2.1 | 2.1.1–2.1.5 | Colab, code cells and visible output |
# | 2.2 | 2.2.1–2.2.13 | Values, variables and names |
# | 2.3 | 2.3.1–2.3.11 | Expressions and calculations |
# | 2.4 | 2.4.1–2.4.15 | Foundational data types |
# | 2.5 | 2.5.1–2.5.10 | Conversion and user input |
# | 2.6 | 2.6.1–2.6.10 | Comments and debugging |
# | 2.7 | 2.7.1–2.7.4 | Integration and recap |

# %% [markdown]
# ## Steps
#
# Follow the tutorial pages and run the matching numbered cells below.

# %% [markdown]
# ## Tutorial 2.1 — Colab, code cells and visible output

# %% [markdown]
# ### Tutorial 2.1 reference — Foundation warm-up calculation
#
# **Website subsection:** Tutorial 2.1
# **Website source:** `python-foundations-i.md`, line 24
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# total_records = 250  # Stores the calculated or supplied value in total_records.
# missing_records = 18  # Stores the calculated or supplied value in missing_records.
# complete_records = total_records - missing_records  # Stores the calculated or supplied value in complete_records.
# completion_rate = complete_records / total_records * 100  # Stores the calculated or supplied value in completion_rate.
# print("Completion rate:", completion_rate)  # Displays information so the result can be inspected.
# ```

# %%
total_records = 250  # Stores the calculated or supplied value in total_records.
missing_records = 18  # Stores the calculated or supplied value in missing_records.
complete_records = total_records - missing_records  # Stores the calculated or supplied value in complete_records.
completion_rate = complete_records / total_records * 100  # Stores the calculated or supplied value in completion_rate.
print("Completion rate:", completion_rate)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.1.1 — Run your first code cell
#
# **Website subsection:** Tutorial 2.1
# **Website source:** `python-foundations-i.md`, line 197
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# print("Python is running")  # Displays information so the result can be inspected.
# ```

# %%
print("Python is running")  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.1.2 — Run cells in sequence
#
# **Website subsection:** Tutorial 2.1
# **Website source:** `python-foundations-i.md`, line 242
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# organisation = "North Harbour Council"  # Stores the calculated or supplied value in organisation.
# ```

# %%
organisation = "North Harbour Council"  # Stores the calculated or supplied value in organisation.

# %% [markdown]
# #### Additional runnable cell for Example 2.1.2 — Run cells in sequence — safe diagnostic record
#
# **Website subsection:** Tutorial 2.1
# **Website source:** `python-foundations-i.md`, line 254
# **Status:** Deliberate error or diagnostic example — NameError: name 'organisation' is not defined.
#
# ```python
# print(organisation)  # Displays information so the result can be inspected.
# ```

# %%
example_status = "Example 2.1.2 is labelled deliberate error or diagnostic example: NameError: name 'organisation' is not defined"  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# ### Example 2.1.3 — Display several pieces of information
#
# **Website subsection:** Tutorial 2.1
# **Website source:** `python-foundations-i.md`, line 334
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# print("Dataset status")  # Displays information so the result can be inspected.
# print("Rows received:", 250)  # Displays information so the result can be inspected.
# print("Missing rows:", 18)  # Displays information so the result can be inspected.
# ```

# %%
print("Dataset status")  # Displays information so the result can be inspected.
print("Rows received:", 250)  # Displays information so the result can be inspected.
print("Missing rows:", 18)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.1.4 — Display a small organisational summary
#
# **Website subsection:** Tutorial 2.1
# **Website source:** `python-foundations-i.md`, line 384
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# organisation = "North Harbour Council"  # Stores the calculated or supplied value in organisation.
# responses_received = 480  # Stores the calculated or supplied value in responses_received.
# responses_valid = 452  # Stores the calculated or supplied value in responses_valid.
#
# print("Organisation:", organisation)  # Displays information so the result can be inspected.
# print("Responses received:", responses_received)  # Displays information so the result can be inspected.
# print("Responses retained:", responses_valid)  # Displays information so the result can be inspected.
# print("Responses excluded:", responses_received - responses_valid)  # Displays information so the result can be inspected.
# ```

# %%
organisation = "North Harbour Council"  # Stores the calculated or supplied value in organisation.
responses_received = 480  # Stores the calculated or supplied value in responses_received.
responses_valid = 452  # Stores the calculated or supplied value in responses_valid.

print("Organisation:", organisation)  # Displays information so the result can be inspected.
print("Responses received:", responses_received)  # Displays information so the result can be inspected.
print("Responses retained:", responses_valid)  # Displays information so the result can be inspected.
print("Responses excluded:", responses_received - responses_valid)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.1.5 — Format a readable report with newline characters
#
# **Website subsection:** Tutorial 2.1
# **Website source:** `python-foundations-i.md`, line 442
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# report_title = "Monthly data-quality note"  # Stores the calculated or supplied value in report_title.
# records_checked = 1250  # Stores the calculated or supplied value in records_checked.
#
# print(report_title)  # Displays information so the result can be inspected.
# print("\nRecords checked:", records_checked)  # Displays information so the result can be inspected.
# print("Status:\nReview required")  # Displays information so the result can be inspected.
# ```

# %%
report_title = "Monthly data-quality note"  # Stores the calculated or supplied value in report_title.
records_checked = 1250  # Stores the calculated or supplied value in records_checked.

print(report_title)  # Displays information so the result can be inspected.
print("\nRecords checked:", records_checked)  # Displays information so the result can be inspected.
print("Status:\nReview required")  # Displays information so the result can be inspected.

# %% [markdown]
# ## Tutorial 2.2 — Values, variables and meaningful names

# %% [markdown]
# ### Example 2.2.1 — Use literals directly
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 546
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# print("Consultation responses")  # Displays information so the result can be inspected.
# print(320)  # Displays information so the result can be inspected.
# print(4.5)  # Displays information so the result can be inspected.
# print(True)  # Displays information so the result can be inspected.
# ```

# %%
print("Consultation responses")  # Displays information so the result can be inspected.
print(320)  # Displays information so the result can be inspected.
print(4.5)  # Displays information so the result can be inspected.
print(True)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.2 — Use constants by convention
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 598
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# EXPECTED_COLUMNS = 12  # Stores the calculated or supplied value in EXPECTED_COLUMNS.
# MISSING_LABEL = "Unknown"  # Stores the calculated or supplied value in MISSING_LABEL.
# MAX_PREVIEW_ROWS = 10  # Stores the calculated or supplied value in MAX_PREVIEW_ROWS.
#
# print("Expected columns:", EXPECTED_COLUMNS)  # Displays information so the result can be inspected.
# print("Label for missing category:", MISSING_LABEL)  # Displays information so the result can be inspected.
# print("Maximum preview rows:", MAX_PREVIEW_ROWS)  # Displays information so the result can be inspected.
# ```

# %%
EXPECTED_COLUMNS = 12  # Stores the calculated or supplied value in EXPECTED_COLUMNS.
MISSING_LABEL = "Unknown"  # Stores the calculated or supplied value in MISSING_LABEL.
MAX_PREVIEW_ROWS = 10  # Stores the calculated or supplied value in MAX_PREVIEW_ROWS.

print("Expected columns:", EXPECTED_COLUMNS)  # Displays information so the result can be inspected.
print("Label for missing category:", MISSING_LABEL)  # Displays information so the result can be inspected.
print("Maximum preview rows:", MAX_PREVIEW_ROWS)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.3 — Recognise the risk of unexplained literals
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 653
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# MINIMUM_ACCEPTABLE_COMPLETION = 80  # Stores the calculated or supplied value in MINIMUM_ACCEPTABLE_COMPLETION.
# completion_rate = 76.5  # Stores the calculated or supplied value in completion_rate.
# gap_to_threshold = MINIMUM_ACCEPTABLE_COMPLETION - completion_rate  # Stores the calculated or supplied value in gap_to_threshold.
#
# print("Completion rate:", completion_rate)  # Displays information so the result can be inspected.
# print("Gap to stated threshold:", gap_to_threshold)  # Displays information so the result can be inspected.
# ```

# %%
MINIMUM_ACCEPTABLE_COMPLETION = 80  # Stores the calculated or supplied value in MINIMUM_ACCEPTABLE_COMPLETION.
completion_rate = 76.5  # Stores the calculated or supplied value in completion_rate.
gap_to_threshold = MINIMUM_ACCEPTABLE_COMPLETION - completion_rate  # Stores the calculated or supplied value in gap_to_threshold.

print("Completion rate:", completion_rate)  # Displays information so the result can be inspected.
print("Gap to stated threshold:", gap_to_threshold)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.4 — Assign and display values
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 730
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# city = "Copenhagen"  # Stores the calculated or supplied value in city.
# survey_responses = 275  # Stores the calculated or supplied value in survey_responses.
# average_rating = 4.2  # Stores the calculated or supplied value in average_rating.
#
# print(city)  # Displays information so the result can be inspected.
# print(survey_responses)  # Displays information so the result can be inspected.
# print(average_rating)  # Displays information so the result can be inspected.
# ```

# %%
city = "Copenhagen"  # Stores the calculated or supplied value in city.
survey_responses = 275  # Stores the calculated or supplied value in survey_responses.
average_rating = 4.2  # Stores the calculated or supplied value in average_rating.

print(city)  # Displays information so the result can be inspected.
print(survey_responses)  # Displays information so the result can be inspected.
print(average_rating)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.5 — Reassign a variable
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 785
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# records_reviewed = 0  # Stores the calculated or supplied value in records_reviewed.
# print("Initially reviewed:", records_reviewed)  # Displays information so the result can be inspected.
#
# records_reviewed = 25  # Stores the calculated or supplied value in records_reviewed.
# print("After first batch:", records_reviewed)  # Displays information so the result can be inspected.
#
# records_reviewed = records_reviewed + 10  # Stores the calculated or supplied value in records_reviewed.
# print("After second batch:", records_reviewed)  # Displays information so the result can be inspected.
# ```

# %%
records_reviewed = 0  # Stores the calculated or supplied value in records_reviewed.
print("Initially reviewed:", records_reviewed)  # Displays information so the result can be inspected.

records_reviewed = 25  # Stores the calculated or supplied value in records_reviewed.
print("After first batch:", records_reviewed)  # Displays information so the result can be inspected.

records_reviewed = records_reviewed + 10  # Stores the calculated or supplied value in records_reviewed.
print("After second batch:", records_reviewed)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.6 — Extend an audit trail with `+=`
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 844
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# audit_trail = "File received"  # Stores the calculated or supplied value in audit_trail.
# audit_trail += " -> column names standardised"  # Runs this step from the tutorial example.
# audit_trail += " -> identifiers preserved as text"  # Runs this step from the tutorial example.
#
# print(audit_trail)  # Displays information so the result can be inspected.
# ```

# %%
audit_trail = "File received"  # Stores the calculated or supplied value in audit_trail.
audit_trail += " -> column names standardised"  # Runs this step from the tutorial example.
audit_trail += " -> identifiers preserved as text"  # Runs this step from the tutorial example.

print(audit_trail)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.7 — Derive new variables without losing originals
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 896
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# total_records = 640  # Stores the calculated or supplied value in total_records.
# missing_records = 32  # Stores the calculated or supplied value in missing_records.
# duplicate_records = 8  # Stores the calculated or supplied value in duplicate_records.
#
# usable_records = total_records - missing_records - duplicate_records  # Stores the calculated or supplied value in usable_records.
# usable_percentage = usable_records / total_records * 100  # Stores the calculated or supplied value in usable_percentage.
#
# print("Total records:", total_records)  # Displays information so the result can be inspected.
# print("Usable records:", usable_records)  # Displays information so the result can be inspected.
# print("Usable percentage:", usable_percentage)  # Displays information so the result can be inspected.
# ```

# %%
total_records = 640  # Stores the calculated or supplied value in total_records.
missing_records = 32  # Stores the calculated or supplied value in missing_records.
duplicate_records = 8  # Stores the calculated or supplied value in duplicate_records.

usable_records = total_records - missing_records - duplicate_records  # Stores the calculated or supplied value in usable_records.
usable_percentage = usable_records / total_records * 100  # Stores the calculated or supplied value in usable_percentage.

print("Total records:", total_records)  # Displays information so the result can be inspected.
print("Usable records:", usable_records)  # Displays information so the result can be inspected.
print("Usable percentage:", usable_percentage)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.8 — Use a reserved word inside a meaningful name
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 990
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# class_size = 28  # Stores the calculated or supplied value in class_size.
# return_rate = 91.5  # Stores the calculated or supplied value in return_rate.
# survey_from_students = "completed"  # Stores the calculated or supplied value in survey_from_students.
#
# print("Class size:", class_size)  # Displays information so the result can be inspected.
# print("Return rate:", return_rate)  # Displays information so the result can be inspected.
# print("Survey status:", survey_from_students)  # Displays information so the result can be inspected.
# ```

# %%
class_size = 28  # Stores the calculated or supplied value in class_size.
return_rate = 91.5  # Stores the calculated or supplied value in return_rate.
survey_from_students = "completed"  # Stores the calculated or supplied value in survey_from_students.

print("Class size:", class_size)  # Displays information so the result can be inspected.
print("Return rate:", return_rate)  # Displays information so the result can be inspected.
print("Survey status:", survey_from_students)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.9 — Check whether words are Python keywords
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 1046
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# import keyword  # Imports a module used by this example.
#
# print(keyword.iskeyword("class"))  # Displays information so the result can be inspected.
# print(keyword.iskeyword("records"))  # Displays information so the result can be inspected.
# print(keyword.iskeyword("True"))  # Displays information so the result can be inspected.
# print(keyword.iskeyword("print"))  # Displays information so the result can be inspected.
# ```

# %%
import keyword  # Imports a module used by this example.

print(keyword.iskeyword("class"))  # Displays information so the result can be inspected.
print(keyword.iskeyword("records"))  # Displays information so the result can be inspected.
print(keyword.iskeyword("True"))  # Displays information so the result can be inspected.
print(keyword.iskeyword("print"))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.10 — Avoid hiding a built-in function
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 1100
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# record_type = "Consultation"  # Stores the calculated or supplied value in record_type.
# record_count = 42  # Stores the calculated or supplied value in record_count.
#
# print("Record type:", record_type)  # Displays information so the result can be inspected.
# print("Type of record_count:", type(record_count))  # Displays information so the result can be inspected.
# ```

# %%
record_type = "Consultation"  # Stores the calculated or supplied value in record_type.
record_count = 42  # Stores the calculated or supplied value in record_count.

print("Record type:", record_type)  # Displays information so the result can be inspected.
print("Type of record_count:", type(record_count))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.11 — Use valid snake-case names
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 1206
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# survey_year = 2026  # Stores the calculated or supplied value in survey_year.
# responses_received = 315  # Stores the calculated or supplied value in responses_received.
# missing_response_count = 12  # Stores the calculated or supplied value in missing_response_count.
#
# print("Survey year:", survey_year)  # Displays information so the result can be inspected.
# print("Responses received:", responses_received)  # Displays information so the result can be inspected.
# print("Missing responses:", missing_response_count)  # Displays information so the result can be inspected.
# ```

# %%
survey_year = 2026  # Stores the calculated or supplied value in survey_year.
responses_received = 315  # Stores the calculated or supplied value in responses_received.
missing_response_count = 12  # Stores the calculated or supplied value in missing_response_count.

print("Survey year:", survey_year)  # Displays information so the result can be inspected.
print("Responses received:", responses_received)  # Displays information so the result can be inspected.
print("Missing responses:", missing_response_count)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.12 — Replace vague names with meaningful ones
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 1260
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# total_responses = 500  # Stores the calculated or supplied value in total_responses.
# invalid_responses = 35  # Stores the calculated or supplied value in invalid_responses.
# valid_responses = total_responses - invalid_responses  # Stores the calculated or supplied value in valid_responses.
#
# print("Valid responses:", valid_responses)  # Displays information so the result can be inspected.
# ```

# %%
total_responses = 500  # Stores the calculated or supplied value in total_responses.
invalid_responses = 35  # Stores the calculated or supplied value in invalid_responses.
valid_responses = total_responses - invalid_responses  # Stores the calculated or supplied value in valid_responses.

print("Valid responses:", valid_responses)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.2.13 — Notice case sensitivity
#
# **Website subsection:** Tutorial 2.2
# **Website source:** `python-foundations-i.md`, line 1310
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# records = 120  # Stores the calculated or supplied value in records.
# Records = 15  # Stores the calculated or supplied value in Records.
# RECORDS = 5  # Stores the calculated or supplied value in RECORDS.
#
# print(records)  # Displays information so the result can be inspected.
# print(Records)  # Displays information so the result can be inspected.
# print(RECORDS)  # Displays information so the result can be inspected.
# ```

# %%
records = 120  # Stores the calculated or supplied value in records.
Records = 15  # Stores the calculated or supplied value in Records.
RECORDS = 5  # Stores the calculated or supplied value in RECORDS.

print(records)  # Displays information so the result can be inspected.
print(Records)  # Displays information so the result can be inspected.
print(RECORDS)  # Displays information so the result can be inspected.

# %% [markdown]
# ## Tutorial 2.3 — Expressions, arithmetic and precedence

# %% [markdown]
# ### Example 2.3.1 — Put an expression inside a statement
#
# **Website subsection:** Tutorial 2.3
# **Website source:** `python-foundations-i.md`, line 1408
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# received = 90  # Stores the calculated or supplied value in received.
# excluded = 7  # Stores the calculated or supplied value in excluded.
# print(received - excluded)  # Displays information so the result can be inspected.
# ```

# %%
received = 90  # Stores the calculated or supplied value in received.
excluded = 7  # Stores the calculated or supplied value in excluded.
print(received - excluded)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.3.2 — Store the result of an expression
#
# **Website subsection:** Tutorial 2.3
# **Website source:** `python-foundations-i.md`, line 1456
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# total_records = 300  # Stores the calculated or supplied value in total_records.
# missing_records = 21  # Stores the calculated or supplied value in missing_records.
# complete_records = total_records - missing_records  # Stores the calculated or supplied value in complete_records.
# completion_rate = complete_records / total_records * 100  # Stores the calculated or supplied value in completion_rate.
#
# print("Complete records:", complete_records)  # Displays information so the result can be inspected.
# print("Completion rate:", completion_rate)  # Displays information so the result can be inspected.
# ```

# %%
total_records = 300  # Stores the calculated or supplied value in total_records.
missing_records = 21  # Stores the calculated or supplied value in missing_records.
complete_records = total_records - missing_records  # Stores the calculated or supplied value in complete_records.
completion_rate = complete_records / total_records * 100  # Stores the calculated or supplied value in completion_rate.

print("Complete records:", complete_records)  # Displays information so the result can be inspected.
print("Completion rate:", completion_rate)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.3.3 — Turn a messy field label into a consistent name
#
# **Website subsection:** Tutorial 2.3
# **Website source:** `python-foundations-i.md`, line 1510
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# raw_field_label = "  Preferred TRANSPORT mode  "  # Stores the calculated or supplied value in raw_field_label.
# trimmed_label = raw_field_label.strip()  # Stores the calculated or supplied value in trimmed_label.
# lowercase_label = trimmed_label.lower()  # Stores the calculated or supplied value in lowercase_label.
# field_name = lowercase_label.replace(" ", "_")  # Stores the calculated or supplied value in field_name.
#
# print("Raw label:", raw_field_label)  # Displays information so the result can be inspected.
# print("Trimmed label:", trimmed_label)  # Displays information so the result can be inspected.
# print("Proposed field name:", field_name)  # Displays information so the result can be inspected.
# ```

# %%
raw_field_label = "  Preferred TRANSPORT mode  "  # Stores the calculated or supplied value in raw_field_label.
trimmed_label = raw_field_label.strip()  # Stores the calculated or supplied value in trimmed_label.
lowercase_label = trimmed_label.lower()  # Stores the calculated or supplied value in lowercase_label.
field_name = lowercase_label.replace(" ", "_")  # Stores the calculated or supplied value in field_name.

print("Raw label:", raw_field_label)  # Displays information so the result can be inspected.
print("Trimmed label:", trimmed_label)  # Displays information so the result can be inspected.
print("Proposed field name:", field_name)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.3.4 — Calculate basic data-quality counts
#
# **Website subsection:** Tutorial 2.3
# **Website source:** `python-foundations-i.md`, line 1608
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# received = 240  # Stores the calculated or supplied value in received.
# missing = 18  # Stores the calculated or supplied value in missing.
# duplicates = 6  # Stores the calculated or supplied value in duplicates.
#
# flagged = missing + duplicates  # Stores the calculated or supplied value in flagged.
# retained = received - flagged  # Stores the calculated or supplied value in retained.
#
# print("Flagged records:", flagged)  # Displays information so the result can be inspected.
# print("Retained records:", retained)  # Displays information so the result can be inspected.
# ```

# %%
received = 240  # Stores the calculated or supplied value in received.
missing = 18  # Stores the calculated or supplied value in missing.
duplicates = 6  # Stores the calculated or supplied value in duplicates.

flagged = missing + duplicates  # Stores the calculated or supplied value in flagged.
retained = received - flagged  # Stores the calculated or supplied value in retained.

print("Flagged records:", flagged)  # Displays information so the result can be inspected.
print("Retained records:", retained)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.3.5 — Compare division, floor division and remainder
#
# **Website subsection:** Tutorial 2.3
# **Website source:** `python-foundations-i.md`, line 1663
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# records_to_review = 125  # Stores the calculated or supplied value in records_to_review.
# batch_size = 20  # Stores the calculated or supplied value in batch_size.
#
# exact_batches = records_to_review / batch_size  # Stores the calculated or supplied value in exact_batches.
# full_batches = records_to_review // batch_size  # Stores the calculated or supplied value in full_batches.
# remaining_records = records_to_review % batch_size  # Stores the calculated or supplied value in remaining_records.
#
# print("Exact division result:", exact_batches)  # Displays information so the result can be inspected.
# print("Complete batches:", full_batches)  # Displays information so the result can be inspected.
# print("Records left over:", remaining_records)  # Displays information so the result can be inspected.
# ```

# %%
records_to_review = 125  # Stores the calculated or supplied value in records_to_review.
batch_size = 20  # Stores the calculated or supplied value in batch_size.

exact_batches = records_to_review / batch_size  # Stores the calculated or supplied value in exact_batches.
full_batches = records_to_review // batch_size  # Stores the calculated or supplied value in full_batches.
remaining_records = records_to_review % batch_size  # Stores the calculated or supplied value in remaining_records.

print("Exact division result:", exact_batches)  # Displays information so the result can be inspected.
print("Complete batches:", full_batches)  # Displays information so the result can be inspected.
print("Records left over:", remaining_records)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.3.6 — Calculate a rate and a projected count
#
# **Website subsection:** Tutorial 2.3
# **Website source:** `python-foundations-i.md`, line 1720
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# eligible_residents = 800  # Stores the calculated or supplied value in eligible_residents.
# responses_received = 520  # Stores the calculated or supplied value in responses_received.
# next_round_multiplier = 1.10  # Stores the calculated or supplied value in next_round_multiplier.
#
# response_rate = responses_received / eligible_residents * 100  # Stores the calculated or supplied value in response_rate.
# projected_responses = responses_received * next_round_multiplier  # Stores the calculated or supplied value in projected_responses.
#
# print("Response rate:", response_rate)  # Displays information so the result can be inspected.
# print("Projected responses:", projected_responses)  # Displays information so the result can be inspected.
# ```

# %%
eligible_residents = 800  # Stores the calculated or supplied value in eligible_residents.
responses_received = 520  # Stores the calculated or supplied value in responses_received.
next_round_multiplier = 1.10  # Stores the calculated or supplied value in next_round_multiplier.

response_rate = responses_received / eligible_residents * 100  # Stores the calculated or supplied value in response_rate.
projected_responses = responses_received * next_round_multiplier  # Stores the calculated or supplied value in projected_responses.

print("Response rate:", response_rate)  # Displays information so the result can be inspected.
print("Projected responses:", projected_responses)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.3.7 — Use exponentiation in a simple growth scenario
#
# **Website subsection:** Tutorial 2.3
# **Website source:** `python-foundations-i.md`, line 1776
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# initial_count = 100  # Stores the calculated or supplied value in initial_count.
# growth_factor = 1.05  # Stores the calculated or supplied value in growth_factor.
# number_of_periods = 2  # Stores the calculated or supplied value in number_of_periods.
#
# projected_count = initial_count * growth_factor ** number_of_periods  # Stores the calculated or supplied value in projected_count.
# print("Projected count after two periods:", projected_count)  # Displays information so the result can be inspected.
# ```

# %%
initial_count = 100  # Stores the calculated or supplied value in initial_count.
growth_factor = 1.05  # Stores the calculated or supplied value in growth_factor.
number_of_periods = 2  # Stores the calculated or supplied value in number_of_periods.

projected_count = initial_count * growth_factor ** number_of_periods  # Stores the calculated or supplied value in projected_count.
print("Projected count after two periods:", projected_count)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.3.8 — See how multiplication happens before addition
#
# **Website subsection:** Tutorial 2.3
# **Website source:** `python-foundations-i.md`, line 1859
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# without_parentheses = 1200 + 350 * 4  # Stores the calculated or supplied value in without_parentheses.
# with_parentheses = (1200 + 350) * 4  # Stores the calculated or supplied value in with_parentheses.
#
# print("Without parentheses:", without_parentheses)  # Displays information so the result can be inspected.
# print("With parentheses:", with_parentheses)  # Displays information so the result can be inspected.
# ```

# %%
without_parentheses = 1200 + 350 * 4  # Stores the calculated or supplied value in without_parentheses.
with_parentheses = (1200 + 350) * 4  # Stores the calculated or supplied value in with_parentheses.

print("Without parentheses:", without_parentheses)  # Displays information so the result can be inspected.
print("With parentheses:", with_parentheses)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.3.9 — Make a percentage formula explicit
#
# **Website subsection:** Tutorial 2.3
# **Website source:** `python-foundations-i.md`, line 1910
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# missing_records = 18  # Stores the calculated or supplied value in missing_records.
# duplicate_records = 6  # Stores the calculated or supplied value in duplicate_records.
# total_records = 240  # Stores the calculated or supplied value in total_records.
#
# problem_rate = (missing_records + duplicate_records) / total_records * 100  # Stores the calculated or supplied value in problem_rate.
#
# print("Problem rate:", problem_rate)  # Displays information so the result can be inspected.
# ```

# %%
missing_records = 18  # Stores the calculated or supplied value in missing_records.
duplicate_records = 6  # Stores the calculated or supplied value in duplicate_records.
total_records = 240  # Stores the calculated or supplied value in total_records.

problem_rate = (missing_records + duplicate_records) / total_records * 100  # Stores the calculated or supplied value in problem_rate.

print("Problem rate:", problem_rate)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.3.10 — Use nested parentheses for a weighted scenario
#
# **Website subsection:** Tutorial 2.3
# **Website source:** `python-foundations-i.md`, line 1962
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# missing_records = 18  # Stores the calculated or supplied value in missing_records.
# duplicate_records = 6  # Stores the calculated or supplied value in duplicate_records.
# total_records = 240  # Stores the calculated or supplied value in total_records.
#
# weighted_problem_rate = ((missing_records * 2) + duplicate_records) / total_records * 100  # Stores the calculated or supplied value in weighted_problem_rate.
#
# print("Weighted problem rate:", weighted_problem_rate)  # Displays information so the result can be inspected.
# ```

# %%
missing_records = 18  # Stores the calculated or supplied value in missing_records.
duplicate_records = 6  # Stores the calculated or supplied value in duplicate_records.
total_records = 240  # Stores the calculated or supplied value in total_records.

weighted_problem_rate = ((missing_records * 2) + duplicate_records) / total_records * 100  # Stores the calculated or supplied value in weighted_problem_rate.

print("Weighted problem rate:", weighted_problem_rate)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.3.11 — Understand a subtle negative-number case
#
# **Website subsection:** Tutorial 2.3
# **Website source:** `python-foundations-i.md`, line 2014
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# result_without_grouping = -3 ** 2  # Stores the calculated or supplied value in result_without_grouping.
# result_with_grouping = (-3) ** 2  # Stores the calculated or supplied value in result_with_grouping.
#
# print("Without grouping:", result_without_grouping)  # Displays information so the result can be inspected.
# print("With grouping:", result_with_grouping)  # Displays information so the result can be inspected.
# ```

# %%
result_without_grouping = -3 ** 2  # Stores the calculated or supplied value in result_without_grouping.
result_with_grouping = (-3) ** 2  # Stores the calculated or supplied value in result_with_grouping.

print("Without grouping:", result_without_grouping)  # Displays information so the result can be inspected.
print("With grouping:", result_with_grouping)  # Displays information so the result can be inspected.

# %% [markdown]
# ## Tutorial 2.4 — Strings, numbers, Booleans and type()

# %% [markdown]
# ### Tutorial 2.4 reference — Strings: working with text
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2094
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# "Copenhagen"  # Runs this step from the tutorial example.
# 'Public consultation'  # Runs this step from the tutorial example.
# ```

# %%
"Copenhagen"  # Runs this step from the tutorial example.
'Public consultation'  # Runs this step from the tutorial example.

# %% [markdown]
# ### Example 2.4.1 — Choose quotation marks that fit the text
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2107
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# case_title = "Residents' transport survey"  # Stores the calculated or supplied value in case_title.
# department = 'Urban Mobility Office'  # Stores the calculated or supplied value in department.
#
# print("Case:", case_title)  # Displays information so the result can be inspected.
# print("Department:", department)  # Displays information so the result can be inspected.
# ```

# %%
case_title = "Residents' transport survey"  # Stores the calculated or supplied value in case_title.
department = 'Urban Mobility Office'  # Stores the calculated or supplied value in department.

print("Case:", case_title)  # Displays information so the result can be inspected.
print("Department:", department)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.2 — Join and repeat strings
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2158
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# source = "Consultation portal"  # Stores the calculated or supplied value in source.
# period = "October 2026"  # Stores the calculated or supplied value in period.
# report_label = source + " | " + period  # Stores the calculated or supplied value in report_label.
# separator = "-" * 25  # Stores the calculated or supplied value in separator.
#
# print(report_label)  # Displays information so the result can be inspected.
# print(separator)  # Displays information so the result can be inspected.
# ```

# %%
source = "Consultation portal"  # Stores the calculated or supplied value in source.
period = "October 2026"  # Stores the calculated or supplied value in period.
report_label = source + " | " + period  # Stores the calculated or supplied value in report_label.
separator = "-" * 25  # Stores the calculated or supplied value in separator.

print(report_label)  # Displays information so the result can be inspected.
print(separator)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.3 — Build clear messages with f-strings
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2213
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# organisation = "North Harbour Council"  # Stores the calculated or supplied value in organisation.
# records_checked = 640  # Stores the calculated or supplied value in records_checked.
# completion_rate = 93.75  # Stores the calculated or supplied value in completion_rate.
#
# summary = f"{organisation} checked {records_checked} records. Completion: {completion_rate:.1f}%"  # Stores the calculated or supplied value in summary.
# print(summary)  # Displays information so the result can be inspected.
# ```

# %%
organisation = "North Harbour Council"  # Stores the calculated or supplied value in organisation.
records_checked = 640  # Stores the calculated or supplied value in records_checked.
completion_rate = 93.75  # Stores the calculated or supplied value in completion_rate.

summary = f"{organisation} checked {records_checked} records. Completion: {completion_rate:.1f}%"  # Stores the calculated or supplied value in summary.
print(summary)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.4 — Use counts and measurements appropriately
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2289
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# response_count = 275  # Stores the calculated or supplied value in response_count.
# average_waiting_minutes = 6.5  # Stores the calculated or supplied value in average_waiting_minutes.
#
# print("Response count:", response_count)  # Displays information so the result can be inspected.
# print("Average waiting time:", average_waiting_minutes)  # Displays information so the result can be inspected.
# print("Count type:", type(response_count))  # Displays information so the result can be inspected.
# print("Average type:", type(average_waiting_minutes))  # Displays information so the result can be inspected.
# ```

# %%
response_count = 275  # Stores the calculated or supplied value in response_count.
average_waiting_minutes = 6.5  # Stores the calculated or supplied value in average_waiting_minutes.

print("Response count:", response_count)  # Displays information so the result can be inspected.
print("Average waiting time:", average_waiting_minutes)  # Displays information so the result can be inspected.
print("Count type:", type(response_count))  # Displays information so the result can be inspected.
print("Average type:", type(average_waiting_minutes))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.5 — Notice that division produces a float
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2345
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# total_waiting_minutes = 45  # Stores the calculated or supplied value in total_waiting_minutes.
# people_observed = 6  # Stores the calculated or supplied value in people_observed.
# average_waiting_minutes = total_waiting_minutes / people_observed  # Stores the calculated or supplied value in average_waiting_minutes.
#
# print("Average waiting time:", average_waiting_minutes)  # Displays information so the result can be inspected.
# print("Result type:", type(average_waiting_minutes))  # Displays information so the result can be inspected.
# ```

# %%
total_waiting_minutes = 45  # Stores the calculated or supplied value in total_waiting_minutes.
people_observed = 6  # Stores the calculated or supplied value in people_observed.
average_waiting_minutes = total_waiting_minutes / people_observed  # Stores the calculated or supplied value in average_waiting_minutes.

print("Average waiting time:", average_waiting_minutes)  # Displays information so the result can be inspected.
print("Result type:", type(average_waiting_minutes))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.6 — Understand floating-point representation
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2399
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# first_share = 0.1  # Stores the calculated or supplied value in first_share.
# second_share = 0.2  # Stores the calculated or supplied value in second_share.
# combined_share = first_share + second_share  # Stores the calculated or supplied value in combined_share.
#
# print("Raw result:", combined_share)  # Displays information so the result can be inspected.
# print(f"Formatted result: {combined_share:.2f}")  # Displays information so the result can be inspected.
# ```

# %%
first_share = 0.1  # Stores the calculated or supplied value in first_share.
second_share = 0.2  # Stores the calculated or supplied value in second_share.
combined_share = first_share + second_share  # Stores the calculated or supplied value in combined_share.

print("Raw result:", combined_share)  # Displays information so the result can be inspected.
print(f"Formatted result: {combined_share:.2f}")  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.7 — Recognise implicit conversion from integer to float
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2453
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# whole_hours = 12  # Stores the calculated or supplied value in whole_hours.
# additional_hours = 0.5  # Stores the calculated or supplied value in additional_hours.
# total_hours = whole_hours + additional_hours  # Stores the calculated or supplied value in total_hours.
#
# print("Total observed hours:", total_hours)  # Displays information so the result can be inspected.
# print("Whole-hours type:", type(whole_hours))  # Displays information so the result can be inspected.
# print("Total-hours type:", type(total_hours))  # Displays information so the result can be inspected.
# ```

# %%
whole_hours = 12  # Stores the calculated or supplied value in whole_hours.
additional_hours = 0.5  # Stores the calculated or supplied value in additional_hours.
total_hours = whole_hours + additional_hours  # Stores the calculated or supplied value in total_hours.

print("Total observed hours:", total_hours)  # Displays information so the result can be inspected.
print("Whole-hours type:", type(whole_hours))  # Displays information so the result can be inspected.
print("Total-hours type:", type(total_hours))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.8 — Separate rounding a value from formatting its display
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2510
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# raw_completion_rate = 93.756  # Stores the calculated or supplied value in raw_completion_rate.
# rounded_rate = round(raw_completion_rate, 1)  # Stores the calculated or supplied value in rounded_rate.
# display_line = f"Completion rate: {raw_completion_rate:.1f}%"  # Stores the calculated or supplied value in display_line.
#
# print("Raw value:", raw_completion_rate)  # Displays information so the result can be inspected.
# print("Rounded numerical value:", rounded_rate)  # Displays information so the result can be inspected.
# print(display_line)  # Displays information so the result can be inspected.
# print("Raw value is still:", raw_completion_rate)  # Displays information so the result can be inspected.
# ```

# %%
raw_completion_rate = 93.756  # Stores the calculated or supplied value in raw_completion_rate.
rounded_rate = round(raw_completion_rate, 1)  # Stores the calculated or supplied value in rounded_rate.
display_line = f"Completion rate: {raw_completion_rate:.1f}%"  # Stores the calculated or supplied value in display_line.

print("Raw value:", raw_completion_rate)  # Displays information so the result can be inspected.
print("Rounded numerical value:", rounded_rate)  # Displays information so the result can be inspected.
print(display_line)  # Displays information so the result can be inspected.
print("Raw value is still:", raw_completion_rate)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.9 — Store Boolean flags directly
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2605
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# consent_recorded = True  # Stores the calculated or supplied value in consent_recorded.
# contains_personal_data = False  # Stores the calculated or supplied value in contains_personal_data.
#
# print("Consent recorded:", consent_recorded)  # Displays information so the result can be inspected.
# print("Contains personal data:", contains_personal_data)  # Displays information so the result can be inspected.
# print("Consent flag type:", type(consent_recorded))  # Displays information so the result can be inspected.
# ```

# %%
consent_recorded = True  # Stores the calculated or supplied value in consent_recorded.
contains_personal_data = False  # Stores the calculated or supplied value in contains_personal_data.

print("Consent recorded:", consent_recorded)  # Displays information so the result can be inspected.
print("Contains personal data:", contains_personal_data)  # Displays information so the result can be inspected.
print("Consent flag type:", type(consent_recorded))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.10 — Produce Booleans with comparisons
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2658
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# total_records = 300  # Stores the calculated or supplied value in total_records.
# missing_records = 0  # Stores the calculated or supplied value in missing_records.
# minimum_required = 250  # Stores the calculated or supplied value in minimum_required.
#
# has_no_missing_records = missing_records == 0  # Runs this step from the tutorial example.
# meets_minimum_size = total_records >= minimum_required  # Runs this step from the tutorial example.
# is_exactly_minimum = total_records == minimum_required  # Runs this step from the tutorial example.
#
# print("No missing records:", has_no_missing_records)  # Displays information so the result can be inspected.
# print("Meets minimum size:", meets_minimum_size)  # Displays information so the result can be inspected.
# print("Exactly minimum size:", is_exactly_minimum)  # Displays information so the result can be inspected.
# ```

# %%
total_records = 300  # Stores the calculated or supplied value in total_records.
missing_records = 0  # Stores the calculated or supplied value in missing_records.
minimum_required = 250  # Stores the calculated or supplied value in minimum_required.

has_no_missing_records = missing_records == 0  # Runs this step from the tutorial example.
meets_minimum_size = total_records >= minimum_required  # Runs this step from the tutorial example.
is_exactly_minimum = total_records == minimum_required  # Runs this step from the tutorial example.

print("No missing records:", has_no_missing_records)  # Displays information so the result can be inspected.
print("Meets minimum size:", meets_minimum_size)  # Displays information so the result can be inspected.
print("Exactly minimum size:", is_exactly_minimum)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.11 — Combine Boolean conditions
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2716
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# has_required_columns = True  # Stores the calculated or supplied value in has_required_columns.
# missing_record_count = 0  # Stores the calculated or supplied value in missing_record_count.
# duplicate_record_count = 0  # Stores the calculated or supplied value in duplicate_record_count.
#
# ready_for_initial_analysis = (  # Stores the calculated or supplied value in ready_for_initial_analysis.
#     has_required_columns  # Runs this step from the tutorial example.
#     and missing_record_count == 0  # Runs this step from the tutorial example.
#     and duplicate_record_count == 0  # Runs this step from the tutorial example.
# )  # Runs this step from the tutorial example.
#
# print("Ready for initial analysis:", ready_for_initial_analysis)  # Displays information so the result can be inspected.
# ```

# %%
has_required_columns = True  # Stores the calculated or supplied value in has_required_columns.
missing_record_count = 0  # Stores the calculated or supplied value in missing_record_count.
duplicate_record_count = 0  # Stores the calculated or supplied value in duplicate_record_count.

ready_for_initial_analysis = (  # Stores the calculated or supplied value in ready_for_initial_analysis.
    has_required_columns  # Runs this step from the tutorial example.
    and missing_record_count == 0  # Runs this step from the tutorial example.
    and duplicate_record_count == 0  # Runs this step from the tutorial example.
)  # Runs this step from the tutorial example.

print("Ready for initial analysis:", ready_for_initial_analysis)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.12 — Inspect the four foundation types
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2804
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# case_name = "Green Mobility Debate"  # Stores the calculated or supplied value in case_name.
# record_count = 420  # Stores the calculated or supplied value in record_count.
# average_engagement = 37.5  # Stores the calculated or supplied value in average_engagement.
# review_complete = False  # Stores the calculated or supplied value in review_complete.
#
# print(type(case_name))  # Displays information so the result can be inspected.
# print(type(record_count))  # Displays information so the result can be inspected.
# print(type(average_engagement))  # Displays information so the result can be inspected.
# print(type(review_complete))  # Displays information so the result can be inspected.
# ```

# %%
case_name = "Green Mobility Debate"  # Stores the calculated or supplied value in case_name.
record_count = 420  # Stores the calculated or supplied value in record_count.
average_engagement = 37.5  # Stores the calculated or supplied value in average_engagement.
review_complete = False  # Stores the calculated or supplied value in review_complete.

print(type(case_name))  # Displays information so the result can be inspected.
print(type(record_count))  # Displays information so the result can be inspected.
print(type(average_engagement))  # Displays information so the result can be inspected.
print(type(review_complete))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.13 — Use `type()` to investigate a failed calculation
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2861
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# records_received = "250"  # Stores the calculated or supplied value in records_received.
# records_missing = 18  # Stores the calculated or supplied value in records_missing.
#
# print("records_received type:", type(records_received))  # Displays information so the result can be inspected.
# print("records_missing type:", type(records_missing))  # Displays information so the result can be inspected.
# ```

# %%
records_received = "250"  # Stores the calculated or supplied value in records_received.
records_missing = 18  # Stores the calculated or supplied value in records_missing.

print("records_received type:", type(records_received))  # Displays information so the result can be inspected.
print("records_missing type:", type(records_missing))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.14 — Inspect expressions, not only variables
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2911
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# print(type(10 + 5))  # Displays information so the result can be inspected.
# print(type(10 / 5))  # Displays information so the result can be inspected.
# print(type("10" + "5"))  # Displays information so the result can be inspected.
# print(type(10 > 5))  # Displays information so the result can be inspected.
# ```

# %%
print(type(10 + 5))  # Displays information so the result can be inspected.
print(type(10 / 5))  # Displays information so the result can be inspected.
print(type("10" + "5"))  # Displays information so the result can be inspected.
print(type(10 > 5))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.4.15 — Preserve three different states
#
# **Website subsection:** Tutorial 2.4
# **Website source:** `python-foundations-i.md`, line 2967
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# waiting_time_minutes = None  # Stores the calculated or supplied value in waiting_time_minutes.
# complaint_count = 0  # Stores the calculated or supplied value in complaint_count.
# optional_comment = ""  # Stores the calculated or supplied value in optional_comment.
#
# print("Waiting time:", waiting_time_minutes)  # Displays information so the result can be inspected.
# print("Complaint count:", complaint_count)  # Displays information so the result can be inspected.
# print("Optional comment:", optional_comment)  # Displays information so the result can be inspected.
# print("Waiting-time type:", type(waiting_time_minutes))  # Displays information so the result can be inspected.
# print("Complaint-count type:", type(complaint_count))  # Displays information so the result can be inspected.
# print("Comment type:", type(optional_comment))  # Displays information so the result can be inspected.
# ```

# %%
waiting_time_minutes = None  # Stores the calculated or supplied value in waiting_time_minutes.
complaint_count = 0  # Stores the calculated or supplied value in complaint_count.
optional_comment = ""  # Stores the calculated or supplied value in optional_comment.

print("Waiting time:", waiting_time_minutes)  # Displays information so the result can be inspected.
print("Complaint count:", complaint_count)  # Displays information so the result can be inspected.
print("Optional comment:", optional_comment)  # Displays information so the result can be inspected.
print("Waiting-time type:", type(waiting_time_minutes))  # Displays information so the result can be inspected.
print("Complaint-count type:", type(complaint_count))  # Displays information so the result can be inspected.
print("Comment type:", type(optional_comment))  # Displays information so the result can be inspected.

# %% [markdown]
# ## Tutorial 2.5 — Type conversion and user input

# %% [markdown]
# ### Example 2.5.1 — Convert whole-number text to an integer
#
# **Website subsection:** Tutorial 2.5
# **Website source:** `python-foundations-i.md`, line 3077
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# records_text = "250"  # Stores the calculated or supplied value in records_text.
# records_number = int(records_text)  # Stores the calculated or supplied value in records_number.
# remaining_records = records_number - 18  # Stores the calculated or supplied value in remaining_records.
#
# print("Original type:", type(records_text))  # Displays information so the result can be inspected.
# print("Converted type:", type(records_number))  # Displays information so the result can be inspected.
# print("Remaining records:", remaining_records)  # Displays information so the result can be inspected.
# ```

# %%
records_text = "250"  # Stores the calculated or supplied value in records_text.
records_number = int(records_text)  # Stores the calculated or supplied value in records_number.
remaining_records = records_number - 18  # Stores the calculated or supplied value in remaining_records.

print("Original type:", type(records_text))  # Displays information so the result can be inspected.
print("Converted type:", type(records_number))  # Displays information so the result can be inspected.
print("Remaining records:", remaining_records)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.5.2 — Convert decimal text to a float
#
# **Website subsection:** Tutorial 2.5
# **Website source:** `python-foundations-i.md`, line 3131
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# completion_text = "93.5"  # Stores the calculated or supplied value in completion_text.
# completion_number = float(completion_text)  # Stores the calculated or supplied value in completion_number.
# gap_to_full_completion = 100 - completion_number  # Stores the calculated or supplied value in gap_to_full_completion.
#
# print("Completion:", completion_number)  # Displays information so the result can be inspected.
# print("Gap to 100:", gap_to_full_completion)  # Displays information so the result can be inspected.
# print("Converted type:", type(completion_number))  # Displays information so the result can be inspected.
# ```

# %%
completion_text = "93.5"  # Stores the calculated or supplied value in completion_text.
completion_number = float(completion_text)  # Stores the calculated or supplied value in completion_number.
gap_to_full_completion = 100 - completion_number  # Stores the calculated or supplied value in gap_to_full_completion.

print("Completion:", completion_number)  # Displays information so the result can be inspected.
print("Gap to 100:", gap_to_full_completion)  # Displays information so the result can be inspected.
print("Converted type:", type(completion_number))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.5.3 — Convert numbers to text for concatenation
#
# **Website subsection:** Tutorial 2.5
# **Website source:** `python-foundations-i.md`, line 3184
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# report_year = 2026  # Stores the calculated or supplied value in report_year.
# record_count = 420  # Stores the calculated or supplied value in record_count.
#
# file_label = "report_" + str(report_year) + "_records_" + str(record_count)  # Stores the calculated or supplied value in file_label.
# print(file_label)  # Displays information so the result can be inspected.
# ```

# %%
report_year = 2026  # Stores the calculated or supplied value in report_year.
record_count = 420  # Stores the calculated or supplied value in record_count.

file_label = "report_" + str(report_year) + "_records_" + str(record_count)  # Stores the calculated or supplied value in file_label.
print(file_label)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.5.4 — Understand that `int()` truncates floats
#
# **Website subsection:** Tutorial 2.5
# **Website source:** `python-foundations-i.md`, line 3235
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# projected_responses = 572.9  # Stores the calculated or supplied value in projected_responses.
# whole_responses = int(projected_responses)  # Stores the calculated or supplied value in whole_responses.
#
# print("Original projection:", projected_responses)  # Displays information so the result can be inspected.
# print("Converted integer:", whole_responses)  # Displays information so the result can be inspected.
# ```

# %%
projected_responses = 572.9  # Stores the calculated or supplied value in projected_responses.
whole_responses = int(projected_responses)  # Stores the calculated or supplied value in whole_responses.

print("Original projection:", projected_responses)  # Displays information so the result can be inspected.
print("Converted integer:", whole_responses)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.5.5 — Collect and display text input — manual or file-dependent example
#
# **Website subsection:** Tutorial 2.5
# **Website source:** `python-foundations-i.md`, line 3329
# **Status:** Run manually with the stated input or file — interactive input.
#
# ```python
# organisation = input("Enter the organisation name: ")  # Stores the calculated or supplied value in organisation.
# print("Organisation recorded:", organisation)  # Displays information so the result can be inspected.
# print("Input type:", type(organisation))  # Displays information so the result can be inspected.
# ```

# %%
example_status = 'Example 2.5.5 is labelled run manually with the stated input or file: interactive input'  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# ### Example 2.5.6 — Convert numerical input before calculating — manual or file-dependent example
#
# **Website subsection:** Tutorial 2.5
# **Website source:** `python-foundations-i.md`, line 3379
# **Status:** Run manually with the stated input or file — interactive input.
#
# ```python
# records_text = input("Enter the number of records received: ")  # Stores the calculated or supplied value in records_text.
# records_received = int(records_text)  # Stores the calculated or supplied value in records_received.
# records_missing = 8  # Stores the calculated or supplied value in records_missing.
# records_complete = records_received - records_missing  # Stores the calculated or supplied value in records_complete.
#
# print("Complete records:", records_complete)  # Displays information so the result can be inspected.
# ```

# %%
example_status = 'Example 2.5.6 is labelled run manually with the stated input or file: interactive input'  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# ### Example 2.5.7 — Turn messy text input into a traceable file label — manual or file-dependent example
#
# **Website subsection:** Tutorial 2.5
# **Website source:** `python-foundations-i.md`, line 3432
# **Status:** Run manually with the stated input or file — interactive input.
#
# ```python
# organisation_raw = input("Organisation: ")  # Stores the calculated or supplied value in organisation_raw.
# dataset_raw = input("Dataset title: ")  # Stores the calculated or supplied value in dataset_raw.
# period_raw = input("Reporting period: ")  # Stores the calculated or supplied value in period_raw.
#
# organisation = organisation_raw.strip().title()  # Stores the calculated or supplied value in organisation.
# organisation_label = organisation.lower().replace(" ", "_")  # Stores the calculated or supplied value in organisation_label.
# dataset_label = dataset_raw.strip().lower().replace(" ", "_")  # Stores the calculated or supplied value in dataset_label.
# period_label = period_raw.strip().lower().replace(" ", "_")  # Stores the calculated or supplied value in period_label.
# file_name = f"{organisation_label}_{dataset_label}_{period_label}.csv"  # Stores the calculated or supplied value in file_name.
#
# print(f"\nOrganisation: {organisation}")  # Displays information so the result can be inspected.
# print("Dataset label:", dataset_label)  # Displays information so the result can be inspected.
# print("Reporting-period label:", period_label)  # Displays information so the result can be inspected.
# print("Draft file name:", file_name)  # Displays information so the result can be inspected.
# ```

# %%
example_status = 'Example 2.5.7 is labelled run manually with the stated input or file: interactive input'  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# ### Example 2.5.8 — Compare text joining before and after conversion — manual or file-dependent example
#
# **Website subsection:** Tutorial 2.5
# **Website source:** `python-foundations-i.md`, line 3502
# **Status:** Run manually with the stated input or file — interactive input.
#
# ```python
# first_text = input("First count: ")  # Stores the calculated or supplied value in first_text.
# second_text = input("Second count: ")  # Stores the calculated or supplied value in second_text.
#
# joined_text = first_text + second_text  # Stores the calculated or supplied value in joined_text.
# numerical_total = int(first_text) + int(second_text)  # Stores the calculated or supplied value in numerical_total.
#
# print("Text joined:", joined_text)  # Displays information so the result can be inspected.
# print("Numbers added:", numerical_total)  # Displays information so the result can be inspected.
# ```

# %%
example_status = 'Example 2.5.8 is labelled run manually with the stated input or file: interactive input'  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# ### Example 2.5.9 — Transfer the input pattern to a gross-pay estimate — manual or file-dependent example
#
# **Website subsection:** Tutorial 2.5
# **Website source:** `python-foundations-i.md`, line 3581
# **Status:** Run manually with the stated input or file — interactive input.
#
# ```python
# role_label = input("Role label: ")  # Stores the calculated or supplied value in role_label.
# hours_worked = float(input("Hours worked: "))  # Stores the calculated or supplied value in hours_worked.
# hourly_rate_dkk = float(input("Hourly rate in DKK: "))  # Stores the calculated or supplied value in hourly_rate_dkk.
#
# gross_pay_dkk = hours_worked * hourly_rate_dkk  # Stores the calculated or supplied value in gross_pay_dkk.
# pay_note = f"{role_label}: estimated gross pay is {gross_pay_dkk:.2f} DKK"  # Stores the calculated or supplied value in pay_note.
#
# print(pay_note)  # Displays information so the result can be inspected.
# ```

# %%
example_status = 'Example 2.5.9 is labelled run manually with the stated input or file: interactive input'  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# ### Example 2.5.10 — Transfer the input pattern to a temperature conversion — manual or file-dependent example
#
# **Website subsection:** Tutorial 2.5
# **Website source:** `python-foundations-i.md`, line 3640
# **Status:** Run manually with the stated input or file — interactive input.
#
# ```python
# sensor_id = input("Sensor identifier: ")  # Stores the calculated or supplied value in sensor_id.
# celsius_text = input("Temperature in degrees Celsius: ")  # Stores the calculated or supplied value in celsius_text.
# celsius = float(celsius_text)  # Stores the calculated or supplied value in celsius.
#
# fahrenheit = celsius * 9 / 5 + 32  # Stores the calculated or supplied value in fahrenheit.
# report_line = f"Sensor {sensor_id}: {celsius:.1f} °C equals {fahrenheit:.1f} °F"  # Stores the calculated or supplied value in report_line.
#
# print(report_line)  # Displays information so the result can be inspected.
# print("Original temperature text:", celsius_text)  # Displays information so the result can be inspected.
# ```

# %%
example_status = 'Example 2.5.10 is labelled run manually with the stated input or file: interactive input'  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# ## Tutorial 2.6 — Comments and beginner debugging

# %% [markdown]
# ### Example 2.6.1 — Explain purpose and assumptions
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 3726
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# # Summarise the first technical check of a monthly file.
# total_records = 240  # Stores the calculated or supplied value in total_records.
# missing_records = 18  # Stores the calculated or supplied value in missing_records.
#
# # Assumption: missing_records is a non-overlapping count.
# complete_records = total_records - missing_records  # Stores the calculated or supplied value in complete_records.
#
# print("Complete records:", complete_records)  # Displays information so the result can be inspected.
# ```

# %%
# Summarise the first technical check of a monthly file.
total_records = 240  # Stores the calculated or supplied value in total_records.
missing_records = 18  # Stores the calculated or supplied value in missing_records.

# Assumption: missing_records is a non-overlapping count.
complete_records = total_records - missing_records  # Stores the calculated or supplied value in complete_records.

print("Complete records:", complete_records)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.6.2 — Use end-of-line comments carefully
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 3780
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# MINIMUM_REQUIRED = 80  # Stated project threshold, pending review.
# completion_rate = 76.5  # Percentage, not a proportion.
#
# gap = MINIMUM_REQUIRED - completion_rate  # Stores the calculated or supplied value in gap.
# print("Gap to stated threshold:", gap)  # Displays information so the result can be inspected.
# ```

# %%
MINIMUM_REQUIRED = 80  # Stated project threshold, pending review.
completion_rate = 76.5  # Percentage, not a proportion.

gap = MINIMUM_REQUIRED - completion_rate  # Stores the calculated or supplied value in gap.
print("Gap to stated threshold:", gap)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.6.3 — Do not confuse strings with comments
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 3830
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# note = "Missing categories are labelled Unknown in this teaching example."  # Stores the calculated or supplied value in note.
# # The string above is stored data. This line is a comment.
#
# print(note)  # Displays information so the result can be inspected.
# print(type(note))  # Displays information so the result can be inspected.
# ```

# %%
note = "Missing categories are labelled Unknown in this teaching example."  # Stores the calculated or supplied value in note.
# The string above is stored data. This line is a comment.

print(note)  # Displays information so the result can be inspected.
print(type(note))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.6.4 — `SyntaxError` — safe diagnostic record
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 3931
# **Status:** Deliberate error or diagnostic example — SyntaxError on line 1: unterminated string literal (detected at line 1).
#
# ```python
# case_title = "Mobility survey  # Stores the calculated or supplied value in case_title.
# print(case_title)  # Displays information so the result can be inspected.
# ```

# %%
example_status = 'Example 2.6.4 is labelled deliberate error or diagnostic example: SyntaxError on line 1: unterminated string literal (detected at line 1)'  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# #### Additional runnable cell for Example 2.6.4 — `SyntaxError`
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 3946
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# case_title = "Mobility survey"  # Stores the calculated or supplied value in case_title.
# print(case_title)  # Displays information so the result can be inspected.
# ```

# %%
case_title = "Mobility survey"  # Stores the calculated or supplied value in case_title.
print(case_title)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.6.5 — `NameError` — safe diagnostic record
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 3992
# **Status:** Deliberate error or diagnostic example — NameError: name 'missing_record' is not defined. Did you mean: 'missing_records'?.
#
# ```python
# total_records = 250  # Stores the calculated or supplied value in total_records.
# missing_records = 18  # Stores the calculated or supplied value in missing_records.
# complete_records = total_records - missing_record  # Stores the calculated or supplied value in complete_records.
# print(complete_records)  # Displays information so the result can be inspected.
# ```

# %%
example_status = "Example 2.6.5 is labelled deliberate error or diagnostic example: NameError: name 'missing_record' is not defined. Did you mean: 'missing_records'?"  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# #### Additional runnable cell for Example 2.6.5 — `NameError`
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 4007
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# total_records = 250  # Stores the calculated or supplied value in total_records.
# missing_records = 18  # Stores the calculated or supplied value in missing_records.
# complete_records = total_records - missing_records  # Stores the calculated or supplied value in complete_records.
# print(complete_records)  # Displays information so the result can be inspected.
# ```

# %%
total_records = 250  # Stores the calculated or supplied value in total_records.
missing_records = 18  # Stores the calculated or supplied value in missing_records.
complete_records = total_records - missing_records  # Stores the calculated or supplied value in complete_records.
print(complete_records)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.6.6 — `TypeError` — safe diagnostic record
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 4056
# **Status:** Deliberate error or diagnostic example — TypeError: unsupported operand type(s) for -: 'str' and 'int'.
#
# ```python
# total_records = "250"  # Stores the calculated or supplied value in total_records.
# missing_records = 18  # Stores the calculated or supplied value in missing_records.
# complete_records = total_records - missing_records  # Stores the calculated or supplied value in complete_records.
# print(complete_records)  # Displays information so the result can be inspected.
# ```

# %%
example_status = "Example 2.6.6 is labelled deliberate error or diagnostic example: TypeError: unsupported operand type(s) for -: 'str' and 'int'"  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# #### Additional runnable cell for Example 2.6.6 — `TypeError`
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 4071
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# total_records = int("250")  # Stores the calculated or supplied value in total_records.
# missing_records = 18  # Stores the calculated or supplied value in missing_records.
# complete_records = total_records - missing_records  # Stores the calculated or supplied value in complete_records.
# print(complete_records)  # Displays information so the result can be inspected.
# ```

# %%
total_records = int("250")  # Stores the calculated or supplied value in total_records.
missing_records = 18  # Stores the calculated or supplied value in missing_records.
complete_records = total_records - missing_records  # Stores the calculated or supplied value in complete_records.
print(complete_records)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.6.7 — `ValueError` — safe diagnostic record
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 4120
# **Status:** Deliberate error or diagnostic example — ValueError: invalid literal for int() with base 10: '93.5'.
#
# ```python
# completion_text = "93.5"  # Stores the calculated or supplied value in completion_text.
# completion_number = int(completion_text)  # Stores the calculated or supplied value in completion_number.
# print(completion_number)  # Displays information so the result can be inspected.
# ```

# %%
example_status = "Example 2.6.7 is labelled deliberate error or diagnostic example: ValueError: invalid literal for int() with base 10: '93.5'"  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# #### Additional runnable cell for Example 2.6.7 — `ValueError`
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 4134
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# completion_text = "93.5"  # Stores the calculated or supplied value in completion_text.
# completion_number = float(completion_text)  # Stores the calculated or supplied value in completion_number.
# print(completion_number)  # Displays information so the result can be inspected.
# ```

# %%
completion_text = "93.5"  # Stores the calculated or supplied value in completion_text.
completion_number = float(completion_text)  # Stores the calculated or supplied value in completion_number.
print(completion_number)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.6.8 — `ZeroDivisionError` — safe diagnostic record
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 4182
# **Status:** Deliberate error or diagnostic example — ZeroDivisionError: division by zero.
#
# ```python
# completed_responses = 0  # Stores the calculated or supplied value in completed_responses.
# invited_participants = 0  # Stores the calculated or supplied value in invited_participants.
# completion_rate = completed_responses / invited_participants * 100  # Stores the calculated or supplied value in completion_rate.
# print(completion_rate)  # Displays information so the result can be inspected.
# ```

# %%
example_status = 'Example 2.6.8 is labelled deliberate error or diagnostic example: ZeroDivisionError: division by zero'  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# #### Additional runnable cell for Example 2.6.8 — `ZeroDivisionError`
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 4197
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# completed_responses = 72  # Stores the calculated or supplied value in completed_responses.
# invited_participants = 90  # Stores the calculated or supplied value in invited_participants.
# completion_rate = completed_responses / invited_participants * 100  # Stores the calculated or supplied value in completion_rate.
# print(completion_rate)  # Displays information so the result can be inspected.
# ```

# %%
completed_responses = 72  # Stores the calculated or supplied value in completed_responses.
invited_participants = 90  # Stores the calculated or supplied value in invited_participants.
completion_rate = completed_responses / invited_participants * 100  # Stores the calculated or supplied value in completion_rate.
print(completion_rate)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.6.9 — `IndentationError` — safe diagnostic record
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 4246
# **Status:** Deliberate error or diagnostic example — SyntaxError on line 1: unexpected indent.
#
# ```python
#     print("Dataset loaded")  # Displays information so the result can be inspected.
# print("Initial check started")  # Displays information so the result can be inspected.
# ```

# %%
example_status = 'Example 2.6.9 is labelled deliberate error or diagnostic example: SyntaxError on line 1: unexpected indent'  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# #### Additional runnable cell for Example 2.6.9 — `IndentationError`
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 4259
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# print("Dataset loaded")  # Displays information so the result can be inspected.
# print("Initial check started")  # Displays information so the result can be inspected.
# ```

# %%
print("Dataset loaded")  # Displays information so the result can be inspected.
print("Initial check started")  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.6.10 — A logical error with no traceback
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 4306
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# complete_records = 180  # Stores the calculated or supplied value in complete_records.
# total_records = 200  # Stores the calculated or supplied value in total_records.
# completion_rate = total_records / complete_records * 100  # Stores the calculated or supplied value in completion_rate.
#
# print("Completion rate:", completion_rate)  # Displays information so the result can be inspected.
# ```

# %%
complete_records = 180  # Stores the calculated or supplied value in complete_records.
total_records = 200  # Stores the calculated or supplied value in total_records.
completion_rate = total_records / complete_records * 100  # Stores the calculated or supplied value in completion_rate.

print("Completion rate:", completion_rate)  # Displays information so the result can be inspected.

# %% [markdown]
# #### Additional runnable cell for Example 2.6.10 — A logical error with no traceback
#
# **Website subsection:** Tutorial 2.6
# **Website source:** `python-foundations-i.md`, line 4322
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# complete_records = 180  # Stores the calculated or supplied value in complete_records.
# total_records = 200  # Stores the calculated or supplied value in total_records.
# completion_rate = complete_records / total_records * 100  # Stores the calculated or supplied value in completion_rate.
#
# print("Completion rate:", completion_rate)  # Displays information so the result can be inspected.
# ```

# %%
complete_records = 180  # Stores the calculated or supplied value in complete_records.
total_records = 200  # Stores the calculated or supplied value in total_records.
completion_rate = complete_records / total_records * 100  # Stores the calculated or supplied value in completion_rate.

print("Completion rate:", completion_rate)  # Displays information so the result can be inspected.

# %% [markdown]
# ## Tutorial 2.7 — Integration, mini-cases and self-test

# %% [markdown]
# ### Example 2.7.1 — Produce a monthly data-quality summary
#
# **Website subsection:** Tutorial 2.7
# **Website source:** `python-foundations-i.md`, line 4417
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# # Report settings
# REPORT_TITLE = "Monthly consultation data check"  # Stores the calculated or supplied value in REPORT_TITLE.
# total_records = 750  # Stores the calculated or supplied value in total_records.
# missing_records = 27  # Stores the calculated or supplied value in missing_records.
# duplicate_records = 9  # Stores the calculated or supplied value in duplicate_records.
#
# # Initial technical summary. Problem counts are assumed not to overlap.
# problem_records = missing_records + duplicate_records  # Stores the calculated or supplied value in problem_records.
# usable_records = total_records - problem_records  # Stores the calculated or supplied value in usable_records.
# usable_rate = usable_records / total_records * 100  # Stores the calculated or supplied value in usable_rate.
# has_identified_problems = problem_records > 0  # Stores the calculated or supplied value in has_identified_problems.
#
# print(REPORT_TITLE)  # Displays information so the result can be inspected.
# print("Total records:", total_records)  # Displays information so the result can be inspected.
# print("Problem records:", problem_records)  # Displays information so the result can be inspected.
# print("Usable records:", usable_records)  # Displays information so the result can be inspected.
# print(f"Usable rate: {usable_rate:.1f}%")  # Displays information so the result can be inspected.
# print("Identified problems present:", has_identified_problems)  # Displays information so the result can be inspected.
# ```

# %%
# Report settings
REPORT_TITLE = "Monthly consultation data check"  # Stores the calculated or supplied value in REPORT_TITLE.
total_records = 750  # Stores the calculated or supplied value in total_records.
missing_records = 27  # Stores the calculated or supplied value in missing_records.
duplicate_records = 9  # Stores the calculated or supplied value in duplicate_records.

# Initial technical summary. Problem counts are assumed not to overlap.
problem_records = missing_records + duplicate_records  # Stores the calculated or supplied value in problem_records.
usable_records = total_records - problem_records  # Stores the calculated or supplied value in usable_records.
usable_rate = usable_records / total_records * 100  # Stores the calculated or supplied value in usable_rate.
has_identified_problems = problem_records > 0  # Stores the calculated or supplied value in has_identified_problems.

print(REPORT_TITLE)  # Displays information so the result can be inspected.
print("Total records:", total_records)  # Displays information so the result can be inspected.
print("Problem records:", problem_records)  # Displays information so the result can be inspected.
print("Usable records:", usable_records)  # Displays information so the result can be inspected.
print(f"Usable rate: {usable_rate:.1f}%")  # Displays information so the result can be inspected.
print("Identified problems present:", has_identified_problems)  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.7.2 — Compare expected and received file structure
#
# **Website subsection:** Tutorial 2.7
# **Website source:** `python-foundations-i.md`, line 4492
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# # Expected structure agreed for this fictional teaching case.
# EXPECTED_COLUMNS = 12  # Stores the calculated or supplied value in EXPECTED_COLUMNS.
#
# dataset_name = "October service log"  # Stores the calculated or supplied value in dataset_name.
# received_columns_text = "10"  # Stores the calculated or supplied value in received_columns_text.
# received_columns = int(received_columns_text)  # Stores the calculated or supplied value in received_columns.
#
# missing_column_count = EXPECTED_COLUMNS - received_columns  # Stores the calculated or supplied value in missing_column_count.
# structure_matches_expectation = received_columns == EXPECTED_COLUMNS  # Runs this step from the tutorial example.
#
# summary = (  # Stores the calculated or supplied value in summary.
#     f"{dataset_name}: received {received_columns} of "  # Runs this step from the tutorial example.
#     f"{EXPECTED_COLUMNS} expected columns."  # Runs this step from the tutorial example.
# )  # Runs this step from the tutorial example.
#
# print(summary)  # Displays information so the result can be inspected.
# print("Missing column count:", missing_column_count)  # Displays information so the result can be inspected.
# print("Structure matches expectation:", structure_matches_expectation)  # Displays information so the result can be inspected.
# print("Original input type:", type(received_columns_text))  # Displays information so the result can be inspected.
# print("Converted input type:", type(received_columns))  # Displays information so the result can be inspected.
# ```

# %%
# Expected structure agreed for this fictional teaching case.
EXPECTED_COLUMNS = 12  # Stores the calculated or supplied value in EXPECTED_COLUMNS.

dataset_name = "October service log"  # Stores the calculated or supplied value in dataset_name.
received_columns_text = "10"  # Stores the calculated or supplied value in received_columns_text.
received_columns = int(received_columns_text)  # Stores the calculated or supplied value in received_columns.

missing_column_count = EXPECTED_COLUMNS - received_columns  # Stores the calculated or supplied value in missing_column_count.
structure_matches_expectation = received_columns == EXPECTED_COLUMNS  # Runs this step from the tutorial example.

summary = (  # Stores the calculated or supplied value in summary.
    f"{dataset_name}: received {received_columns} of "  # Runs this step from the tutorial example.
    f"{EXPECTED_COLUMNS} expected columns."  # Runs this step from the tutorial example.
)  # Runs this step from the tutorial example.

print(summary)  # Displays information so the result can be inspected.
print("Missing column count:", missing_column_count)  # Displays information so the result can be inspected.
print("Structure matches expectation:", structure_matches_expectation)  # Displays information so the result can be inspected.
print("Original input type:", type(received_columns_text))  # Displays information so the result can be inspected.
print("Converted input type:", type(received_columns))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Example 2.7.3 — Create an interactive organisational intake note — manual or file-dependent example
#
# **Website subsection:** Tutorial 2.7
# **Website source:** `python-foundations-i.md`, line 4567
# **Status:** Run manually with the stated input or file — interactive input.
#
# ```python
# # Collect a small, non-sensitive teaching example.
# organisation = input("Organisation: ")  # Stores the calculated or supplied value in organisation.
# reporting_period = input("Reporting period: ")  # Stores the calculated or supplied value in reporting_period.
# records_received = int(input("Records received: "))  # Stores the calculated or supplied value in records_received.
# records_excluded = int(input("Records excluded: "))  # Stores the calculated or supplied value in records_excluded.
#
# records_retained = records_received - records_excluded  # Stores the calculated or supplied value in records_retained.
# retention_rate = records_retained / records_received * 100  # Stores the calculated or supplied value in retention_rate.
# has_exclusions = records_excluded > 0  # Stores the calculated or supplied value in has_exclusions.
#
# print(f"\n{organisation} | {reporting_period}")  # Displays information so the result can be inspected.
# print("Records retained:", records_retained)  # Displays information so the result can be inspected.
# print(f"Retention rate: {retention_rate:.1f}%")  # Displays information so the result can be inspected.
# print("Has exclusions:", has_exclusions)  # Displays information so the result can be inspected.
# ```

# %%
example_status = 'Example 2.7.3 is labelled run manually with the stated input or file: interactive input'  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# ### Example 2.7.4 — Preserve raw metadata and publish a standardisation note
#
# **Website subsection:** Tutorial 2.7
# **Website source:** `python-foundations-i.md`, line 4640
# **Status:** Runnable and audited — executed successfully during the audit.
#
# ```python
# # Raw metadata copied from a fictional intake form.
# raw_project_title = "  neighbourhood ACCESS study  "  # Stores the calculated or supplied value in raw_project_title.
# raw_field_label = "Service Access?"  # Stores the calculated or supplied value in raw_field_label.
# raw_missing_marker = " n/a "  # Stores the calculated or supplied value in raw_missing_marker.
# reviewer_note = None  # Stores the calculated or supplied value in reviewer_note.
#
# project_title = raw_project_title.strip().title()  # Stores the calculated or supplied value in project_title.
# field_name = raw_field_label.strip().lower().replace(" ", "_").replace("?", "")  # Stores the calculated or supplied value in field_name.
# missing_marker = raw_missing_marker.strip().upper()  # Stores the calculated or supplied value in missing_marker.
# review_complete = False  # Stores the calculated or supplied value in review_complete.
#
# standardisation_note = (  # Stores the calculated or supplied value in standardisation_note.
#     f"Project: {project_title}\n"  # Runs this step from the tutorial example.
#     f"Proposed field name: {field_name}\n"  # Runs this step from the tutorial example.
#     f"Preserved missing marker: {missing_marker}\n"  # Runs this step from the tutorial example.
#     f"Review complete: {review_complete}\n"  # Runs this step from the tutorial example.
#     f"Reviewer note: {reviewer_note}"  # Runs this step from the tutorial example.
# )  # Runs this step from the tutorial example.
#
# print(standardisation_note)  # Displays information so the result can be inspected.
# print("Raw project title retained:", raw_project_title)  # Displays information so the result can be inspected.
# print("Reviewer-note type:", type(reviewer_note))  # Displays information so the result can be inspected.
# ```

# %%
# Raw metadata copied from a fictional intake form.
raw_project_title = "  neighbourhood ACCESS study  "  # Stores the calculated or supplied value in raw_project_title.
raw_field_label = "Service Access?"  # Stores the calculated or supplied value in raw_field_label.
raw_missing_marker = " n/a "  # Stores the calculated or supplied value in raw_missing_marker.
reviewer_note = None  # Stores the calculated or supplied value in reviewer_note.

project_title = raw_project_title.strip().title()  # Stores the calculated or supplied value in project_title.
field_name = raw_field_label.strip().lower().replace(" ", "_").replace("?", "")  # Stores the calculated or supplied value in field_name.
missing_marker = raw_missing_marker.strip().upper()  # Stores the calculated or supplied value in missing_marker.
review_complete = False  # Stores the calculated or supplied value in review_complete.

standardisation_note = (  # Stores the calculated or supplied value in standardisation_note.
    f"Project: {project_title}\n"  # Runs this step from the tutorial example.
    f"Proposed field name: {field_name}\n"  # Runs this step from the tutorial example.
    f"Preserved missing marker: {missing_marker}\n"  # Runs this step from the tutorial example.
    f"Review complete: {review_complete}\n"  # Runs this step from the tutorial example.
    f"Reviewer note: {reviewer_note}"  # Runs this step from the tutorial example.
)  # Runs this step from the tutorial example.

print(standardisation_note)  # Displays information so the result can be inspected.
print("Raw project title retained:", raw_project_title)  # Displays information so the result can be inspected.
print("Reviewer-note type:", type(reviewer_note))  # Displays information so the result can be inspected.

# %% [markdown]
# ### Tutorial 2.7 reference — What comes next — manual or file-dependent example
#
# **Website subsection:** Tutorial 2.7
# **Website source:** `python-foundations-i.md`, line 5260
# **Status:** Run manually with the stated input or file — an external CSV file.
#
# ```python
# data = pd.read_csv("main_case_raw.csv")  # Stores the calculated or supplied value in data.
# ```

# %%
example_status = 'Tutorial 2.7 reference is labelled run manually with the stated input or file: an external CSV file'  # Stores the audit result without executing unsafe or deliberately broken code.
print(example_status)  # Displays why the original snippet is not run automatically.

# %% [markdown]
# ## Checks
#
# - Every example is grouped under the same 2.1–2.7 number used by the website.
# - Every executable cell can run from a fresh Python 3 session.
# - Deliberately broken, interactive or future file-dependent snippets remain visible in the preceding text and use a safe status cell during **Run all**.

# %% [markdown]
# ## Next Steps
#
# Open the separate Lecture 3 exercises notebook after working through the examples for the current website page.
